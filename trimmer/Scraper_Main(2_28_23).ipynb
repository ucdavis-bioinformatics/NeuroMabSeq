# %%
# !git clone https://github.com/dimitryzub/scrape-google-scholar.git
# Out:
# fatal: destination path 'scrape-google-scholar' already exists and is not an empty directory.

# %%
# !pip install -r scrape-google-scholar/requirements.txt
# Out:
# Requirement already satisfied: async-generator==1.10 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 1)) (1.10)
# Requirement already satisfied: attrs==22.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 2)) (22.2.0)
# Requirement already satisfied: certifi==2022.12.7 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==3.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: Cython==0.29.33 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 5)) (0.29.33)
# Requirement already satisfied: exceptiongroup==1.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: google-search-results==2.4.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: h11==0.14.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: html5lib==1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 9)) (1.1)
# Requirement already satisfied: idna==3.4 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 10)) (3.4)
# Requirement already satisfied: lxml==4.9.2 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 11)) (4.9.2)
# Requirement already satisfied: numpy==1.24.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 12)) (1.24.1)
# Requirement already satisfied: outcome==1.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: pandas==1.5.2 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 14)) (1.5.2)
# Requirement already satisfied: PySocks==1.7.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 15)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: pytz==2022.7.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 17)) (2022.7.1)
# Requirement already satisfied: requests==2.28.2 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 18)) (2.28.2)
# Requirement already satisfied: selectolax==0.3.12 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 19)) (0.3.12)
# Requirement already satisfied: selenium==4.7.2 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 20)) (4.7.2)
# Requirement already satisfied: selenium-stealth==1.0.6 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 21)) (1.0.6)
# Requirement already satisfied: six==1.16.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 22)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 24)) (2.4.0)
# Requirement already satisfied: trio==0.22.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 25)) (0.22.0)
# Requirement already satisfied: trio-websocket==0.9.2 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 26)) (0.9.2)
# Requirement already satisfied: urllib3==1.26.14 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 27)) (1.26.14)
# Requirement already satisfied: webencodings==0.5.1 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 28)) (0.5.1)
# Requirement already satisfied: wsproto==1.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from -r scrape-google-scholar/requirements.txt (line 29)) (1.2.0)

# %% [markdown]
# ## Import

# %%
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.chrome.service import Service
from selectolax.lexbor import LexborHTMLParser
import os, json
from typing import List, Dict, Callable
import time, random, re
import pandas as pd

import requests
import io
from io import BytesIO
from io import StringIO

import requests

import re
from bs4 import BeautifulSoup

import time

# %%
def parse(parser: Callable, organic_results_data: Callable):
    '''
    Arugments:
    - parser:  Lexbor parser from scrape_google_scholar_organic_results() function.
    - organic_results_data: List to append data to. List origin location is scrape_google_scholar_organic_results() function. Line 104.
    
    This function parses data from Google Scholar Organic results and appends data to a List.
    
    It's used by scrape_google_scholar_organic_results().
    
    It returns nothing as it appends data to `organic_results_data`, 
    which appends it to `organic_results_data` List in the scrape_google_scholar_organic_results() function.
    '''
    
    for result in parser.css('.gs_r.gs_or.gs_scl'):
        try:
            title: str = result.css_first('.gs_rt').text()
        except: title = None

        try:
            title_link: str = result.css_first('.gs_rt a').attrs['href']
        except: title_link = None

        try:
            publication_info: str = result.css_first('.gs_a').text()
        except: publication_info = None

        try:
            snippet: str = result.css_first('.gs_rs').text()
        except: snippet = None

        try:
            # if Cited by is present in inline links, it will be extracted
            cited_by_link = ''.join([link.attrs['href'] for link in result.css('.gs_ri .gs_fl a') if 'Cited by' in link.text()])
        except: cited_by_link = None
        
        try:
            # if Cited by is present in inline links, it will be extracted and type cast it to integer
            cited_by_count = int(''.join([re.search(r'\d+', link.text()).group() for link in result.css('.gs_ri .gs_fl a') if 'Cited by' in link.text()]))
        except: cited_by_count = None
        
        try:
            pdf_file: str = result.css_first('.gs_or_ggsm a').attrs['href']
        except: pdf_file = None

        organic_results_data.append({
            'title': title,
            'title_link': title_link,
            'publication_info': publication_info,
            'snippet': snippet if snippet else None,
            'cited_by_link': f'https://scholar.google.com{cited_by_link}' if cited_by_link else None,
            'cited_by_count': cited_by_count if cited_by_count else None,
            'pdf_file': pdf_file
        })

def scrape_google_scholar_organic_results(
                                        query: str,
                                        pagination: bool = False,
                                        operating_system: str = 'Windows' or 'Linux',
                                        year_start: int = None,
                                        year_end: int = None,
                                        save_to_csv: bool = False, 
                                        save_to_json: bool = False
                                        ) -> List[Dict[str, str]]:
    '''
    Extracts data from Google Scholar Organic resutls page:
    - title: str
    - title_link: str
    - publication_info: str 
    - snippet: str
    - cited_by_link: str 
    - cited_by_count: int
    - pdf_file: str
    
    Arguments:
    - query: str. Search query. 
    - pagination: bool. Enables or disables pagination.
    - operating_system: str. 'Windows' or 'Linux', Checks for operating system to either run Windows or Linux verson of chromedriver
    
    Usage:
    data = scrape_google_scholar_organic_results(query='blizzard', pagination=False, operating_system='win') # pagination defaults to False 
    
    for organic_result in data:
        print(organic_result['title'])
        print(organic_result['pdf_file'])
    '''
    assert year_start and year_end
    if year_start or year_end:
        assert year_start and year_end
        assert year_start <= year_end

    # selenium stealth
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    
    options.add_experimental_option('excludeSwitches', ['enable-automation'])
    options.add_experimental_option('useAutomationExtension', False)
    
    # checks for operating system to either run Windows or Linux verson of chromedriver
    # expects to have chromedriver near the runnable file
    if operating_system is None:
        raise Exception('Please provide your OS to `operating_system` argument: "Windows" or "Linux" for script to operate.')
    
    if operating_system.lower() == 'windows' or 'win':
        driver = webdriver.Chrome(options=options, service=Service(executable_path='chromedriver.exe'))
    
    if operating_system.lower() == 'linux': 
        driver = webdriver.Chrome(options=options, service=Service(executable_path='chromedriver'))
    
    stealth(driver,
        languages=['en-US', 'en'],
        vendor='Google Inc.',
        platform='Win32',
        webgl_vendor='Intel Inc.',
        renderer='Intel Iris OpenGL Engine',
        fix_hairline=True,
    )
    
    page_num: int = 0
    organic_results_data: list = []
    
    if pagination:
        while True:
            # parse all pages
            driver.get(f'https://scholar.google.com/scholar?q={query}&hl=en&gl=us&start={page_num}&as_ylo={year_start}&as_yhi={year_end}')
            parser = LexborHTMLParser(driver.page_source)
            
            parse(parser=parser, organic_results_data=organic_results_data)
            
            # pagination
            if parser.css_first('.gs_ico_nav_next'):  # checks for the "Next" page button
                page_num += 10                        # paginate to the next page
                time.sleep(random.randint(1, 2))      # sleep between paginations
            else:
                break
    else:
        # parse single, first page
        driver.get(f'https://scholar.google.com/scholar?q={query}&hl=en&gl=us&start={page_num}')
        parser = LexborHTMLParser(driver.page_source)
    
        parse(parser=parser, organic_results_data=organic_results_data)
        
    if save_to_csv:
        pd.DataFrame(data=organic_results_data).to_csv('google_scholar_organic_results_data.csv', 
                                                        index=False, encoding='utf-8')
    if save_to_json:
        pd.DataFrame(data=organic_results_data).to_json('google_scholar_organic_results_data.json', 
                                                        index=False, orient='records')
    driver.quit()
    return organic_results_data

# %% [markdown]
# ## Add target column from neuromab database

# %%
def AddTargetCol(df,final_df):
            
    merged_df = final_df.merge(df[['Clone', 'Target']], left_on=['Antibody'],right_on=['Clone'], how='left')
    merged_df = merged_df.drop('Clone', axis=1)
   
    return merged_df

# %% [markdown]
# ## Grab Neuromab DataFrame from site

# %%
data = requests.get("https://neuromab.ucdavis.edu/catalog-download.cfm").content
df = pd.read_csv(BytesIO(data))

# %% [markdown]
# ## Grab Catalog df for query creation

# %%
df2 = pd.read_excel('/Users/HMans_MacBook_Pro/Library/Mobile Documents/com~apple~CloudDocs/Desktop/TrimmerLab/runresults.xlsx')

# %% [markdown]
# ## Create URL

# %%
def CreatURL(query):
    
    query1 = query[0:8]
    end_pos = query.find('/', 9)
    query2= query[9:end_pos]
    query3= query[end_pos+1:]
    
    url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=' + (query1 + '+' + query2 + '%' + '2F' + query3 + '&oq=neuromab+')

    return url

# %% [markdown]
# ## Create Dataframe function

# %%
def CreateDF(query,result_value,data):
    
    # Record the difference between search result # and data length 
    count = (int(result_value)) - (int({len(data)}.pop()))
    final_df = pd.DataFrame(data)
    
    # Get rid of extraneous strings from title 
    final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')

    # Creat file for data 
    file_query = query.replace("/","_")
    file_query = file_query[0:8]+file_query[9:]
    filename = file_query + ".csv"
    directory = '/Users/HMans_MacBook_Pro/Library/Mobile Documents/com~apple~CloudDocs/Desktop/TrimmerLab/picklequeries'

    # Input Antibody name into table 
    final_df["Antibody"] = [query[9:]] * len(final_df)
    final_df = AddTargetCol(df,final_df)
    final_df.to_csv(os.path.join(directory, filename), index=False)
    
    # Input different result string based on difference in count 
    if count == 0:
        print(query + ' ' + 'All accounted for : DF saved to file')
        df2.loc[df2['Clone'] == query_name, 'Result'] = 'All accounted for : DF saved to file'

    elif (count < 4) and (count > 0) :
        print(query + ' ' +'There seems to be'+" "+str(count)+' '+"paper(s) w/o years")
        df2.loc[df2['Clone'] == query_name, 'Result'] = 'There seems to be'+" "+str(count)+' '+"paper(s) w/o years"

    else:
        print(query + ' ' +'Something went wrong with Search, too many papers not found')
        df2.loc[df2['Clone'] == query_name, 'Result'] = 'Something went wrong with Search, too many papers not found'

    return final_df

# %% [markdown]
# ## Scholar Query : search into google scholar and grab data from query

# %%
# Initialize a value to count 0 result pages 
zero_result_counter = 0

for query_name in df2.iloc[109:]['Clone']:
    data = {}
 
    # Set query for google scholar 
    query = 'neuromab' + ' ' + query_name

    # Grab data from google scholar 
    data = scrape_google_scholar_organic_results(query=query, pagination=True, operating_system="Windows", year_start=2005, year_end=2024)

    # create URL to grab results 
    url = CreatURL(query)
    url_info = requests.get(url)
    html = url_info.text

    # Create a BeautifulSoup object from the HTML string
    soup = BeautifulSoup(html, 'html.parser')
    result_elem = soup.select_one('#gs_ab_md .gs_ab_mdw')

    if result_elem:
        result_text = result_elem.get_text(strip=True)
        result_match = re.search(r'(\d+[\d,]*)\s+results', result_text)
        if result_match == None:
            result_match = re.search(r'(\d+[\d,]*)\s+result', result_text)

        if result_match:
            result_value = result_match.group(1)
            final_df = CreateDF(query,result_value,data)
        else:
            print(query + ' ' +"Search - No papers Available")
            df2.loc[df2['Clone'] == query_name, 'Result'] = "Search - No papers Available"
            
    else:
        print(query + ' ' +"No result element , we got dropped")
        df2.loc[df2['Clone'] == query_name, 'Result'] = "No result element , we got dropped"
        zero_result_counter = zero_result_counter + 1
        if zero_result_counter > 2:
            print('Going to bed on' + ' ' + query)
            time.sleep(3600)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#      28 if result_match:
#      29     result_value = result_match.group(1)
# ---> 30     final_df = CreateDF(query,result_value,data)
#      31 else:
#      32     print(query + ' ' +"Search - No papers Available")
#
# Input In [7], in CreateDF(query, result_value, data)
#       3 count = (int(result_value)) - (int({len(data)}.pop()))
#       4 final_df = pd.DataFrame(data)
# ----> 5 final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
#       7 file_query = query.replace("/","_")
#       8 file_query = file_query[0:8]+file_query[9:]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'title'

# %%
df2.to_excel('/Users/HMans_MacBook_Pro/Library/Mobile Documents/com~apple~CloudDocs/Desktop/TrimmerLab/runresults.xlsx')

# %%
final_df
# Out:
#                                                 title  \
# 0   Metabolic regulation of Kv channels and cardia...
# 1   Distribution of language‐related Cntnap2 prote...
# 2   Stress-evoked tyrosine phosphorylation of sign...
# 3   Selective loss of presynaptic potassium channe...
# 4   K+ channel alterations in the progression of e...
# 5   An αII spectrin-based cytoskeleton protects la...
# 6    Identification of voltage-gated K+ channel be...
# 7   A toolbox of IgG subclass-switched recombinant...
# 8    mTOR-dependent alterations of Kv1. 1 subunit ...
# 9    Characterization of the axon initial segment ...
# 10   Interaction proteomics analysis of the pre-sy...
# 11  Modulation of cardiac Kv currents by Kvbeta2 a...
# 12  Secretin-Modulated Potassium Channel Trafficki...
# 13   The Role of Potassium Ion and Water Channels ...
# 14  Role of Autism Susceptibility Gene, CNTNAP2, i...
# 15   A Songbird Model of Genetically Based Speech ...
#
#                                            title_link  \
# 0   https://www.sciencedirect.com/science/article/...
# 1   https://onlinelibrary.wiley.com/doi/abs/10.100...
# 2   https://www.jneurosci.org/content/30/31/10472....
# 3   https://www.jneurosci.org/content/35/32/11433....
# 4   https://www.sciencedirect.com/science/article/...
# 5   https://www.jneurosci.org/content/37/47/11323....
# 6   https://www.sciencedirect.com/science/article/...
# 7            https://elifesciences.org/articles/43322
# 8   https://link.springer.com/content/pdf/10.1038/...
# 9   https://bmcbiol.biomedcentral.com/articles/10....
# 10  https://research.vumc.nl/files/472719/chapter%...
# 11        https://ir.library.louisville.edu/etd/2400/
# 12          https://scholarworks.uvm.edu/graddis/241/
# 13  https://search.proquest.com/openview/e61a02ffd...
# 14      https://apps.dtic.mil/sti/citations/ADA604001
# 15  https://search.proquest.com/openview/ab2c1a9e2...
#
#                                      publication_info  \
# 0   PJ Kilfoil, KC Chapalamadugu, X Hu, D Zhang… -...
# 1   MC Condro, SA White - Journal of Comparative N...
# 2   H Ohnishi, T Murata, S Kusakari, Y Hayashi… - ...
# 3   MJ Kole, J Qian, MP Waase, TL Klassen… - Journ...
# 4   PI Jukkola, AE Lovett-Racke, SS Zamvil, C Gu -...
# 5   CYM Huang, C Zhang, DR Zollinger… - Journal of...
# 6   C Bavassano, L Marvaldi, M Langeslag, B Sarg… ...
# 7   NP Andrews, JX Boeckman, CF Manning, JT Nguyen...
# 8   LH Nguyen, AE Anderson - Scientific Reports, 2...
# 9   A Duflocq, F Chareyre, M Giovannini… - BMC …, ...
# 10  N Chen, F Koopmans, RC van der Schors, P Klemm...
# 11      PJ Kilfoil - 2016 - ir.library.louisville.edu
# 12           M Williams - 2013 - scholarworks.uvm.edu
# 13            PI Jukkola - 2014 - search.proquest.com
# 14                    SA White - 2013 - apps.dtic.mil
# 15             MC Condro - 2013 - search.proquest.com
#
#                                               snippet  \
# 0   … (NeuroMab; K17/70) primary antibodies in 200...
# 1   … NP_034728), conserved in zebra finch Neuroma...
# 2   … Mouse mAbs to Kvβ2 (K17/70) and to Kv1.4 (K1...
# 3   A specialized axonal ending, the basket cell “...
# 4   … (clone #: K14/16, K17/70, and K13/31, respec...
# 5   Axons must withstand mechanical forces, includ...
# 6   … Monoclonal anti-Kvβ2 antibody (clone K17/70)...
# 7   … We thank the current and former staff member...
# 8   Cortical dysplasia (CD) is a common cause for ...
# 9   The axon initial segment (AIS) plays a crucial...
# 10  … Neuromab antibodies were provided by UC Davi...
# 11  Myocardial voltage-gated potassium (Kv) channe...
# 12  The voltage-gated potassium channel Kv1. 2 is ...
# 13  Neuroinflammation and demyelination in multipl...
# 14  Variants of the contactin associated protein-l...
# 15  Abstract Language is a complex communicative b...
#
#                                         cited_by_link  cited_by_count  \
# 0   https://scholar.google.com/scholar?cites=27357...            17.0
# 1   https://scholar.google.com/scholar?cites=16321...            36.0
# 2   https://scholar.google.com/scholar?cites=10583...            37.0
# 3   https://scholar.google.com/scholar?cites=18110...            22.0
# 4   https://scholar.google.com/scholar?cites=98209...            45.0
# 5   https://scholar.google.com/scholar?cites=14284...            53.0
# 6   https://scholar.google.com/scholar?cites=12225...            23.0
# 7   https://scholar.google.com/scholar?cites=17050...            23.0
# 8   https://scholar.google.com/scholar?cites=68005...            25.0
# 9   https://scholar.google.com/scholar?cites=34662...            95.0
# 10                                               None             NaN
# 11                                               None             NaN
# 12                                               None             NaN
# 13                                               None             NaN
# 14                                               None             NaN
# 15                                               None             NaN
#
#                                              pdf_file Antibody  \
# 0   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...   K17/70
# 1   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   K17/70
# 2   https://www.jneurosci.org/content/jneuro/30/31...   K17/70
# 3   https://www.jneurosci.org/content/jneuro/35/32...   K17/70
# 4   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   K17/70
# 5   https://www.jneurosci.org/content/jneuro/37/47...   K17/70
# 6   https://www.sciencedirect.com/science/article/...   K17/70
# 7        https://elifesciences.org/articles/43322.pdf   K17/70
# 8   https://link.springer.com/content/pdf/10.1038/...   K17/70
# 9   https://bmcbiol.biomedcentral.com/articles/10....   K17/70
# 10  https://research.vumc.nl/files/472719/chapter%...   K17/70
# 11  https://ir.library.louisville.edu/cgi/viewcont...   K17/70
# 12  https://scholarworks.uvm.edu/cgi/viewcontent.c...   K17/70
# 13  https://etd.ohiolink.edu/apexprod/rws_etd/send...   K17/70
# 14       https://apps.dtic.mil/sti/pdfs/ADA604001.pdf   K17/70
# 15                                               None   K17/70
#
#                        Target
# 0   Kvbeta2/KCNAB2 K+ channel
# 1   Kvbeta2/KCNAB2 K+ channel
# 2   Kvbeta2/KCNAB2 K+ channel
# 3   Kvbeta2/KCNAB2 K+ channel
# 4   Kvbeta2/KCNAB2 K+ channel
# 5   Kvbeta2/KCNAB2 K+ channel
# 6   Kvbeta2/KCNAB2 K+ channel
# 7   Kvbeta2/KCNAB2 K+ channel
# 8   Kvbeta2/KCNAB2 K+ channel
# 9   Kvbeta2/KCNAB2 K+ channel
# 10  Kvbeta2/KCNAB2 K+ channel
# 11  Kvbeta2/KCNAB2 K+ channel
# 12  Kvbeta2/KCNAB2 K+ channel
# 13  Kvbeta2/KCNAB2 K+ channel
# 14  Kvbeta2/KCNAB2 K+ channel
# 15  Kvbeta2/KCNAB2 K+ channel

# %%
import os
import pandas as pd
df_list = []
path_to_files = ""
for file in os.listdir(path_to_files):
    query = pd.read_csv(f"{path_to_files}/{file})
    query["query"] = file.split(".")[0]
    df_list.append(pd.read_csv("file"))
final_df = pd.concat(df_list)
