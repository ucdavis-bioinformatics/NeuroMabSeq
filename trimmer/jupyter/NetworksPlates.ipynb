# %%
# read the file in downloads/TRIMMER00113_P101_LightChain.tsv
# create a dataframe of connections between the Sample_Name and DuplicatedIn whic is a list of Sample_Names

import pandas as pd
import sys
import os
import re
import argparse
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import gravis as gv
import glob


def read_in_nodes(file_name):
    """Reads the file and returns a dataframe of nodes"""
    df = pd.read_csv(file_name, sep='\t')
    # filter for only ones that contain LC in the chain column
    dfh = df[df['Chain'].str.contains('HC')]
    df = df[df['Chain'].str.contains('LC')]
    df = df[['Sample_Name', 'DuplicatedIn', 'MabID']]
    # replace empty space in the Sampline Name and DuplicatedIn columns with ""
    # if duplicated in is empty, create a connection to itsefl
    df['DuplicatedIn'] = df['DuplicatedIn'].fillna(df['Sample_Name'])
    df = df.dropna()
    df['DuplicatedIn'] = df['DuplicatedIn'].apply(lambda x: x.split(','))
    # if 

    # groupby the MabID and count the number of unique samples
    # print("Number of MabIDs reporting a sequence for the LC")
    # print(df.groupby('MabID')['Sample_Name'].nunique().count())
    # # do the same for the dfh
    # print("Number of MabIDs reporting a sequence for the HC")
    # print(dfh.groupby('MabID')['Sample_Name'].nunique().count())
    df = df.explode('DuplicatedIn')
    df = df.drop_duplicates()
    # drop duplicates for the other direction too
    df = df.rename(columns={'Sample_Name': 'Source', 'DuplicatedIn': 'Target'})
    # replace empty space in the Sampline Name and DuplicatedIn columns with ""
    df["Source"] = df["Source"].str.replace(' ', '')
    df["Target"] = df["Target"].str.replace(' ', '')
    df = df.drop_duplicates()
    df = df.reset_index(drop=True)
    # set a color column based on the MabId and everyhting before the first .
    df['category'] = df['MabID'].apply(lambda x: x.split('.')[0])
    # add a label column based on the source part after the _   
    df['label'] = df['Source'].apply(lambda x: x.split('_')[1])
    # drop the MaBID column
    df = df.drop(columns=['MabID'])

    # also print the number of unique samples

    return df

def create_graph(df):
    """Creates a graph from the dataframe and retain the color information"""
    G = nx.from_pandas_edgelist(df, 'Source', 'Target')
    # add the category as a node attribute
    nx.set_node_attributes(G, df.set_index('Source')['category'].to_dict(), 'category')
    # add the label as a node attribute
    nx.set_node_attributes(G, df.set_index('Source')['label'].to_dict(), 'label')

    return G

# %%
import matplotlib.pyplot as plt
import networkx as nx
import plotly.graph_objs as go
import matplotlib.pyplot as plt


def create_plotly_network_graph(G, file_name):
    # Ensure positions are assigned to the nodes
    if not nx.get_node_attributes(G, 'pos'):
        pos = nx.spring_layout(G)
    else:
        pos = nx.get_node_attributes(G, 'pos')

    # Assign a color to each category
    categories = set(nx.get_node_attributes(G, 'category').values())
    color_map = plt.cm.get_cmap('Set1', len(categories))
    category_color = {category: f'rgb{color_map(i)[:3]}' for i, category in enumerate(categories)}

    # Create edge trace
    edge_trace = go.Scatter(
        x=[],
        y=[],
        line=dict(width=0.5, color='#888'),
        hoverinfo='none',
        mode='lines')

    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_trace['x'] += tuple([x0, x1, None])
        edge_trace['y'] += tuple([y0, y1, None])

    # Create node trace
    node_trace = go.Scatter(
        x=[],
        y=[],
        mode='markers',
        hoverinfo='none',
        marker=dict(
            showscale=False,
            size=10,
            color=[category_color[G.nodes[node]['category']] for node in G.nodes()],
            line_width=2))

    # Node positions for annotation
    node_x = []
    node_y = []
    node_text = []

    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(G.nodes[node].get('label', str(node)))

    node_trace['x'] = node_x
    node_trace['y'] = node_y

    # Adding annotations for labels
    annotations = []
    for idx, label in enumerate(node_text):
        annotations.append(dict(
            x=node_x[idx],
            y=node_y[idx],
            xref="x",
            yref="y",
            text=label,
            showarrow=True,
            font=dict(
                size=16,
            ),
            ax=0,
            # put the label above the node
            
            ay=12,
        ))

    # Create network graph
    fig = go.Figure(data=[edge_trace, node_trace],
                 layout=go.Layout(
                    title=f"<br>{file_name}",
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20,l=5,r=5,t=40),
                    annotations=annotations,
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                    )

    # incrase the height of the figure
    fig.update_layout(height=800)
    return fig

# %%
# just do glob here
import glob
# get all the files in the temp_plates directory
files = glob.glob("/Users/keithmitchell/Desktop/temp_plates/*_Sequences.tsv")
# sort the globbed files
files.sort()
# loop through the files
for i, file in enumerate(files):
    # print("---------------")
    # print(f"Processing file {file}")

    # look in desktop/temp_plates
    fig = create_plotly_network_graph(create_graph(read_in_nodes(file)), file)
    
    # write out the figure as an html
    #fig.write_html(f"{project}_{plate}_LightChain.html")
    fig.show()

# %%
import plotly.offline as pyo

def save_multiple_graphs_to_html(graphs, filename="multiple_graphs.html"):
    html_string = """
    <html>
    <head>
    <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
    </head>
    <body>
    """
    
    for fig in graphs:
        # Convert each Plotly graph to an HTML div string
        div = pyo.plot(fig, include_plotlyjs=False, output_type='div')
        html_string += div
    
    html_string += """
    </body>
    </html>
    """

    # Write the combined HTML to a file
    with open(filename, 'w') as f:
        f.write(html_string)

# %%
# save all the files to an html
fig_list = []
for i in range(1, 105):    
    # if the plate is less than 100, add a 0 to the front else if plate is less than 10 add 00 to the front
    plate = f"P{i+1}"
    # glob for the file based on the plate
    file = glob.glob(f"/Users/keithmitchell/Downloads/alllcs/*_{plate}_LightChain.tsv")
    #fig = create_plotly_network_graph(create_graph(read_in_nodes(f"/Users/keithmitchell/Downloads/{project}_{plate}_LightChain.tsv")))
    if file:
        print(file, plate)
        fig = create_plotly_network_graph(create_graph(read_in_nodes(file[0])), file[0])
        # write out the figure as an html
        fig.write_html(f"{project}_{plate}_LightChain.html")
        fig_list.append(fig)

save_multiple_graphs_to_html(fig_list, filename="multiple_graphs.html")
# Out:
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0002_P2_LightChain.tsv'] P2
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0003_P3_LightChain.tsv'] P3
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0004.2_P4_LightChain.tsv'] P4
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0005_P5_LightChain.tsv'] P5
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0006_P6_LightChain.tsv'] P6
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0007_P7_LightChain.tsv'] P7
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0018_P8_LightChain.tsv'] P8
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0019_P9_LightChain.tsv'] P9
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0020_P10_LightChain.tsv'] P10
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0021_P11_LightChain.tsv'] P11
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0022_P12_LightChain.tsv'] P12
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0023_P13_LightChain.tsv'] P13
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0024_P14_LightChain.tsv'] P14
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0031_P15_LightChain.tsv'] P15
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0026_P16_LightChain.tsv'] P16
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0033_P17_LightChain.tsv'] P17
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0034_P18_LightChain.tsv'] P18
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0035_P19_LightChain.tsv'] P19
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0036_P20_LightChain.tsv'] P20
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0037_P21_LightChain.tsv'] P21
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0038_P22_LightChain.tsv'] P22
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0039_P23_LightChain.tsv'] P23
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0040_P24_LightChain.tsv'] P24
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0041_P25_LightChain.tsv'] P25
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0042_P26_LightChain.tsv'] P26
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0043_P27_LightChain.tsv'] P27
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0013_P28_LightChain.tsv'] P28
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0014_P29_LightChain.tsv'] P29
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0015_P30_LightChain.tsv'] P30
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0016_P31_LightChain.tsv'] P31
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0027_P33_LightChain.tsv'] P33
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0028_P34_LightChain.tsv'] P34
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0029_P35_LightChain.tsv'] P35
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0030_P36_LightChain.tsv'] P36
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0044_P37_LightChain.tsv'] P37
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0045_P38_LightChain.tsv'] P38
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0046_P39_LightChain.tsv'] P39
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0047_P40_LightChain.tsv'] P40
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0048_P41_LightChain.tsv'] P41
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0049_P42_LightChain.tsv'] P42
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0050_P43_LightChain.tsv'] P43
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0051_P44_LightChain.tsv'] P44
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0017_P45_LightChain.tsv'] P45
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0052_P46_LightChain.tsv'] P46
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0053_P47_LightChain.tsv'] P47
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0054_P48_LightChain.tsv'] P48
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0055_P49_LightChain.tsv'] P49
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0056_P50_LightChain.tsv'] P50
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0057_P51_LightChain.tsv'] P51
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0058_P52_LightChain.tsv'] P52
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0059_P54_LightChain.tsv'] P54
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0060_P55_LightChain.tsv'] P55
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0061_P56_LightChain.tsv'] P56
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0062_P57_LightChain.tsv'] P57
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0063_P58_LightChain.tsv'] P58
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0064_P59_LightChain.tsv'] P59
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0065_P60_LightChain.tsv'] P60
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0066_P65_LightChain.tsv'] P65
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0067_P66_LightChain.tsv'] P66
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0078_P67_LightChain.tsv'] P67
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0079_P68_LightChain.tsv'] P68
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0080_P69_LightChain.tsv'] P69
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0081_P70_LightChain.tsv'] P70
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0082_P71_LightChain.tsv'] P71
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0083_P72_LightChain.tsv'] P72
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0084_P73_LightChain.tsv'] P73
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0085_P74_LightChain.tsv'] P74
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0086_P75_LightChain.tsv'] P75
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0087_P76_LightChain.tsv'] P76
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0088_P77_LightChain.tsv'] P77
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0089_P78_LightChain.tsv'] P78
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0090_P79_LightChain.tsv'] P79
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0091_P80_LightChain.tsv'] P80
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0092_P81_LightChain.tsv'] P81
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0093_P82_LightChain.tsv'] P82
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0094_P83_LightChain.tsv'] P83
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0095_P84_LightChain.tsv'] P84
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0096_P85_LightChain.tsv'] P85
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0097_P86_LightChain.tsv'] P86
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0098_P87_LightChain.tsv'] P87
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER0099_P88_LightChain.tsv'] P88
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00100_P89_LightChain.tsv'] P89
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00101_P90_LightChain.tsv'] P90
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00103_P91_LightChain.tsv'] P91
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00104_P92_LightChain.tsv'] P92
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00105_P93_LightChain.tsv'] P93
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00106_P94_LightChain.tsv'] P94
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00107_P95_LightChain.tsv'] P95
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00108_P96_LightChain.tsv'] P96
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00109_P97_LightChain.tsv'] P97
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00110_P98_LightChain.tsv'] P98
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00111_P99_LightChain.tsv'] P99
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00112_P100_LightChain.tsv'] P100
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00113_P101_LightChain.tsv'] P101
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00114_P102_LightChain.tsv'] P102
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00115_P103_LightChain.tsv'] P103
# ['/Users/keithmitchell/Downloads/alllcs/TRIMMER00116_P104_LightChain.tsv'] P104
