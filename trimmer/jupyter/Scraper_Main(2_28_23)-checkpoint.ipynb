# %%
from selenium import webdriver
from selenium_stealth import stealth
from selenium.webdriver.chrome.service import Service
from selectolax.lexbor import LexborHTMLParser
from typing import List, Dict, Callable
import time, random, re
import requests
import io
from io import BytesIO
from io import StringIO
from bs4 import BeautifulSoup
import glob as glob
from fuzzywuzzy import fuzz
import numpy as np
from pymed import PubMed
import os, json
from typing import List, Dict, Callable
import time, random, re
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time 
import glob
import os
import pandas as pd
import numpy as np
# Out:
# /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# !brew install chromedriver
# Out:
# Running `brew update --auto-update`...
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:02180ca8b8295422ae84921bcf034b7ee8ce5575488bd5e6a37a192e53cd5d34
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.1.4.el_capitan.bottle.tar.gz
# ==> homebrew/core is old and unneeded, untapping to save space...
# Untapping homebrew/core...
# Untapped 3 commands and 6829 formulae (7,240 files, 713.7MB).
# ==> homebrew/cask is old and unneeded, untapping to save space...
# Untapping homebrew/cask...
# Untapped 4290 casks (4,423 files, 391.7MB).
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# abi3audit                                python-asn1crypto
# action-validator                         python-attrs
# ain                                      python-boto3
# ali                                      python-botocore
# amass                                    python-brotli
# ansible@8                                python-cachetools
# apkleaks                                 python-chardet
# appstream                                python-charset-normalizer
# argc                                     python-cli-helpers
# asitop                                   python-colorama
# auditwheel                               python-configargparse
# authz0                                   python-configobj
# awscli-local                             python-cycler
# badkeys                                  python-dateutil
# bao                                      python-dicttoxml
# biodiff                                  python-distlib
# bkcrack                                  python-distro
# bob                                      python-docopt
# bomber                                   python-filelock
# bounceback                               python-hatch-fancy-pypi-readme
# c3c                                      python-hatch-vcs
# cargo-llvm-cov                           python-hatchling
# cargo-sweep                              python-idna
# cariddi                                  python-jinja
# certgraph                                python-jmespath
# certsync                                 python-json5
# cfripper                                 python-kiwisolver
# chainsaw                                 python-magic
# changie                                  python-mako
# cherrybomb                               python-markdown-it-py
# chisel-tunnel                            python-matplotlib
# cidr                                     python-mdurl
# cliam                                    python-mpmath
# crunchy-cli                              python-msgpack
# csprecon                                 python-networkx
# csvlens                                  python-oauthlib
# daktilo                                  python-openapi3
# dalfox                                   python-pathspec
# dcp                                      python-pbr
# der-ascii                                python-platformdirs
# dicebear                                 python-pluggy
# diffoci                                  python-ply
# direwolf                                 python-prompt-toolkit
# dockerfile-language-server               python-regex
# dockly                                   python-requests
# doltgres                                 python-requests-oauthlib
# doppler                                  python-rich
# dotter                                   python-s3transfer
# drogon                                   python-setuptools-scm
# eatmemory                                python-sympy
# faircamp                                 python-termcolor
# favirecon                                python-trove-classifiers
# flyscrape                                python-urllib3
# frozen                                   python-wcwidth
# gdrive@2                                 python-websocket-client
# geoip2fast                               python-xlsxwriter
# ghc@9.6                                  qbittorrent-cli
# git-grab                                 rapidfuzz-cpp
# git-mediate                              rathole
# gitsign                                  rattler-build
# gittuf                                   raven
# glbinding@2                              rdap
# goresym                                  redress
# gotpm                                    redwax-tool
# gptline                                  reflex
# graphqlviz                               regclient
# haiti                                    rekor-cli
# halp                                     retire
# helm-ls                                  retry
# hopscotch-map                            richgo
# immer                                    rsyncy
# instaloader                              ruby@3.2
# intercept                                ruler
# invoice                                  scarb
# jot                                      scikit-image
# jprq                                     scilla
# k8sgpt                                   scnlib
# kew                                      senpai
# kiota                                    shell2http
# lager                                    shellspec
# libconfini                               sigma-cli
# libcyaml                                 signmykey
# libdpp                                   sigstore
# libjuice                                 skate
# libnghttp3                               sloth
# libnsbmp                                 snakeviz
# libnsgif                                 snyk-cli
# libsail                                  solo2-cli
# libspelling                              spglib
# libwapcaplet                             spicetify-cli
# limesuite                                spidermonkey@91
# mariadb@11.1                             sqlfmt
# mediamtx                                 squealer
# memray                                   ssh-mitm
# minder                                   sshportal
# modsurfer                                steamguard-cli
# ncmdump                                  sugarjar
# netsurf-buildsystem                      tailspin
# node@20                                  telegram-downloader
# noir                                     terraform-local
# nowplaying-cli                           terrapin-scanner
# nvimpager                                texi2mdoc
# ocaml@4                                  texttest
# open-simh                                three-body
# openjph                                  tlrc
# opensca-cli                              tomlplusplus
# orbuculum                                urlscan
# osctrl-cli                               uvicorn
# oslo                                     veilid
# pan                                      vet
# patat                                    virtctl
# patch-package                            vulkan-volk
# pciutils                                 vulsio-gost
# pdfalyzer                                wasmedge
# pdfrip                                   whisper-cpp
# perl-xml-parser                          witness
# php@8.2                                  xeol
# phylum-cli                               xnvme
# pivit                                    yatas
# pmix                                     zigmod
# presenterm                               zipkin
# purr                                     zix
# python-abseil                            zug
# python-anytree
# ==> New Casks
# affine                                   mdb-accdb-viewer
# amie                                     mediamate
# anka-build-cloud-controller              metamer
# anka-build-cloud-registry                mindmac
# aqua                                     mitmproxy
# batchoutput-pdf                          music-decoy
# bezel                                    navigraph-charts
# bitbox                                   navigraph-simlink
# blockstream-green                        nightshade
# brickstore                               notes-better
# brightintosh                             nvs
# btp                                      nx-studio
# bugdom2                                  october
# cardo-update                             ok-json
# clibor                                   ollama
# codewhisperer                            opencat
# commandpost                              openthesaurus-deutsch
# creality-print                           orka3
# deskpad                                  ovito
# deveco-studio                            ovito-pro
# domzilla-caffeine                        pile
# douyin-chat                              prettyclean
# effect-house                             proton-drive
# egovframedev                             reader
# emby                                     roam
# focusrite-control-2                      rode-central
# fossa                                    sakura
# free-podcast-transcription               salt
# garmin-basecamp                          screens-assist
# geekbench-ml                             senabluetoothdevicemanager
# greenery                                 shadow-bot
# gstreamer-development                    simplex
# gstreamer-runtime                        streammusic
# hapigo                                   taccy
# heynote                                  theiaide
# hides                                    timemachinestatus
# hoppscotch                               truhu
# ia-presenter                             ttu-base-suite
# imazing-profile-editor                   tunetag
# insomnium                                vimcal
# jazz2-resurrection                       wakatime
# jyutping                                 wave
# keyboard-cowboy                          wiso-steuer-2024
# keymapp                                  writerside
# libndi                                   xact
# lightburn                                xliff-editor
# lw-scanner                               xsplit-vcam
# lyricsfinder                             znote
# markedit
#
# You have 19 outdated formulae and 1 outdated cask installed.
#
# ==> Upgrading 1 outdated package:
# chromedriver 118.0.5993.70 -> 121.0.6167.85
# ==> Upgrading chromedriver
# ==> Downloading https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/121.
# ######################################################################### 100.0%
# ==> Unlinking Binary '/usr/local/bin/chromedriver'
# ==> Linking Binary 'chromedriver' to '/usr/local/bin/chromedriver'
# ==> Purging files for version 118.0.5993.70 of Cask chromedriver
# 🍺  chromedriver was successfully upgraded!

# %% [markdown]
# # TODO
# - clean up functions and doc strings and parameter typing - especially where it says for you to start onwards.
# - clean up the resulting files and merge pubmed results (clean duplicates etc.)
# - we also want to be sure the query is in the paper based on the pubmed url -
#   - i think there were some false positives from google scholar and most journals easy to hit url grab pdf and search it
# - when grouping by duplicates mark that multiple neuromabs were marked and str join on groupby so we see all the mabs that showed up in that paper.
# - query the paper via pubmed in order to confirm the query is in the paper? (we are doing this to confirm something which i cant rembmer its been a while)
# - follow up when you get the stage above and we will be adding more potential query data to the pipeline from antibodies inc and addgene
# - make a directory for the dates that were queried and the querieis that were created as files in the directory (unless you have a better idea but we want to be able to abstractly see the queries done and maybe check for files already being there and skip those queries?)
#   - for now this is all the data we need need but lets make somethign for this a bit better for the future.
#
#
#
# ## LONG TERM
# - data story telling and figures
# - add the add gene counts and do something creative to help us understand the most important research reagents (data science exercise)
# - antibodies inc sales as well but this and add gene are bottom of the list
# - add this data to the database/website

# %% [markdown]
# # A few notes
# - The code is not very clean but it works. Not sure how much you need of this but would be good excercise to work on and
# - `brew install chromedriver` to install chromedriver
# - change the directory above for your outputs
# - I can give you my login for VPN but you can also run with sleep as a background task - i think it does take a couple hours to reset.
# - Follow ups is find the papers with pubmed links and then scrape the pubmed links for the abstracts.

# %% [markdown]
# # Begin the scrapping of google scholar citations for neuromabs

# %%
query_out = '/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/'

# %%
def parse(parser: Callable, organic_results_data: Callable):
    '''
    Arugments:
    - parser:  Lexbor parser from scrape_google_scholar_organic_results() function.
    - organic_results_data: List to append data to. List origin location is scrape_google_scholar_organic_results() function. Line 104.
    
    This function parses data from Google Scholar Organic results and appends data to a List.
    
    It's used by scrape_google_scholar_organic_results().
    
    It returns nothing as it appends data to `organic_results_data`, 
    which appends it to `organic_results_data` List in the scrape_google_scholar_organic_results() function.
    '''
    
    for result in parser.css('.gs_r.gs_or.gs_scl'):
        try:
            title: str = result.css_first('.gs_rt').text()
        except: title = None

        try:
            title_link: str = result.css_first('.gs_rt a').attrs['href']
        except: title_link = None

        try:
            publication_info: str = result.css_first('.gs_a').text()
        except: publication_info = None

        try:
            snippet: str = result.css_first('.gs_rs').text()
        except: snippet = None

        try:
            # if Cited by is present in inline links, it will be extracted
            cited_by_link = ''.join([link.attrs['href'] for link in result.css('.gs_ri .gs_fl a') if 'Cited by' in link.text()])
        except: cited_by_link = None
        
        try:
            # if Cited by is present in inline links, it will be extracted and type cast it to integer
            cited_by_count = int(''.join([re.search(r'\d+', link.text()).group() for link in result.css('.gs_ri .gs_fl a') if 'Cited by' in link.text()]))
        except: cited_by_count = None
        
        try:
            pdf_file: str = result.css_first('.gs_or_ggsm a').attrs['href']
        except: pdf_file = None

        organic_results_data.append({
            'title': title,
            'title_link': title_link,
            'publication_info': publication_info,
            'snippet': snippet if snippet else None,
            'cited_by_link': f'https://scholar.google.com{cited_by_link}' if cited_by_link else None,
            'cited_by_count': cited_by_count if cited_by_count else None,
            'pdf_file': pdf_file
        })

def scrape_google_scholar_organic_results(
                                        query: str,
                                        pagination: bool = False,
                                        operating_system: str = 'Windows' or 'Linux',
                                        year_start: int = None,
                                        year_end: int = None,
                                        save_to_csv: bool = False, 
                                        save_to_json: bool = False
                                        ) -> List[Dict[str, str]]:
    '''
    Extracts data from Google Scholar Organic resutls page:
    - title: str
    - title_link: str
    - publication_info: str 
    - snippet: str
    - cited_by_link: str 
    - cited_by_count: int
    - pdf_file: str
    
    Arguments:
    - query: str. Search query. 
    - pagination: bool. Enables or disables pagination.
    - operating_system: str. 'Windows' or 'Linux', Checks for operating system to either run Windows or Linux verson of chromedriver
    
    Usage:
    data = scrape_google_scholar_organic_results(query='blizzard', pagination=False, operating_system='win') # pagination defaults to False 
    
    for organic_result in data:
        print(organic_result['title'])
        print(organic_result['pdf_file'])
    '''
    assert year_start and year_end
    if year_start or year_end:
        assert year_start and year_end
        assert year_start <= year_end

    from selenium import webdriver
    from selenium.webdriver.chrome.service import Service

    service = Service()

    # selenium stealth
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    
    options.add_experimental_option('excludeSwitches', ['enable-automation'])
    options.add_experimental_option('useAutomationExtension', False)
    
    # checks for operating system to either run Windows or Linux verson of chromedriver
    # expects to have chromedriver near the runnable file
    if operating_system is None:
        raise Exception('Please provide your OS to `operating_system` argument: "Windows" or "Linux" for script to operate.')
    
    # if operating_system.lower() == 'windows' or 'win':
    #     driver = webdriver.Chrome(options=options, service=Service(executable_path='chromedriver.exe'))
    
    # if operating_system.lower() == 'linux': 
    #     driver = webdriver.Chrome(options=options, service=Service(executable_path='/Users/keithmitchell/Desktop/chromedriver_mac64/chromedriver'))
    


    driver = webdriver.Chrome(service=service, options=options)
    stealth(driver,
        languages=['en-US', 'en'],
        vendor='Google Inc.',
        platform='Win32',
        webgl_vendor='Intel Inc.',
        renderer='Intel Iris OpenGL Engine',
        fix_hairline=True,
    )
    
    page_num: int = 0
    organic_results_data: list = []
    
    if pagination:
        while True:
            # parse all pages
            driver.get(f'https://scholar.google.com/scholar?q={query}&hl=en&gl=us&start={page_num}&as_ylo={year_start}&as_yhi={year_end}')
            parser = LexborHTMLParser(driver.page_source)
            
            parse(parser=parser, organic_results_data=organic_results_data)
            
            # pagination
            if parser.css_first('.gs_ico_nav_next'):  # checks for the "Next" page button
                page_num += 10                        # paginate to the next page
                time.sleep(random.randint(1, 2))      # sleep between paginations
            else:
                break
    else:
        # parse single, first page
        driver.get(f'https://scholar.google.com/scholar?q={query}&hl=en&gl=us&start={page_num}')
        parser = LexborHTMLParser(driver.page_source)
    
        parse(parser=parser, organic_results_data=organic_results_data)
        
    if save_to_csv:
        pd.DataFrame(data=organic_results_data).to_csv('google_scholar_organic_results_data.csv', 
                                                        index=False, encoding='utf-8')
    if save_to_json:
        pd.DataFrame(data=organic_results_data).to_json('google_scholar_organic_results_data.json', 
                                                        index=False, orient='records')
    driver.quit()
    return organic_results_data


def AddTargetCol(df,final_df):
            
    merged_df = final_df.merge(df[['Clone', 'Target']], left_on=['Antibody'],right_on=['Clone'], how='left')
    merged_df = merged_df.drop('Clone', axis=1)
   
    return merged_df

def CreatURL(query):
    
    query1 = query[0:8]
    end_pos = query.find('/', 9)
    query2= query[9:end_pos]
    query3= query[end_pos+1:]
    
    url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=' + (query1 + '+' + query2 + '%' + '2F' + query3 + '&oq=neuromab+')

    return url

def CreateDF(query,result_value,data):
    
    # Record the difference between search result # and data length 
    # TODO wendon not sure why pop but:
        # i bet this whole function can be cleaned quite a bit and might be a good initial cleaning stage
        # more info is still better than less info most of the time moving forward more filtering at the final result after pubmed query
    count = (int(result_value)) - (int({len(data)}.pop()))
    final_df = pd.DataFrame(data)
    
    # Get rid of extraneous strings from title 
    final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')

    # Creat file for data 
    file_query = query.replace("/","_")
    file_query = file_query[0:8]+file_query[9:]
    filename = file_query + ".csv"
    directory = query_out

    # Input Antibody name into table 
    final_df["Antibody"] = [query[9:]] * len(final_df)
    final_df = AddTargetCol(df,final_df)
    final_filename = directory + filename
    final_df.to_csv(final_filename, index=False)


def run_code(new_index, df):
    # Initialize a value to count 0 result pages 
    zero_result_counter = 0
    count_list = []
    # in the future we will only need to run 2023 - 202X
    zero_result_length = 10
    start_year = 2005
    end_year = 2024


    for index, query_name in zip(df.index[new_index:], df['Clone'][new_index:]):
        # Construct the filename and directory path
        file_query = 'neuromab' + ' ' + query_name.replace("/", "_")
        filename = file_query[0:8] + file_query[9:] + ".csv"
        directory = query_out
        final_filename = directory + filename

        # Check if the file already exists
        print(final_filename)
        if os.path.exists(final_filename):
            print(f"File {final_filename} already exists. Skipping query for {query_name}.")
            count_list = []
            continue  # Skip this iteration and move to the next query_name

        data = {}
        print(index, query_name)
        # Set query for google scholar 
        query = 'neuromab' + ' ' + query_name


        # Grab data from google scholar 
        data = scrape_google_scholar_organic_results(query=query, pagination=True, operating_system="Windows", year_start=2005, year_end=2024)
        if len(data) == 0:
            count_list.append(len(data))
            past_0 = 10
            # if the last X elements are 0 then break - we got booted and need to reset the vpn
            # check if the last past_0 elements are 0
            if len(count_list) > past_0 and all([i == 0 for i in count_list[-past_0:]]):
                print("We got booted, resetting vpn")
                new_index = index - past_0
                print(count_list[-20:])
                return new_index
            continue
        else:
            print(len(data))
            count_list.append(len(data))
        # create URL to grab results 
        url = CreatURL(query)
        url_info = requests.get(url)
        html = url_info.text

        # Create a BeautifulSoup object from the HTML string
        soup = BeautifulSoup(html, 'html.parser')
        result_elem = soup.select_one('#gs_ab_md .gs_ab_mdw')

        if result_elem:
            result_text = result_elem.get_text(strip=True)
            result_match = re.search(r'(\d+[\d,]*)\s+results', result_text)
            if result_match == None:
                result_match = re.search(r'(\d+[\d,]*)\s+result', result_text)

            if result_match:
                result_value = result_match.group(1)
                final_df = CreateDF(query,result_value,data)
            elif len(data) > 0:
                print(query + ' ' + "Problem with search")
            else:
                print(query + ' ' +"Search - No papers Available")

# %%
new_index = run_code(0)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN358_68.csv
# 0 N358/68
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN297_59.csv
# 1 N297/59
# [{'title': 'A toolbox of IgG subclass-switched recombinant monoclonal antibodies for enhanced multiplex immunolabeling of brain', 'title_link': 'https://elifesciences.org/articles/43322', 'publication_info': 'NP Andrews, JX Boeckman, CF Manning, JT Nguyen…\xa0- Elife, 2019 - elifesciences.org', 'snippet': '… We thank the current and former staff members of the UC Davis/NIH NeuroMab Facility and \nthe Trimmer laboratory for their contributions and dedicated efforts, and Dr. Randall Stewart …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17050756740404723444&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 35, 'pdf_file': 'https://elifesciences.org/articles/43322.pdf'}]
# 1
# <div class="gs_ab_mdw">1 result (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN144_14.csv
# 2 N144/14
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'A complex of Protocadherin-19 and N-cadherin mediates a novel mechanism of cell adhesion', 'title_link': 'https://rupress.org/jcb/article-abstract/195/7/1115/50544', 'publication_info': 'MR Emond, S Biswas, CJ Blevins, JD Jontes\xa0- Journal of Cell Biology, 2011 - rupress.org', 'snippet': '… N144/14; University of California Davis/National Institutes of Health … (N144/14) was \nobtained form the University of California Davis/National Institutes of Health NeuroMab Facility. …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=11570850227880684426&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 118, 'pdf_file': 'https://rupress.org/jcb/article/195/7/1115/50544'}, {'title': '[HTML][HTML] Cdk5-mediated phosphorylation of CRMP-2 enhances its interaction with CaV2. 2', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S0014579312007302', 'publication_info': 'JM Brittain, Y Wang, O Eruvwetere, R Khanna\xa0- FEBS letters, 2012 - Elsevier', 'snippet': '… Lysates were incubated with CRMP-2-6xHis, following phosphorylation, and immunoprecipitated \n(IP) with a 6xHis antibody (UC Davis/NIH NeuroMab Facility, clone N144/14) overnight …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=16563680875508578169&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 83, 'pdf_file': 'https://www.sciencedirect.com/science/article/pii/S0014579312007302'}, {'title': 'Reprogramming protein kinase substrate specificity through synthetic mutations', 'title_link': 'https://www.biorxiv.org/content/10.1101/091892.abstract', 'publication_info': 'JM Lubner, GM Church, MF Chou, D Schwartz\xa0- bioRxiv, 2016 - biorxiv.org', 'snippet': 'Protein kinase specificity is largely imparted through substrate binding pocket motifs. Missense \nmutations in these regions are frequently associated with human disease, and in some …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=11711795253009293444&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 5, 'pdf_file': 'https://www.biorxiv.org/content/10.1101/091892.full.pdf'}, {'title': 'α-synuclein promotes neuronal dysfunction and death by disrupting the binding of ankyrin to β-spectrin', 'title_link': 'https://www.jneurosci.org/content/43/9/1614.abstract', 'publication_info': 'G Maor, RR Dubreuil, MB Feany\xa0- Journal of Neuroscience, 2023 - Soc Neuroscience', 'snippet': 'α-Synuclein plays a key role in the pathogenesis of Parkinson’s disease and related disorders, \nbut critical interacting partners and molecular mechanisms mediating neurotoxicity are …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=2534773715424354551&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 4, 'pdf_file': 'https://www.jneurosci.org/content/jneuro/43/9/1614.full.pdf'}, {'title': '[PDF][PDF] Direct binding between pre-S1 and TRP-like domains in TRPP channels mediates gating and functional regulation by PIP2', 'title_link': 'https://www.cell.com/cell-reports/pdf/S2211-1247(18)30074-3.pdf', 'publication_info': 'W Zheng, R Cai, L Hofmann, V Nesin, Q Hu, W Long…\xa0- Cell reports, 2018 - cell.com', 'snippet': '… Mouse antibody against His (N144/14) for western blotting was from NeuroMab (Davis, \nCA). Mouse antibody against His (27E8) and rabbit antibody against His (no. 2365) were …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=11546023765385568191&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 47, 'pdf_file': 'https://www.cell.com/cell-reports/pdf/S2211-1247(18)30074-3.pdf'}, {'title': 'A cytoskeleton-membrane interaction conserved in fast-spiking neurons controls movement, emotion, and memory', 'title_link': 'https://www.nature.com/articles/s41380-023-02286-7', 'publication_info': 'D Ma, C Sun, R Manne, T Guo, C Bosc, J Barry…\xa0- Molecular\xa0…, 2023 - nature.com', 'snippet': 'The pathogenesis of schizophrenia is believed to involve combined dysfunctions of many \nproteins including microtubule-associated protein 6 (MAP6) and Kv3.1 voltage-gated K + (Kv) …', 'ci ...
# 18
# <div class="gs_ab_mdw">About 18 results (<b>0.04</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN441_35.csv
# 3 N441/35
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN46_30.csv
# 4 N46/30
# [{'title': 'ADAM22, a Kv1 channel-interacting protein, recruits membrane-associated guanylate kinases to juxtaparanodes of myelinated axons', 'title_link': 'https://www.jneurosci.org/content/30/3/1038.short', 'publication_info': 'Y Ogawa, J Oses-Prieto, MY Kim, I Horresh…\xa0- Journal of\xa0…, 2010 - Soc Neuroscience', 'snippet': '… Mouse monoclonal anti-PSD-93 (N18/30) and anti-ADAM22 (cytoplasmic, N46/30; extracellular, \nN57/2) were obtained from the University of California Davis/NIH NeuroMab Facility and …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14430312203913766150&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 140, 'pdf_file': 'https://www.jneurosci.org/content/jneuro/30/3/1038.full.pdf'}, {'title': 'ADAM22 ethnic-specific variant reducing binding of membrane-associated guanylate kinases causes focal epilepsy and behavioural disorder', 'title_link': 'https://academic.oup.com/braincomms/article-abstract/5/6/fcad295/7331272', 'publication_info': 'L Nosková, Y Fukata, V Stránecký…\xa0- Brain\xa0…, 2023 - academic.oup.com', 'snippet': 'Pathogenic variants of ADAM22 affecting either its biosynthesis and/or its interactions with \neither LGI1 and/or PSD-95 have been recently identified in individuals with developmental …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://academic.oup.com/braincomms/article/5/6/fcad295/7331272'}, {'title': 'Selective loss of presynaptic potassium channel clusters at the cerebellar basket cell terminal pinceau in adam11 mutants reveals their role in ephaptic control of\xa0…', 'title_link': 'https://www.jneurosci.org/content/35/32/11433.short', 'publication_info': 'MJ Kole, J Qian, MP Waase, TL Klassen…\xa0- Journal of\xa0…, 2015 - Soc Neuroscience', 'snippet': 'A specialized axonal ending, the basket cell “pinceau,” encapsulates the Purkinje cell axon \ninitial segment (AIS), exerting final inhibitory control over the integrated outflow of the …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=18110999572490803927&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 31, 'pdf_file': 'https://www.jneurosci.org/content/jneuro/35/32/11433.full.pdf'}, {'title': 'Implication of perturbed axoglial apparatus in early pediatric multiple sclerosis', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/ana.22693', 'publication_info': 'AS Dhaunchak, C Becker, H Schulman…\xa0- Annals of\xa0…, 2012 - Wiley Online Library', 'snippet': 'Cerebrospinal fluid samples collected from children during initial presentation of central \nnervous system inflammation, who may or may not subsequently be diagnosed as having …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=7257469917794942915&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 72, 'pdf_file': 'https://www.academia.edu/download/97417051/ana.2269320230117-1-119id9n.pdf'}, {'title': 'ADAM22 and ADAM23 modulate the targeting of the Kv1 channel-associated protein LGI1 to the axon initial segment', 'title_link': 'https://journals.biologists.com/jcs/article-abstract/132/2/jcs219774/57255', 'publication_info': 'B Hivert, L Marien, KN Agbam…\xa0- Journal of Cell\xa0…, 2019 - journals.biologists.com', 'snippet': 'The distribution of the voltage-gated Kv1 K + channels at the axon initial segment (AIS) \ninfluences neuronal intrinsic excitability. The Kv1.1 and Kv1.2 (also known as KCNA1 and KCNA2…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14121031914267829013&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 35, 'pdf_file': 'https://www.biorxiv.org/content/biorxiv/early/2018/04/30/311365.full.pdf'}, {'title': '[HTML][HTML] Selective axonal expression of the Kv1 channel complex in pre-myelinated GABAergic hippocampal neurons', 'title_link': 'https://www.frontiersin.org/articles/10.3389/fncel.2019.00222/full', 'publication_info': 'G Bonetto, B Hivert, L Goutebroze…\xa0- Frontiers in Cellular\xa0…, 2019 - frontiersin.org', 'snippet': 'In myelinated fibers, the voltage-gated sodium cha ...
# 10
# <div class="gs_ab_mdw">10 results (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN57_2.csv
# 5 N57/2
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'ADAM22, a Kv1 channel-interacting protein, recruits membrane-associated guanylate kinases to juxtaparanodes of myelinated axons', 'title_link': 'https://www.jneurosci.org/content/30/3/1038.short', 'publication_info': 'Y Ogawa, J Oses-Prieto, MY Kim, I Horresh…\xa0- Journal of\xa0…, 2010 - Soc Neuroscience', 'snippet': '… Mouse monoclonal anti-PSD-93 (N18/30) and anti-ADAM22 (cytoplasmic, N46/30; extracellular, \nN57/2) were obtained from the University of California Davis/NIH NeuroMab Facility and …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14430312203913766150&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 140, 'pdf_file': 'https://www.jneurosci.org/content/jneuro/30/3/1038.full.pdf'}, {'title': 'ADAM22 and ADAM23 modulate the targeting of the Kv1 channel-associated protein LGI1 to the axon initial segment', 'title_link': 'https://journals.biologists.com/jcs/article-abstract/132/2/jcs219774/57255', 'publication_info': 'B Hivert, L Marien, KN Agbam…\xa0- Journal of Cell\xa0…, 2019 - journals.biologists.com', 'snippet': 'The distribution of the voltage-gated Kv1 K + channels at the axon initial segment (AIS) \ninfluences neuronal intrinsic excitability. The Kv1.1 and Kv1.2 (also known as KCNA1 and KCNA2…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14121031914267829013&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 35, 'pdf_file': 'https://www.biorxiv.org/content/biorxiv/early/2018/04/30/311365.full.pdf'}, {'title': 'Characterizing the molecular etiology of arthrogryposis multiplex congenita in patients with LGI4 mutations', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/glia.24061', 'publication_info': 'DG Booth, N Kozar, S Bradley, D Meijer\xa0- Glia, 2021 - Wiley Online Library', 'snippet': 'Disruption of axon‐glia interactions in the peripheral nervous system has emerged as a major \ncause of arthrogryposis multiplex congenita (AMC), a condition characterized by multiple …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14556690499801745311&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 1, 'pdf_file': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/glia.24061'}]
# 3
# <div class="gs_ab_mdw">3 results (<b>0.02</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN444_63.csv
# 6 N444/63
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN103_39.csv
# 7 N103/39
# [{'title': '[HTML][HTML] New α-and γ-synuclein immunopathological lesions in human brain', 'title_link': 'https://link.springer.com/article/10.1186/s40478-014-0132-8', 'publication_info': 'I Surgucheva, KL Newell, J Burns…\xa0- Acta neuropathologica\xa0…, 2014 - Springer', 'snippet': '… Antibodies to the following astrocytes markers have been used: monoclonal anti-Aldh1L1, \nclone N103/39 (Cat #MABN495, NeuroMab UC, Davis, CA) is used as a protoplasmic …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=13484574156534265402&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 63, 'pdf_file': 'https://link.springer.com/article/10.1186/s40478-014-0132-8'}, {'title': '[PDF][PDF] New α-and γ-synuclein immunopathological', 'title_link': 'https://www.researchgate.net/profile/Andrei-Surguchov/publication/265557954_New_-_and_-synuclein_immunopathological_lesions_in_human_brain/links/544a958a0cf2d6347f401164/New-and-synuclein-immunopathological-lesions-in-human-brain.pdf', 'publication_info': 'I Surgucheva, KL Newell, J Burns, A Surguchov - 2014 - researchgate.net', 'snippet': '8 Abstract 9 Introduction: Several neurodegenerative diseases are classified as proteopathies \nas they are associated with the 10 aggregation of misfolded proteins. Synucleinopathies …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://www.researchgate.net/profile/Andrei-Surguchov/publication/265557954_New_-_and_-synuclein_immunopathological_lesions_in_human_brain/links/544a958a0cf2d6347f401164/New-and-synuclein-immunopathological-lesions-in-human-brain.pdf'}, {'title': '[PDF][PDF] BACE1 regulates hippocampal astrogenesis via the Jagged1-Notch pathway', 'title_link': 'https://www.cell.com/cell-reports/pdf/S2211-1247(13)00283-0.pdf', 'publication_info': 'X Hu, W He, X Luo, KE Tsubota, R Yan\xa0- Cell reports, 2013 - cell.com', 'snippet': "BACE1 is the sole secretase for generating β-amyloid (Aβ) in vivo and is being actively pursued \nas a drug target for the treatment of Alzheimer's disease. Transmembrane BACE1 exerts …", 'cited_by_link': 'https://scholar.google.com/scholar?cites=10564077969651103915&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 93, 'pdf_file': 'https://www.cell.com/cell-reports/pdf/S2211-1247(13)00283-0.pdf'}, {'title': '[HTML][HTML] Astrocyte activation via Stat3 signaling determines the balance of oligodendrocyte versus Schwann cell remyelination', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S0002944015003338', 'publication_info': 'GM De Castro, NA Deja, D Ma, C Zhao…\xa0- The American journal of\xa0…, 2015 - Elsevier', 'snippet': 'Remyelination within the central nervous system (CNS) most often is the result of oligodendrocyte \nprogenitor cells differentiating into myelin-forming oligodendrocytes. In some cases, …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=12689982981287117930&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 51, 'pdf_file': 'https://www.sciencedirect.com/science/article/pii/S0002944015003338'}, {'title': '[HTML][HTML] Immature excitatory neurons develop during adolescence in the human amygdala', 'title_link': 'https://www.nature.com/articles/s41467-019-10765-1', 'publication_info': 'SF Sorrells, MF Paredes, D Velmeshev…\xa0- Nature\xa0…, 2019 - nature.com', 'snippet': 'The human amygdala grows during childhood, and its abnormal development is linked to \nmood disorders. The primate amygdala contains a large population of immature neurons in the …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=5273292342553155364&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 100, 'pdf_file': 'https://www.nature.com/articles/s41467-019-10765-1'}, {'title': 'Temporal patterns of gene expression during calyx of held development', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/dneu.22306', 'publication_info': 'DR Kolson, J Wan, J Wu, M Dehoff…\xa0- Developmental\xa0…, 2016 - Wiley Online Library', 'snippet': 'Relating changes in gene expression  ...
# 19
# <div class="gs_ab_mdw">About 19 results (<b>0.04</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN103_31.csv
# 8 N103/31
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'Influence of rat substrain and growth conditions on the characteristics of primary cultures of adult rat spinal cord astrocytes', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S0165027011000860', 'publication_info': 'S Codeluppi, EN Gregory, J Kjell, G Wigerblad…\xa0- Journal of neuroscience\xa0…, 2011 - Elsevier', 'snippet': 'Primary astrocyte cell cultures have become a valuable tool for studies of signaling pathways \nthat regulate astrocyte physiology, reactivity, and function; however, differences in culture …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=125809848116562120&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 57, 'pdf_file': None}, {'title': 'Cellular and subcellular localization of the neuron‐specific plasma membrane calcium ATPase PMCA1a in the rat brain', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/cne.22409', 'publication_info': 'KA Kenyon, EA Bushong, AS Mauer…\xa0- Journal of\xa0…, 2010 - Wiley Online Library', 'snippet': 'Regulation of intracellular calcium is crucial both for proper neuronal function and survival. \nBy coupling ATP hydrolysis with Ca 2+ extrusion from the cell, the plasma membrane calcium…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=4233604802252694781&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 33, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2894304/'}, {'title': 'A toolbox of IgG subclass-switched recombinant monoclonal antibodies for enhanced multiplex immunolabeling of brain', 'title_link': 'https://elifesciences.org/articles/43322', 'publication_info': 'NP Andrews, JX Boeckman, CF Manning, JT Nguyen…\xa0- Elife, 2019 - elifesciences.org', 'snippet': '… We thank the current and former staff members of the UC Davis/NIH NeuroMab Facility and \nthe Trimmer laboratory for their contributions and dedicated efforts, and Dr. Randall Stewart …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17050756740404723444&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 35, 'pdf_file': 'https://elifesciences.org/articles/43322.pdf'}, {'title': 'Nrf2 signaling links ER oxidative protein folding and calcium homeostasis in health and disease', 'title_link': 'https://www.life-science-alliance.org/content/2/5/e201900563.abstract', 'publication_info': 'V Granatiero, C Konrad, K Bredvik…\xa0- Life science\xa0…, 2019 - life-science-alliance.org', 'snippet': 'We report a signaling pathway linking two fundamental functions of the ER, oxidative protein \nfolding, and intracellular calcium regulation. Cells sense ER oxidative protein folding …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=975324302206061608&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 22, 'pdf_file': 'https://www.life-science-alliance.org/content/lsa/2/5/e201900563.full.pdf'}, {'title': '[HTML][HTML] Interleukin-6 secretion by astrocytes is dynamically regulated by PI3K-mTOR-calcium signaling', 'title_link': 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0092649', 'publication_info': 'S Codeluppi, T Fernandez-Zafra, K Sandor, J Kjell…\xa0- PLoS\xa0…, 2014 - journals.plos.org', 'snippet': 'After contusion spinal cord injury (SCI), astrocytes become reactive and form a glial scar. \nWhile this reduces spreading of the damage by containing the area of injury, it inhibits …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=10368533316909085486&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 46, 'pdf_file': 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0092649'}]
# 5
# <div class="gs_ab_mdw">5 results (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN442_28.csv
# 9 N442/28
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN330A_80.csv
# 10 N330A/80
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN330A_51.csv
# 11 N330A/51
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL86_33.csv
# 12 L86/33
# [{'title': '[HTML][HTML] Kv2 ion channels determine the expression and localization of the associated AMIGO-1 cell adhesion molecule in adult brain neurons', 'title_link': 'https://www.frontiersin.org/articles/10.3389/fnmol.2018.00001/full', 'publication_info': 'HI Bishop, MM Cobb, M Kirmiz, LK Parajuli…\xa0- Frontiers in Molecular\xa0…, 2018 - frontiersin.org', 'snippet': '… Similar results were obtained using multiple Abs against AMIGO-1 (data not shown), including \ntwo different mouse mAbs with distinct cytoplasmic domain binding sites (L86/33 and L86A…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=1439707419585443685&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 34, 'pdf_file': 'https://www.frontiersin.org/articles/10.3389/fnmol.2018.00001/full'}, {'title': '[HTML][HTML] Epilepsy and neurobehavioral abnormalities in mice with a dominant-negative KCNB1 pathogenic variant', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S0969996120304162', 'publication_info': 'NA Hawkins, SN Misra, M Jurado, SK Kang…\xa0- Neurobiology of\xa0…, 2021 - Elsevier', 'snippet': 'Developmental and epileptic encephalopathies (DEE) are a group of severe epilepsies that \nusually present with intractable seizures, developmental delay, and often have elevated risk …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17717715578971690577&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 16, 'pdf_file': 'https://www.sciencedirect.com/science/article/pii/S0969996120304162'}, {'title': '[BOOK][B] Regulation of Kv2. 1 Channel Complexes', 'title_link': 'https://search.proquest.com/openview/ae57141eadb8ec9aad9693fa0aa4db6d/1?pq-origsite=gscholar&cbl=18750', 'publication_info': 'MM Cobb - 2015 - search.proquest.com', 'snippet': '… CMSSID[pS]FISSA; anti-AMIGO mAb L86/33, generated against amino acids 395-493 (… \nL86/33, and L86A/37 are available from the UC Davis/NIH NeuroMab Facility (http://neuromab…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=12378412110529918818&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 1, 'pdf_file': None}]
# 3
# <div class="gs_ab_mdw">3 results (<b>0.02</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL86_36.csv
# 13 L86/36
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL86A_37.csv
# 14 L86A/37
# [{'title': 'Cell type–specific spatial and functional coupling between mammalian brain Kv2.1 K+ channels and ryanodine receptors', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/cne.23641', 'publication_info': 'D Mandikian, E Bocksteins, LK Parajuli…\xa0- Journal of\xa0…, 2014 - Wiley Online Library', 'snippet': "… L86A/37 does not detect other isoforms of AMIGO in immunoblots using cell lysates from \nheterologous cells expressing either AMIGO-1, -2, or -3 (manufacturer's specifications). …", 'cited_by_link': 'https://scholar.google.com/scholar?cites=5232939310089047001&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 74, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4139460/'}, {'title': 'Developing a Toolbox of Antibodies Validated for Array Tomography-Based Imaging of Brain Synapses', 'title_link': 'https://www.eneuro.org/content/10/12/ENEURO.0290-23.2023.abstract', 'publication_info': 'KD Micheva, B Gong, F Collman, RJ Weinberg…\xa0- Eneuro, 2023 - eneuro.org', 'snippet': '… Other lanes include antiserum from one of the immunized mice (HB), a mouse serum negative \ncontrol, and a positive control NeuroMab mAb against a different target (L86A/37, AMIGO-…', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://www.eneuro.org/content/eneuro/10/12/ENEURO.0290-23.2023.full.pdf'}, {'title': '[HTML][HTML] High-volume hybridoma sequencing on the NeuroMabSeq platform enables efficient generation of recombinant monoclonal antibodies and scFvs for\xa0…', 'title_link': 'https://www.nature.com/articles/s41598-023-43233-4', 'publication_info': 'KG Mitchell, B Gong, SS Hunter, D Burkart-Waco…\xa0- Scientific Reports, 2023 - nature.com', 'snippet': '… , including at the UC Davis/NIH NeuroMab Facility, we have generated a large collection of \n… ) in red and the anti-Amigo-1 L86A/37 mAb (IgG2b) in purple. Hoechst nuclear labelling is …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://www.nature.com/articles/s41598-023-43233-4'}, {'title': '[HTML][HTML] NeuroMabSeq: high volume acquisition, processing, and curation of hybridoma sequences and their use in generating recombinant monoclonal antibodies\xa0…', 'title_link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10327083/', 'publication_info': 'KG Mitchell, B Gong, SS Hunter, D Burkart-Waco…\xa0- bioRxiv, 2023 - ncbi.nlm.nih.gov', 'snippet': '… , including at the UC Davis/NIH NeuroMab Facility, we have generated a large collection of \n… (IgG2a) in red and the anti-Amigo-1 L86A/37 (IgG2b) in purple. Hoechst nuclear labelling is …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10327083/'}, {'title': '[HTML][HTML] Kv2 ion channels determine the expression and localization of the associated AMIGO-1 cell adhesion molecule in adult brain neurons', 'title_link': 'https://www.frontiersin.org/articles/10.3389/fnmol.2018.00001/full', 'publication_info': 'HI Bishop, MM Cobb, M Kirmiz, LK Parajuli…\xa0- Frontiers in Molecular\xa0…, 2018 - frontiersin.org', 'snippet': '… (red, N372B/1 mAb), and AMIGO-1 (blue, L86A/37 mAb). Images were adjusted linearly \nfor … distinct cytoplasmic domain binding sites (L86/33 and L86A/37), and a rabbit pAb (AMIGO-1) …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=1439707419585443685&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 34, 'pdf_file': 'https://www.frontiersin.org/articles/10.3389/fnmol.2018.00001/full'}, {'title': 'Activity-dependent endoplasmic reticulum Ca2+ uptake depends on Kv2.1-mediated endoplasmic reticulum/plasma membrane junctions to promote synaptic\xa0…', 'title_link': 'https://www.pnas.org/doi/abs/10.1073/pnas.2117135119', 'publication_info': 'LC Panzera, B Johnson, JA Quinn…\xa0- Proceedings of the\xa0…, 2022 - National Acad Sciences', 'snippet': '… Purified Kv2 and AMIGO mouse monoclonal antibodies, knockout verified, were from \nNeuroMab (Kv2.1, K89/34; Kv2.2, N37B/1; and AMIGO, L86A/37) were used in res ...
# 10
# <div class="gs_ab_mdw">10 results (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN105_13.csv
# 15 N105/13
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'Glial ankyrins facilitate paranodal axoglial junction assembly', 'title_link': 'https://www.nature.com/articles/nn.3858', 'publication_info': 'KJ Chang, DR Zollinger, K Susuki, DL Sherman…\xa0- Nature\xa0…, 2014 - nature.com', 'snippet': '… from a P7 mouse spinal cord immunostained for AnkB (N105/13), AnkG (N106/36) and βIV \n… membrane-binding domain (N105/13 and N105/17, UC Davis/NIH NeuroMab Facility) (1:200 …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=3341068590640544487&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 92, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4260775/'}, {'title': 'Identification of a VxP Targeting Signal in the Flagellar Na+/K+‐ATPase', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/tra.12332', 'publication_info': 'JG Laird, Y Pan, M Modestou, DM Yamaguchi, H Song…\xa0- Traffic, 2015 - Wiley Online Library', 'snippet': 'Na + /K + ‐ ATPase ( NKA ) participates in setting electrochemical gradients, cardiotonic \nsteroid signaling and cellular adhesion. Distinct isoforms of NKA are found in different tissues …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=634896367871640207&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 7, 'pdf_file': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/tra.12332'}, {'title': 'AlphaII-spectrin participates in the surface expression of cell adhesion molecule L1 and neurite outgrowth', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S0014482714000214', 'publication_info': 'MM Trinh-Trang-Tan, S Bigot, J Picot…\xa0- Experimental Cell\xa0…, 2014 - Elsevier', 'snippet': '… conducted using monoclonal antibodies from the UC Davis/NIH NeuroMab Facility (University \nof California, Davis, CA 95616, USA), clones N105/13 and N106/20, respectively. F-actin …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=4553280945622197181&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 12, 'pdf_file': None}, {'title': 'A hierarchy of ankyrin-spectrin complexes clusters sodium channels at nodes of Ranvier', 'title_link': 'https://www.nature.com/articles/nn.3859', 'publication_info': 'TSY Ho, DR Zollinger, KJ Chang, M Xu…\xa0- Nature\xa0…, 2014 - nature.com', 'snippet': 'The scaffolding protein ankyrin-G is required for Na + channel clustering at axon initial \nsegments. It is also considered essential for Na + channel clustering at nodes of Ranvier to …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=12680295506356721648&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 105, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4271271/'}, {'title': 'A toolbox of IgG subclass-switched recombinant monoclonal antibodies for enhanced multiplex immunolabeling of brain', 'title_link': 'https://elifesciences.org/articles/43322', 'publication_info': 'NP Andrews, JX Boeckman, CF Manning, JT Nguyen…\xa0- Elife, 2019 - elifesciences.org', 'snippet': '… We thank the current and former staff members of the UC Davis/NIH NeuroMab Facility and \nthe Trimmer laboratory for their contributions and dedicated efforts, and Dr. Randall Stewart …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17050756740404723444&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 35, 'pdf_file': 'https://elifesciences.org/articles/43322.pdf'}, {'title': 'Complement inhibition prevents glial nodal membrane injury in a GM1 antibody-mediated mouse model', 'title_link': 'https://academic.oup.com/braincomms/article-abstract/4/6/fcac306/6841348', 'publication_info': 'CI Campbell, R McGonigal, JA Barrie…\xa0- Brain\xa0…, 2022 - academic.oup.com', 'snippet': 'The involvement of the complement pathway in Guillain–Barré syndrome pathogenesis has \nbeen demonstrated in both patient biosamples and animal models. One proposed …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17248280246685859586&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 4, 'pdf_file': 'https://academic.oup.com/braincomms/ar ...
# 9
# <div class="gs_ab_mdw">9 results (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN105_17.csv
# 16 N105/17
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'Glial ankyrins facilitate paranodal axoglial junction assembly', 'title_link': 'https://www.nature.com/articles/nn.3858', 'publication_info': 'KJ Chang, DR Zollinger, K Susuki, DL Sherman…\xa0- Nature\xa0…, 2014 - nature.com', 'snippet': '… and AnkB (N105/13 (c) or N105/17 (d)). The arrows indicate … cell (Sc) cultures (AnkB, N105/17). \nThe molecular weight is … cells and immunostained for AnkB (N105/17), neurofilament-M (…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=3341068590640544487&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 92, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4260775/'}, {'title': '[HTML][HTML] In vivo assembly of the axon initial segment in motor neurons', 'title_link': 'https://link.springer.com/article/10.1007/s00429-013-0578-7', 'publication_info': 'B Le Bras, A Fréal, A Czarnecki, P Legendre…\xa0- Brain Structure and\xa0…, 2014 - Springer', 'snippet': '… S1 a, b); (ii) the guinea pig, rabbit and mouse monoclonal anti-AnkG (N106/65; IgG2b; \nNeuromab) antibodies were shown to strictly colocalize at the AISs (Fig. S1 d); (iii) western blots …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=13236689137408544798&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 39, 'pdf_file': 'https://link.springer.com/article/10.1007/s00429-013-0578-7'}, {'title': 'Membrane domain organization of myelinated axons requires βII spectrin', 'title_link': 'https://rupress.org/jcb/article-abstract/203/3/437/31788', 'publication_info': 'C Zhang, K Susuki, DR Zollinger, JL Dupree…\xa0- Journal of Cell\xa0…, 2013 - rupress.org', 'snippet': '… Mouse monoclonal antibodies against ankyrinB (N105/17) and ankyrinG (N106/36) were \npurchased from the UC Davis/NIH NeuroMab Facility (Davis, CA). Mouse monoclonal …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=8617073615306366083&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 77, 'pdf_file': 'https://rupress.org/jcb/article/203/3/437/31788'}, {'title': 'TDP-43 maximizes nerve conduction velocity by repressing a cryptic exon for paranodal junction assembly in Schwann cells', 'title_link': 'https://elifesciences.org/articles/64456', 'publication_info': 'KJ Chang, I Agrawal, A Vainshtein, WY Ho, W Xin…\xa0- Elife, 2021 - elifesciences.org', 'snippet': 'TDP-43 is extensively studied in neurons in physiological and pathological contexts. \nHowever, emerging evidence indicates that glial cells are also reliant on TDP-43 function. We …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=12443971298999657140&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 13, 'pdf_file': 'https://elifesciences.org/articles/64456.pdf'}, {'title': 'A hierarchy of ankyrin-spectrin complexes clusters sodium channels at nodes of Ranvier', 'title_link': 'https://www.nature.com/articles/nn.3859', 'publication_info': 'TSY Ho, DR Zollinger, KJ Chang, M Xu…\xa0- Nature\xa0…, 2014 - nature.com', 'snippet': 'The scaffolding protein ankyrin-G is required for Na + channel clustering at axon initial \nsegments. It is also considered essential for Na + channel clustering at nodes of Ranvier to …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=12680295506356721648&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 105, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4271271/'}, {'title': 'α-synuclein promotes neuronal dysfunction and death by disrupting the binding of ankyrin to β-spectrin', 'title_link': 'https://www.jneurosci.org/content/43/9/1614.abstract', 'publication_info': 'G Maor, RR Dubreuil, MB Feany\xa0- Journal of Neuroscience, 2023 - Soc Neuroscience', 'snippet': 'α-Synuclein plays a key role in the pathogenesis of Parkinson’s disease and related disorders, \nbut critical interacting partners and molecular mechanisms mediating neurotoxicity are …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=2534773715424354551&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 4, 'pdf_file': 'https://www.jneurosci. ...
# 14
# <div class="gs_ab_mdw">About 14 results (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN106_20.csv
# 17 N106/20
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': '[HTML][HTML] Acetylated tau destabilizes the cytoskeleton in the axon initial segment and is mislocalized to the somatodendritic compartment', 'title_link': 'https://link.springer.com/article/10.1186/s13024-016-0109-0', 'publication_info': 'PD Sohn, TE Tracy, HI Son, Y Zhou, REP Leite…\xa0- Molecular\xa0…, 2016 - Springer', 'snippet': '… AnkG (N106/20, NeuroMab), rabbit polyclonal anti-βIV-spectrin (gift from Dr. Matthew N. \nRasband, Baylor College of Medicine), mouse monoclonal Tau5 (AHB0042, Life Technologies), …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=15386607309444817418&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 135, 'pdf_file': 'https://link.springer.com/article/10.1186/s13024-016-0109-0'}, {'title': '[HTML][HTML] High-volume hybridoma sequencing on the NeuroMabSeq platform enables efficient generation of recombinant monoclonal antibodies and scFvs for\xa0…', 'title_link': 'https://www.nature.com/articles/s41598-023-43233-4', 'publication_info': 'KG Mitchell, B Gong, SS Hunter, D Burkart-Waco…\xa0- Scientific Reports, 2023 - nature.com', 'snippet': '… , including at the UC Davis/NIH NeuroMab Facility, we have generated a large collection of \n… -G hybridoma-generated N106/20 mAb (left section) and the N106/20 scFv (right section). (c) …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://www.nature.com/articles/s41598-023-43233-4'}, {'title': '[HTML][HTML] NeuroMabSeq: high volume acquisition, processing, and curation of hybridoma sequences and their use in generating recombinant monoclonal antibodies\xa0…', 'title_link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10327083/', 'publication_info': 'KG Mitchell, B Gong, SS Hunter, D Burkart-Waco…\xa0- bioRxiv, 2023 - ncbi.nlm.nih.gov', 'snippet': '… , including at the UC Davis/NIH NeuroMab Facility, we have generated a large collection of \n… -G hybridoma-generated N106/20 mAb (left section) and the N106/20 scFv (right section). (c) …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10327083/'}, {'title': 'Activity-dependent mismatch between axo-axonic synapses and the axon initial segment controls neuronal output', 'title_link': 'https://www.pnas.org/doi/abs/10.1073/pnas.1502902112', 'publication_info': 'W Wefelmeyer, D Cattaert…\xa0- Proceedings of the\xa0…, 2015 - National Acad Sciences', 'snippet': '… We used the following primary antibodies: mouse monoclonal anti-AnkG (1:500; clone \nN106/20, NeuroMab), guinea pig polyclonal GABA A α2 (1:500; 224 104; Synaptic Systems) and …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=8410955619458170243&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 106, 'pdf_file': 'https://www.pnas.org/syndication/doi/10.1073/pnas.1502902112'}, {'title': '[PDF][PDF] TRIM46 controls neuronal polarity and axon specification by driving the formation of parallel microtubule arrays', 'title_link': 'https://www.cell.com/neuron/pdf/S0896-6273(15)01018-1.pdf', 'publication_info': 'SFB van Beuningen, L Will, M Harterink, A Chazeau…\xa0- Neuron, 2015 - cell.com', 'snippet': 'Axon formation, the initial step in establishing neuronal polarity, critically depends on local \nmicrotubule reorganization and is characterized by the formation of parallel microtubule …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17178720115391558414&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 190, 'pdf_file': 'https://www.cell.com/neuron/pdf/S0896-6273(15)01018-1.pdf'}, {'title': 'Blast wave exposure impairs memory and decreases axon initial segment length', 'title_link': 'https://www.liebertpub.com/doi/abs/10.1089/neu.2012.2478', 'publication_info': 'KL Baalman, RJ Cotton, SN Rasband…\xa0- Journal of\xa0…, 2013 - liebertpub.com', 'snippet': '… N106/36 and N106/20), glial fibrillary acidic protein (GFAP, N206A/8), and Nav1.6 (K87/10A) \nantibodies were purchased from the UC Davis/NIH funded Neuromab monoclonal antibody …', 'cit ...
# 15
# <div class="gs_ab_mdw">About 15 results (<b>0.04</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN106_36.csv
# 18 N106/36
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'A unique ion channel clustering domain on the axon initial segment of mammalian neurons', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/cne.23551', 'publication_info': 'AN King, CF Manning…\xa0- Journal of Comparative\xa0…, 2014 - Wiley Online Library', 'snippet': '… sections (ie, specific labeling of nodes of Ranvier and the AIS) as clone N106/36. N106/36 \nyields a single band of the appropriate size on immunoblots of rat and mouse brain samples, …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=4997433249052648458&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 91, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4133991/'}, {'title': 'Glial ankyrins facilitate paranodal axoglial junction assembly', 'title_link': 'https://www.nature.com/articles/nn.3858', 'publication_info': 'KJ Chang, DR Zollinger, K Susuki, DL Sherman…\xa0- Nature\xa0…, 2014 - nature.com', 'snippet': '… F/F ) spinal cords (AnkG, N106/36). Two mice per genotype and more than … (N106/36 and \nN106/65, NeuroMab) (1:200), Caspr (K65/35, NeuroMab) (1:200), contactin (K73/20, NeuroMab…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=3341068590640544487&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 92, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4260775/'}, {'title': 'Developing high-quality mouse monoclonal antibodies for neuroscience research–approaches, perspectives and opportunities', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S1871678415002587', 'publication_info': 'B Gong, KD Murray, JS Trimmer\xa0- New biotechnology, 2016 - Elsevier', 'snippet': '… We have long encouraged our end users to provide the specific NeuroMab clone number \n(eg, N106/36, N106/65, etc.) as an unambiguous transparent identifier in all publications, a …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14364775402662997243&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 25, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4884554/'}, {'title': 'Heterogeneity of astrocyte and NG2 cell insertion at the node of ranvier', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/cne.24083', 'publication_info': 'DR Serwanski, P Jukkola…\xa0- Journal of Comparative\xa0…, 2017 - Wiley Online Library', 'snippet': 'The node of Ranvier is a functionally important site on the myelinated axon where sodium \nchannels are clustered and regeneration of action potentials occurs, allowing fast saltatory …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=10728693822003018037&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 59, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5177504/'}, {'title': 'Myosin II activity is required for structural plasticity at the axon initial segment', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/ejn.13597', 'publication_info': 'MD Evans, C Tufo, AS Dumitrescu…\xa0- European Journal of\xa0…, 2017 - Wiley Online Library', 'snippet': '… Coverslips were then placed in primary antibody solution, in PBS plus 2 % GS, at relevant \nconcentrations: mouse monoclonal anti-ankyrin-G (Neuromab clone N106/36; 1 : 500) and …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=1287046857549233592&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 35, 'pdf_file': 'https://onlinelibrary.wiley.com/doi/pdf/10.1111/ejn.13597'}, {'title': '[HTML][HTML] Acetylated tau destabilizes the cytoskeleton in the axon initial segment and is mislocalized to the somatodendritic compartment', 'title_link': 'https://link.springer.com/article/10.1186/s13024-016-0109-0', 'publication_info': 'PD Sohn, TE Tracy, HI Son, Y Zhou, REP Leite…\xa0- Molecular\xa0…, 2016 - Springer', 'snippet': '… Sections were incubated first with antibodies against AnkG (N106/36, NeuroMab) and βIV-spectrin \n(gift from Dr. Matthew N. Rasband, Baylor College of Medicine) at 4 C overnight and …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=1538 ...
# 207
# <div class="gs_ab_mdw">About 208 results (<b>0.05</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN106_65.csv
# 19 N106/65
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# ...
# 25 N429/19
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': '[HTML][HTML] Genetic disruption of Ano5 in mice does not recapitulate human ANO5-deficient muscular dystrophy', 'title_link': 'https://link.springer.com/article/10.1186/s13395-015-0069-z', 'publication_info': 'J Xu, M El Refaey, L Xu, L Zhao, Y Gao, K Floyd…\xa0- Skeletal muscle, 2015 - Springer', 'snippet': 'Background Anoctamin 5 (ANO5) is a member of a conserved gene family (TMEM16), which \ncodes for proteins predicted to have eight transmembrane domains and putative Ca 2+ -…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=5895376560326029551&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 49, 'pdf_file': 'https://link.springer.com/article/10.1186/s13395-015-0069-z'}]
# 1
# <div class="gs_ab_mdw">1 result (<b>0.02</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN290B_25.csv
# 26 N290B/25
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN295B_66.csv
# 27 N295B/66
# [{'title': 'Corrigendum to “Hypomorphic Smo mutant with inefficient ciliary enrichment disrupts the highest level of vertebrate Hedgehog response”', 'title_link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6478522/', 'publication_info': 'ED Gigante, AB Long, J Ben-Ami…\xa0- Developmental\xa0…, 2019 - ncbi.nlm.nih.gov', 'snippet': 'The authors regret an error in section 2.3 of the Methods section of the manuscript. We \ninadvertently listed the Arl13b antibody lot number (455–8JD-29) in place of the antibody clone …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': None}, {'title': '[HTML][HTML] Loss of primary cilia occurs early in breast cancer development', 'title_link': 'https://ciliajournal.biomedcentral.com/articles/10.1186/2046-2530-3-7', 'publication_info': 'I Menzl, L Lebeau, R Pandey, NB Hassounah…\xa0- Cilia, 2014 - ciliajournal.biomedcentral.com', 'snippet': 'Primary cilia are microtubule-based organelles that protrude from the cell surface. Primary \ncilia play a critical role in development and disease through regulation of signaling pathways …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=9227819496275684283&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 138, 'pdf_file': 'https://ciliajournal.biomedcentral.com/articles/10.1186/2046-2530-3-7'}, {'title': '[HTML][HTML] Primary cilia are lost in preinvasive and invasive prostate cancer', 'title_link': 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0068521', 'publication_info': 'NB Hassounah, R Nagle, K Saboda, DJ Roe…\xa0- PloS one, 2013 - journals.plos.org', 'snippet': '… NeuroMab Facility, clone N295B/66) to verify the marking of cilia with the antibody against \nacetylated tubulin. The slides were then washed with PBS for 10 minutes (3 x 10 min). The …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=17790168660105844977&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 134, 'pdf_file': 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0068521'}, {'title': 'STRADA‐mutant human cortical organoids model megalencephaly and exhibit delayed neuronal differentiation', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/dneu.22816', 'publication_info': 'LT Dang, S Vaid, G Lin, P Swaminathan…\xa0- Developmental\xa0…, 2021 - Wiley Online Library', 'snippet': 'Genetic diseases involving overactivation of the mechanistic target of rapamycin (mTOR) \npathway, so‐called “mTORopathies,” often manifest with malformations of cortical development …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=11040201263681361290&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 24, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8364481/'}, {'title': 'A flow cytometry-based approach for the study of primary cilia', 'title_link': 'https://www.sciencedirect.com/science/article/pii/S0091679X22001091', 'publication_info': 'K Baur, G Hölzl-Wenig, F Ciccolini\xa0- Methods in Cell Biology, 2023 - Elsevier', 'snippet': 'Primary cilia provide a specialized subcellular environment favoring ordered and timely \ninteraction and modification of signaling molecules, necessary for the sensing and transduction …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=15569294004255639053&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 1, 'pdf_file': None}, {'title': 'Neuron‐specific cilia loss differentially alters locomotor responses to amphetamine in mice', 'title_link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/jnr.24755', 'publication_info': 'C Ramos, JB Roberts, KR Jasso…\xa0- Journal of\xa0…, 2021 - Wiley Online Library', 'snippet': 'The neural mechanisms that underlie responses to drugs of abuse are complex, and \nimpacted by a number of neuromodulatory peptides. Within the past 10 years it has been …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14769689997214690774&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 15, 'pdf_file': 'https://www.ncbi.nlm.nih.gov/pmc ...
# 96
# <div class="gs_ab_mdw">About 96 results (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN411_51.csv
# 28 N411/51
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'Arx expansion mutation perturbs cortical development by augmenting apoptosis without activating innate immunity in a mouse model of X-linked infantile spasms\xa0…', 'title_link': 'https://journals.biologists.com/dmm/article-abstract/13/3/dmm042515/225236', 'publication_info': 'MS Siehr, CA Massey…\xa0- Disease models &\xa0…, 2020 - journals.biologists.com', 'snippet': 'X-linked infantile spasms syndrome (ISSX) is a clinically devastating developmental \nepileptic encephalopathy with life-long impact. Arx (GCG)10+7 , a mouse model of the most …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=8347805286014318753&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 11, 'pdf_file': 'https://journals.biologists.com/dmm/article/13/3/dmm042515/225236'}]
# 1
# <div class="gs_ab_mdw">1 result (<b>0.02</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN271_44.csv
# 29 N271/44
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'Mutation of a conserved glutamine residue does not abolish desensitization of acid-sensing ion channel 1', 'title_link': 'https://rupress.org/jgp/article-abstract/153/8/e202012855/212203', 'publication_info': 'ML Rook, M Miaro, T Couch, DL Kneisley…\xa0- Journal of General\xa0…, 2021 - rupress.org', 'snippet': '… Blots were blocked with bovine serum albumin and probed with an ASIC1-specific antibody \n(NeuroMab clone N271/44) overnight at a 1:1,000 dilution. Blots were washed with Tris-…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=14105565010478009124&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 11, 'pdf_file': 'https://rupress.org/jgp/article/153/8/e202012855/212203'}, {'title': 'Black mamba venom peptides target acid-sensing ion channels to abolish pain', 'title_link': 'https://www.nature.com/articles/nature11494', 'publication_info': 'S Diochot, A Baron, M Salinas, D Douguet, S Scarzello…\xa0- Nature, 2012 - nature.com', 'snippet': '… (N271/44; 1:300; NeuroMab) and a monoclonal antibody against actin (AC-40; 1:1,000; \nSigma) as a loading control. siRNAs were intrathecally injected into mice (2 µg per mouse at a …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=4987435603971842476&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 444, 'pdf_file': 'https://hal.science/hal-04016619/file/Manuscript%2BFig%2BSuppl.pdf'}, {'title': 'Dynorphin neuropeptides decrease apparent proton affinity of ASIC1a by occluding the acidic pocket', 'title_link': 'https://pubs.acs.org/doi/abs/10.1021/acs.jmedchem.1c00447', 'publication_info': 'L Leisle, M Margreiter, A Ortega-Ramírez…\xa0- Journal of medicinal\xa0…, 2021 - ACS Publications', 'snippet': '… using an anti-ASIC1 antibody (NeuroMab clone N271/44 from UC Davis, Merck) and … \ndilution in 5% milk in TBST; NeuroMab clone N271/44 from UC Davis, Merck) in concert …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=4288257475455761114&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 6, 'pdf_file': None}, {'title': 'Functional knockout of the TRPV1 channel has no effect on the exercise pressor reflex in rats', 'title_link': 'https://physoc.onlinelibrary.wiley.com/doi/abs/10.1113/JP285267', 'publication_info': 'L Anselmi, GP Ducrocq, V Ruiz‐Velasco…\xa0- The Journal of\xa0…, 2023 - Wiley Online Library', 'snippet': 'The role played by the transient receptor potential vanilloid 1 (TRPV1) channel on the thin \nfibre afferents evoking the exercise pressor reflex is controversial. To shed light on this …', 'cited_by_link': None, 'cited_by_count': None, 'pdf_file': 'https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/JP285267'}, {'title': 'Mutation of a conserved gln residue does not abolish desensitization of acid-sensing ion channel 1', 'title_link': 'https://www.biorxiv.org/content/10.1101/2020.12.19.423606.abstract', 'publication_info': 'ML Rook, M Miaro, T Couch, DL Kneisley, M Musgaard…\xa0- bioRxiv, 2020 - biorxiv.org', 'snippet': '… Blots were blocked with bovine serum albumin and probed with an ASIC1-specific antibody \n(NeuroMab clone N271/44) overnight at a 1:1000 dilution. Blots were washed with Tris-…', 'cited_by_link': 'https://scholar.google.com/scholar?cites=13861521810294715061&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 1, 'pdf_file': 'https://www.biorxiv.org/content/10.1101/2020.12.19.423606.full.pdf'}, {'title': 'Endomorphins potentiate acid‐sensing ion channel currents and enhance the lactic acid‐mediated increase in arterial blood pressure: effects amplified in hindlimb\xa0…', 'title_link': 'https://physoc.onlinelibrary.wiley.com/doi/abs/10.1113/JP275058', 'publication_info': 'M Farrag, JK Drobish, HL Puhl, JS Kim…\xa0- The Journal of\xa0…, 2017 - Wiley Online Library', 'snippet': 'Key points Chronic limb ischaemia, characterized by inflammatory mediator release and a \nlow extracellular pH, leads to acid‐sensing ion channel (ASIC) activation and reflexively …', 'cited_by_link': 'https://scholar.google.com/s ...
# 9
# <div class="gs_ab_mdw">10 results (<b>0.04</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN347_42.csv
# 30 N347/42
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN76_8.csv
# 31 N76/8
# [{'title': "[PDF][PDF] Loss of ataxin-1 potentiates Alzheimer's pathogenesis by elevating cerebral BACE1 transcription", 'title_link': 'https://www.cell.com/cell/pdf/S0092-8674(19)30843-8.pdf', 'publication_info': 'J Suh, DM Romano, L Nitschke, SP Herrick…\xa0- Cell, 2019 - cell.com', 'snippet': 'Expansion of CAG trinucleotide repeats in ATXN1 causes spinocerebellar ataxia type 1 (SCA1), \na neurodegenerative disease that impairs coordination and cognition. While ATXN1 is …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=6728024840453406169&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 54, 'pdf_file': 'https://www.cell.com/cell/pdf/S0092-8674(19)30843-8.pdf'}]
# 1
# <div class="gs_ab_mdw">1 result (<b>0.03</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN76_3.csv
# 32 N76/3
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# [{'title': 'Self-assembling vascular endothelial growth factor nanoparticles improve function in spinocerebellar ataxia type 1', 'title_link': 'https://academic.oup.com/brain/article-abstract/142/2/312/5289533', 'publication_info': 'YS Hu, J Do, CR Edamakanti, AR Kini, M Martina…\xa0- Brain, 2019 - academic.oup.com', 'snippet': 'There is increasing appreciation for the role of the neurovascular unit in neurodegenerative \ndiseases. We showed previously that the angiogenic and neurotrophic cytokine, vascular …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=8265587599043321919&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 22, 'pdf_file': 'https://academic.oup.com/brain/article/142/2/312/5289533'}, {'title': '[HTML][HTML] Mutant ataxin1 disrupts cerebellar development in spinocerebellar ataxia type 1', 'title_link': 'https://www.jci.org/articles/view/96765', 'publication_info': 'CR Edamakanti, J Do, A Didonna…\xa0- The Journal of\xa0…, 2018 - Am Soc Clin Investig', 'snippet': 'Spinocerebellar ataxia type 1 (SCA1) is an adult-onset neurodegenerative disease caused \nby a polyglutamine expansion in the protein ATXN1, which is involved in transcriptional …', 'cited_by_link': 'https://scholar.google.com/scholar?cites=16254066070581027530&as_sdt=2005&sciodt=0,5&hl=en', 'cited_by_count': 52, 'pdf_file': 'https://www.jci.org/articles/view/96765'}]
# 2
# <div class="gs_ab_mdw">2 results (<b>0.02</b> sec)</div>
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN65_37.csv
# 33 N65/37
# <ipython-input-30-99cd006a2901>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN360A_24.csv
# 34 N360A/24
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN336B_83.csv
# 35 N336B/83
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN332B_15.csv
# 36 N332B/15
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL124_59.csv
# 37 L124/59
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN302_10.csv
# 38 N302/10
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN304B_115.csv
# 39 N304B/115
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN450_53.csv
# 40 N450/53
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN385_21.csv
# 41 N385/21
# []
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN393_2.csv
# 42 N393/2
# []
# We got booted, resetting vpn
# 32

# %%
new_index = run_code(32)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN76_3.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN76_3.csv already exists. Skipping query for N76/3.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN65_37.csv
# 33 N65/37
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN360A_24.csv
# 34 N360A/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN336B_83.csv
# 35 N336B/83
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN332B_15.csv
# 36 N332B/15
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL124_59.csv
# 37 L124/59
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN302_10.csv
# 38 N302/10
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN304B_115.csv
# 39 N304B/115
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN450_53.csv
# 40 N450/53
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN385_21.csv
# 41 N385/21
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN393_2.csv
# 42 N393/2
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN393_76.csv
# 43 N393/76
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN53_32.csv
# 44 N53/32
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN40B_18.csv
# 45 N40B/18
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL18A_3.csv
# 46 L18A/3
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN116_14.csv
# 47 N116/14
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN364_10.csv
# 48 N364/10
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN364_42.csv
# 49 N364/42
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN294A_6.csv
# 50 N294A/6
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN294A_10.csv
# 51 N294A/10
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL109_39.csv
# 52 L109/39
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL109_57.csv
# 53 L109/57
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL122_6.csv
# 54 L122/6
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL122_68.csv
# 55 L122/68
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK56A_50.csv
# 56 K56A/50
# 29
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK65_35.csv
# 57 K65/35
# 91
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK67_25.csv
# 58 K67/25
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL57_46.csv
# 59 L57/46
# 20
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN263_31.csv
# 60 N263/31
# 14
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL48A_9.csv
# 61 L48A/9
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN38_8.csv
# 62 N38/8
# 18
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN178A_9.csv
# 63 N178A/9
# 14
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN55_10.csv
# 64 N55/10
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN7_18.csv
# 65 N7/18
# 15
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN8B_1.csv
# 66 N8B/1
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN473_36.csv
# 67 N473/36
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN10_7.csv
# 68 N10/7
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabEA7.csv
# 69 EA7
# 1
# neuromab EA7 Problem with search
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN143_38.csv
# 70 N143/38
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN143_36.csv
# 71 N143/36
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN446_80.csv
# 72 N446/80
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN486_32.csv
# 73 N486/32
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN486_76.csv
# 74 N486/76
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN258_5.csv
# 75 N258/5
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN222_6.csv
# 76 N222/6
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN406_47.csv
# 77 N406/47
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN380_87.csv
# 78 N380/87
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN400_24.csv
# 79 N400/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL36_12.csv
# 80 L36/12
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL120_12.csv
# 81 L120/12
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL120_30.csv
# 82 L120/30
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK73_20.csv
# 83 K73/20
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL60_4.csv
# 84 L60/4
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL62_29.csv
# 85 L62/29
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK72_8.csv
# 86 K72/8
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN463_52.csv
# 87 N463/52
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN167_7.csv
# 88 N167/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL43_40.csv
# 89 L43/40
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN251_14.csv
# 90 N251/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN250_21.csv
# 91 N250/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabUNC 65.56.18.11.csv
# 92 UNC 65.56.18.11
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN117_9.csv
# 93 N117/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN150_21.csv
# 94 N150/21
# We got booted, resetting vpn
# 84

# %%
new_index = run_code(84)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL60_4.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL60_4.csv already exists. Skipping query for L60/4.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL62_29.csv
# 85 L62/29
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK72_8.csv
# 86 K72/8
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN463_52.csv
# 87 N463/52
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN167_7.csv
# 88 N167/7
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL43_40.csv
# 89 L43/40
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN251_14.csv
# 90 N251/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN250_21.csv
# 91 N250/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabUNC 65.56.18.11.csv
# 92 UNC 65.56.18.11
# 2
# neuromab UNC 65.56.18.11 Problem with search
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN117_9.csv
# 93 N117/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN150_21.csv
# 94 N150/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN186_29.csv
# 95 N186/29
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN331_19.csv
# 96 N331/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN420_24.csv
# 97 N420/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN92_14.csv
# 98 N92/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN94_17.csv
# 99 N94/17
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN91_27.csv
# 100 N91/27
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN225A_10.csv
# 101 N225A/10
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN56_21.csv
# 102 N56/21
# 12
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN202_7.csv
# 103 N202/7
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN353_13.csv
# 104 N353/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN349_96.csv
# 105 N349/96
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN359_28.csv
# 106 N359/28
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN191_7.csv
# 107 N191/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN95_35.csv
# 108 N95/35
# 41
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN399_19.csv
# 109 N399/19
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN398A_34.csv
# 110 N398A/34
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN415_24.csv
# 111 N415/24
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN229A_32.csv
# 112 N229A/32
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN96_55.csv
# 113 N96/55
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromab62-3G1.csv
# 114 62-3G1
# 13
# neuromab 62-3G1 Problem with search
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN87_25.csv
# 115 N87/25
# 11
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN151_3.csv
# 116 N151/3
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN413_67.csv
# 117 N413/67
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN452_69.csv
# 118 N452/69
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN452_73.csv
# 119 N452/73
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN452_30.csv
# 120 N452/30
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN431_64.csv
# 121 N431/64
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL123_109.csv
# 122 L123/109
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN93A_49.csv
# 123 N93A/49
# 20
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN81_2.csv
# 124 N81/2
# 9
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN81_37.csv
# 125 N81/37
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL127_12.csv
# 126 L127/12
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL127_8.csv
# 127 L127/8
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN144_17.csv
# 128 N144/17
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN148_30.csv
# 129 N148/30
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN174B_27.csv
# 130 N174B/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN193A_13.csv
# 131 N193A/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL106_83.csv
# 132 L106/83
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL106_93.csv
# 133 L106/93
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL106_4.csv
# 134 L106/4
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN206A_8.csv
# 135 N206A/8
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN206B_9.csv
# 136 N206B/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_8.csv
# 137 N86/8
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_38.csv
# 138 N86/38
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_20.csv
# 139 N86/20
# We got booted, resetting vpn
# 129

# %%
new_index = run_code(129)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN148_30.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN148_30.csv already exists. Skipping query for N148/30.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN174B_27.csv
# 130 N174B/27
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN193A_13.csv
# 131 N193A/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL106_83.csv
# 132 L106/83
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL106_93.csv
# 133 L106/93
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL106_4.csv
# 134 L106/4
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN206A_8.csv
# 135 N206A/8
# 41
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN206B_9.csv
# 136 N206B/9
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_8.csv
# 137 N86/8
# 101
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_38.csv
# 138 N86/38
# 54
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_20.csv
# 139 N86/20
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN86_44.csv
# 140 N86/44
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN39B_8.csv
# 141 N39B/8
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN83_48.csv
# 142 N83/48
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN355_1.csv
# 143 N355/1
# 33
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL21_32.csv
# 144 L21/32
# 74
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN279B_27.csv
# 145 N279B/27
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN308_48.csv
# 146 N308/48
# 31
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN327A_38.csv
# 147 N327A/38
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN327_95.csv
# 148 N327/95
# 23
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN59_20.csv
# 149 N59/20
# 39
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN59_36.csv
# 150 N59/36
# 66
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN422_18.csv
# 151 N422/18
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN416_40.csv
# 152 N416/40
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN424_45.csv
# 153 N424/45
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN424_48.csv
# 154 N424/48
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN142_28.csv
# 155 N142/28
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN192_12.csv
# 156 N192/12
# 10
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN100_13.csv
# 157 N100/13
# 12
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN128A_2.csv
# 158 N128A/2
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN70_28.csv
# 159 N70/28
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN71_37.csv
# 160 N71/37
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN141_28.csv
# 161 N141/28
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN114_10.csv
# 162 N114/10
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN310_21.csv
# 163 N310/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN299_39.csv
# 164 N299/39
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN158_28.csv
# 165 N158/28
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN307_12.csv
# 166 N307/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN293_50.csv
# 167 N293/50
# We got booted, resetting vpn
# 157

# %%
new_index = run_code(157)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN100_13.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN100_13.csv already exists. Skipping query for N100/13.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN128A_2.csv
# 158 N128A/2
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN70_28.csv
# 159 N70/28
# 32
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN71_37.csv
# 160 N71/37
# 13
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN141_28.csv
# 161 N141/28
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN114_10.csv
# 162 N114/10
# 20
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN310_21.csv
# 163 N310/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN299_39.csv
# 164 N299/39
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN158_28.csv
# 165 N158/28
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN307_12.csv
# 166 N307/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN293_50.csv
# 167 N293/50
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN123_19.csv
# 168 N123/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN123_48.csv
# 169 N123/48
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN309A_21.csv
# 170 N309A/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL113_27.csv
# 171 L113/27
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL113_13.csv
# 172 L113/13
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL113_130.csv
# 173 L113/130
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN451_73.csv
# 174 N451/73
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN201_35.csv
# 175 N201/35
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN171_17.csv
# 176 N171/17
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL24_18.csv
# 177 L24/18
# 18
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL117_1.csv
# 178 L117/1
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN135_37.csv
# 179 N135/37
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN154_32.csv
# 180 N154/32
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN1_66.csv
# 181 N1/66
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN1_12.csv
# 182 N1/12
# 32
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK55_7.csv
# 183 K55/7
# 12
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK60_73.csv
# 184 K60/73
# 13
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK66_38.csv
# 185 K66/38
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN423_75.csv
# 186 N423/75
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN3_26.csv
# 187 N3/26
# 15
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN11_33.csv
# 188 N11/33
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN2_16.csv
# 189 N2/16
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN132A_12.csv
# 190 N132A/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN112B_14.csv
# 191 N112B/14
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN124B_38.csv
# 192 N124B/38
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN25_35.csv
# 193 N25/35
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN465_11.csv
# 194 N465/11
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN455_15.csv
# 195 N455/15
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN366_60.csv
# 196 N366/60
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN363_71.csv
# 197 N363/71
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN321C_49.csv
# 198 N321C/49
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN320_48.csv
# 199 N320/48
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK20_78.csv
# 200 K20/78
# 39
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK36_15.csv
# 201 K36/15
# 38
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK14_16.csv
# 202 K14/16
# 30
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL76_36.csv
# 203 L76/36
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL23_27.csv
# 204 L23/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK13_31.csv
# 205 K13/31
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL71_5.csv
# 206 L71/5
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK7_45.csv
# 207 K7/45
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK19_36.csv
# 208 K19/36
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN471_27.csv
# 209 N471/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN447_24.csv
# 210 N447/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL83_11.csv
# 211 L83/11
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK89_34.csv
# 212 K89/34
# We got booted, resetting vpn
# 202

# %%
new_index = run_code(202)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK14_16.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK14_16.csv already exists. Skipping query for K14/16.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL76_36.csv
# 203 L76/36
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL23_27.csv
# 204 L23/27
# 23
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK13_31.csv
# 205 K13/31
# 34
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL71_5.csv
# 206 L71/5
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK7_45.csv
# 207 K7/45
# 10
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK19_36.csv
# 208 K19/36
# 11
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN471_27.csv
# 209 N471/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN447_24.csv
# 210 N447/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL83_11.csv
# 211 L83/11
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK89_34.csv
# 212 K89/34
# 97
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL80_21.csv
# 213 L80/21
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK39_25.csv
# 214 K39/25
# 12
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK37_89.csv
# 215 K37/89
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN372C_51.csv
# 216 N372C/51
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN372B_60.csv
# 217 N372B/60
# 9
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN372B_1.csv
# 218 N372B/1
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN16B_8.csv
# 219 N16B/8
# 14
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN410_17.csv
# 220 N410/17
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN375_67.csv
# 221 N375/67
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN72_16.csv
# 222 N72/16
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL28_4.csv
# 223 L28/4
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK57_1.csv
# 224 K57/1
# 37
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK75_41.csv
# 225 K75/41
# 34
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK75_30.csv
# 226 K75/30
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN474_27.csv
# 227 N474/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN458_10.csv
# 228 N458/10
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN37A_10.csv
# 229 N37A/10
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN26A_23.csv
# 230 N26A/23
# 16
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN43_6.csv
# 231 N43/6
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN448_88.csv
# 232 N448/88
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN448_50.csv
# 233 N448/50
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN461_19.csv
# 234 N461/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN460_19.csv
# 235 N460/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK9_40.csv
# 236 K9/40
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK47_42.csv
# 237 K47/42
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK17_70.csv
# 238 K17/70
# 16
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN84_37.csv
# 239 N84/37
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN165_38.csv
# 240 N165/38
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN283_7.csv
# 241 N283/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN228A_16.csv
# 242 N228A/16
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN164_6.csv
# 243 N164/6
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN207_27.csv
# 244 N207/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN341_37.csv
# 245 N341/37
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN341_12.csv
# 246 N341/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN241A_34.csv
# 247 N241A/34
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN231B_34.csv
# 248 N231B/34
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromab8G10.csv
# 249 8G10
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN138_6.csv
# 250 N138/6
# We got booted, resetting vpn
# 240

# %%
new_index = run_code(240)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN165_38.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN165_38.csv already exists. Skipping query for N165/38.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN283_7.csv
# 241 N283/7
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN228A_16.csv
# 242 N228A/16
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN164_6.csv
# 243 N164/6
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN207_27.csv
# 244 N207/27
# 12
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN341_37.csv
# 245 N341/37
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN341_12.csv
# 246 N341/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN241A_34.csv
# 247 N241A/34
# 93
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN231B_34.csv
# 248 N231B/34
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromab8G10.csv
# 249 8G10
# 3
# neuromab 8G10 Problem with search
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN138_6.csv
# 250 N138/6
# 26
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromab1D8.csv
# 251 1D8
# 1
# neuromab 1D8 Problem with search
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN209C_35.csv
# 252 N209C/35
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN205B_22.csv
# 253 N205B/22
# 10
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN129A_6.csv
# 254 N129A/6
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN129_15.csv
# 255 N129/15
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN85_18.csv
# 256 N85/18
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN128A_4.csv
# 257 N128A/4
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN377_20.csv
# 258 N377/20
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN377_83.csv
# 259 N377/83
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN227_21.csv
# 260 N227/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN88_12.csv
# 261 N88/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN382_14.csv
# 262 N382/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN382_69.csv
# 263 N382/69
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN90_20.csv
# 264 N90/20
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN75_3.csv
# 265 N75/3
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN75_33.csv
# 266 N75/33
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN384_63.csv
# 267 N384/63
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN472_88.csv
# 268 N472/88
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN111_24.csv
# 269 N111/24
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN153_5.csv
# 270 N153/5
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN230_21.csv
# 271 N230/21
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL51_82.csv
# 272 L51/82
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL94_54.csv
# 273 L94/54
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN52A_42.csv
# 274 N52A/42
# 41
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN119_44.csv
# 275 N119/44
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN185_7.csv
# 276 N185/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK74_71.csv
# 277 K74/71
# 30
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK69_3.csv
# 278 K69/3
# 39
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN255_38.csv
# 279 N255/38
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN397_19.csv
# 280 N397/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK87A_10.csv
# 281 K87A/10
# 40
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN68_6.csv
# 282 N68/6
# 15
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN134_12.csv
# 283 N134/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN405_74.csv
# 284 N405/74
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN395_68.csv
# 285 N395/68
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN396_29.csv
# 286 N396/29
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN168_6.csv
# 287 N168/6
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN414_25.csv
# 288 N414/25
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL129_93.csv
# 289 L129/93
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL129_96.csv
# 290 L129/96
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN126B_31.csv
# 291 N126B/31
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN120A_9.csv
# 292 N120A/9
# We got booted, resetting vpn
# 282

# %%
new_index = run_code(282)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN68_6.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN68_6.csv already exists. Skipping query for N68/6.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN134_12.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN134_12.csv already exists. Skipping query for N134/12.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN405_74.csv
# 284 N405/74
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN395_68.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN395_68.csv already exists. Skipping query for N395/68.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN396_29.csv
# 286 N396/29
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN168_6.csv
# 287 N168/6
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN414_25.csv
# 288 N414/25
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL129_93.csv
# 289 L129/93
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL129_96.csv
# 290 L129/96
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN126B_31.csv
# 291 N126B/31
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN120A_9.csv
# 292 N120A/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN170A_1.csv
# 293 N170A/1
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN170A_26.csv
# 294 N170A/26
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN97A_31.csv
# 295 N97A/31
# 22
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL107_39.csv
# 296 L107/39
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN110_29.csv
# 297 N110/29
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN98_47.csv
# 298 N98/47
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN98_7.csv
# 299 N98/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN49A_21.csv
# 300 N49A/21
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN50_36.csv
# 301 N50/36
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN51_6.csv
# 302 N51/6
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN161_20.csv
# 303 N161/20
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL121_25.csv
# 304 L121/25
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL121_42.csv
# 305 L121/42
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN253_32.csv
# 306 N253/32
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN408_62.csv
# 307 N408/62
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN408_79.csv
# 308 N408/79
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL115_13.csv
# 309 L115/13
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL119_106.csv
# 310 L119/106
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN343_26.csv
# 311 N343/26
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN312_10.csv
# 312 N312/10
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN348_82.csv
# 313 N348/82
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN166A_26.csv
# 314 N166A/26
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN149_25.csv
# 315 N149/25
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN388A_60.csv
# 316 N388A/60
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK96_7.csv
# 317 K96/7
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN235_22.csv
# 318 N235/22
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN144_32.csv
# 319 N144/32
# 11
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN159_5.csv
# 320 N159/5
# 16
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN145_20.csv
# 321 N145/20
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK55_82.csv
# 322 K55/82
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK40_17.csv
# 323 K40/17
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK25_73.csv
# 324 K25/73
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_86.csv
# 325 K28/86
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN419_40.csv
# 326 N419/40
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN419_78.csv
# 327 N419/78
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL11A_41.csv
# 328 L11A/41
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabA12_18.csv
# 329 A12/18
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN121A_1.csv
# 330 N121A/1
# We got booted, resetting vpn
# 320

# %%
new_index = run_code(320)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN159_5.csv
# 320 N159/5
# 16
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN145_20.csv
# 321 N145/20
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK55_82.csv
# 322 K55/82
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK40_17.csv
# 323 K40/17
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK25_73.csv
# 324 K25/73
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_86.csv
# 325 K28/86
# 37
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN419_40.csv
# 326 N419/40
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN419_78.csv
# 327 N419/78
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL11A_41.csv
# 328 L11A/41
# 20
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabA12_18.csv
# 329 A12/18
# 59
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN121A_1.csv
# 330 N121A/1
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN121A_31.csv
# 331 N121A/31
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN165_43.csv
# 332 N165/43
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN147_6.csv
# 333 N147/6
# 21
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN127_31.csv
# 334 N127/31
# 11
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN23B_49.csv
# 335 N23B/49
# 34
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL125_129.csv
# 336 L125/129
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN403_63.csv
# 337 N403/63
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN196_16.csv
# 338 N196/16
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL114_3.csv
# 339 L114/3
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL114_81.csv
# 340 L114/81
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN233_8.csv
# 341 N233/8
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN232_9.csv
# 342 N232/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN257_25.csv
# 343 N257/25
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN259_48.csv
# 344 N259/48
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN262_16.csv
# 345 N262/16
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN210_5.csv
# 346 N210/5
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL20_8.csv
# 347 L20/8
# 13
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN4_15.csv
# 348 N4/15
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN4_49.csv
# 349 N4/49
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN4_19.csv
# 350 N4/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN357_6.csv
# 351 N357/6
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN456_39.csv
# 352 N456/39
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN485_22.csv
# 353 N485/22
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN18_30.csv
# 354 N18/30
# 23
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN18_28.csv
# 355 N18/28
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_43.csv
# 356 K28/43
# 140
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_74.csv
# 357 K28/74
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN195A_16.csv
# 358 N195A/16
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN182_17.csv
# 359 N182/17
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN183_15.csv
# 360 N183/15
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN194_11.csv
# 361 N194/11
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN219_5.csv
# 362 N219/5
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN326D_13.csv
# 363 N326D/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN345_51.csv
# 364 N345/51
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN326D_29.csv
# 365 N326D/29
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN326D_2.csv
# 366 N326D/2
# We got booted, resetting vpn
# 356

# %%
new_index = run_code(356)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_43.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_43.csv already exists. Skipping query for K28/43.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK28_74.csv
# 357 K28/74
# 18
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN195A_16.csv
# 358 N195A/16
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN182_17.csv
# 359 N182/17
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN183_15.csv
# 360 N183/15
# 10
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN194_11.csv
# 361 N194/11
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN219_5.csv
# 362 N219/5
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN326D_13.csv
# 363 N326D/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN345_51.csv
# 364 N345/51
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN326D_29.csv
# 365 N326D/29
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN326D_2.csv
# 366 N326D/2
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN324_2.csv
# 367 N324/2
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN133_21.csv
# 368 N133/21
# 9
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN133_35.csv
# 369 N133/35
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN483_84.csv
# 370 N483/84
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN483_126.csv
# 371 N483/126
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN483_26.csv
# 372 N483/26
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN176A_35.csv
# 373 N176A/35
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN52B_27.csv
# 374 N52B/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN140A_12.csv
# 375 N140A/12
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN19_2.csv
# 376 N19/2
# 29
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK64_15.csv
# 377 K64/15
# 29
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN238_29.csv
# 378 N238/29
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN238_30.csv
# 379 N238/30
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN238_31.csv
# 380 N238/31
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN459_84.csv
# 381 N459/84
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL126_93.csv
# 382 L126/93
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL5_1.csv
# 383 L5/1
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK51_1.csv
# 384 K51/1
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN22_21.csv
# 385 N22/21
# 13
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN367_51.csv
# 386 N367/51
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN23B_6.csv
# 387 N23B/6
# 16
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN69_46.csv
# 388 N69/46
# 9
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN367_62.csv
# 389 N367/62
# 19
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK78_29.csv
# 390 K78/29
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL6_23.csv
# 391 L6/23
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL6_48.csv
# 392 L6/48
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL6_60.csv
# 393 L6/60
# 81
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL8_15.csv
# 394 L8/15
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN104_37.csv
# 395 N104/37
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN104_32.csv
# 396 N104/32
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL111_118.csv
# 397 L111/118
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN56_9.csv
# 398 N56/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN346_9.csv
# 399 N346/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN289_16.csv
# 400 N289/16
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN323A_31.csv
# 401 N323A/31
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN319A_14.csv
# 402 N319A/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN323B_20.csv
# 403 N323B/20
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN356_9.csv
# 404 N356/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN356_23.csv
# 405 N356/23
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL125_121.csv
# 406 L125/121
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN269_73.csv
# 407 N269/73
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN277_7.csv
# 408 N277/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN278_19.csv
# 409 N278/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN274_8.csv
# 410 N274/8
# We got booted, resetting vpn
# 400

# %%
new_index = run_code(400)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN289_16.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN289_16.csv already exists. Skipping query for N289/16.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN323A_31.csv
# 401 N323A/31
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN319A_14.csv
# 402 N319A/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN323B_20.csv
# 403 N323B/20
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN356_9.csv
# 404 N356/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN356_23.csv
# 405 N356/23
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL125_121.csv
# 406 L125/121
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN269_73.csv
# 407 N269/73
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN277_7.csv
# 408 N277/7
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN278_19.csv
# 409 N278/19
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN274_8.csv
# 410 N274/8
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN270_47.csv
# 411 N270/47
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN275_14.csv
# 412 N275/14
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN276A_15.csv
# 413 N276A/15
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL45_30.csv
# 414 L45/30
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN244_5.csv
# 415 N244/5
# 10
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL42_17.csv
# 416 L42/17
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN160_21.csv
# 417 N160/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL102_45.csv
# 418 L102/45
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN173B_13.csv
# 419 N173B/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN466_14.csv
# 420 N466/14
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN245_1.csv
# 421 N245/1
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN245_36.csv
# 422 N245/36
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN374_48.csv
# 423 N374/48
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN175_9.csv
# 424 N175/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN325B_65.csv
# 425 N325B/65
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN468_37.csv
# 426 N468/37
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN245_44.csv
# 427 N245/44
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN125_10.csv
# 428 N125/10
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN402_13.csv
# 429 N402/13
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN402_46.csv
# 430 N402/46
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL130_1.csv
# 431 L130/1
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL128_43.csv
# 432 L128/43
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN445_27.csv
# 433 N445/27
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN389_9.csv
# 434 N389/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN390_43.csv
# 435 N390/43
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN467_1.csv
# 436 N467/1
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN212_7.csv
# 437 N212/7
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN212_17.csv
# 438 N212/17
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN291C_22.csv
# 439 N291C/22
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN212A_34.csv
# 440 N212A/34
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN212_3.csv
# 441 N212/3
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromab1F1.csv
# 442 1F1
# 25
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN77_15.csv
# 443 N77/15
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN67_15.csv
# 444 N67/15
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN490_24.csv
# 445 N490/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN64A_36.csv
# 446 N64A/36
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL88_86.csv
# 447 L88/86
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN470_22.csv
# 448 N470/22
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN74_25.csv
# 449 N74/25
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN268_19.csv
# 450 N268/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN221_17.csv
# 451 N221/17
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN221_12.csv
# 452 N221/12
# We got booted, resetting vpn
# 442

# %%
new_index = run_code(442)
print(new_index)
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromab1F1.csv
# 442 1F1
# 25
# neuromab 1F1 Problem with search
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN77_15.csv
# 443 N77/15
# 7
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN67_15.csv
# 444 N67/15
# 14
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN490_24.csv
# 445 N490/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN64A_36.csv
# 446 N64A/36
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL88_86.csv
# 447 L88/86
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN470_22.csv
# 448 N470/22
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN74_25.csv
# 449 N74/25
# 8
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN268_19.csv
# 450 N268/19
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN221_17.csv
# 451 N221/17
# 12
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN221_12.csv
# 452 N221/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN15_4.csv
# 453 N15/4
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN15_39.csv
# 454 N15/39
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN469_28.csv
# 455 N469/28
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN155_9.csv
# 456 N155/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN6_38.csv
# 457 N6/38
# 6
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN425_45.csv
# 458 N425/45
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN479_12.csv
# 459 N479/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN479_22.csv
# 460 N479/22
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN479_107.csv
# 461 N479/107
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN152B_23.csv
# 462 N152B/23
# 10
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN351_23.csv
# 463 N351/23
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN351_24.csv
# 464 N351/24
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL118_80.csv
# 465 L118/80
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL118_66.csv
# 466 L118/66
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN28_9.csv
# 467 N28/9
# 63
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN29_29.csv
# 468 N29/29
# 15
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN34_34.csv
# 469 N34/34
# 5
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL108_92.csv
# 470 L108/92
# 1
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN440_21.csv
# 471 N440/21
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN440_61.csv
# 472 N440/61
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN449_73.csv
# 473 N449/73
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN432_21.csv
# 474 N432/21
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN432_63.csv
# 475 N432/63
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK91_36.csv
# 476 K91/36
# 4
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN391_68.csv
# 477 N391/68
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN428_12.csv
# 478 N428/12
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN286_74.csv
# 479 N286/74
# 2
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabK88_64.csv
# 480 K88/64
# 3
# <ipython-input-33-738d4b2e2e3a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN476_9.csv
# 481 N476/9
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN328B_37.csv
# 482 N328B/37
# None

# %% [markdown]
# # Add target column from neuromab database

# %%
data = requests.get("https://neuromab.ucdavis.edu/catalog-download.cfm").content
df = pd.read_csv(BytesIO(data))
df

# %% [markdown]
# # Merge all previous runs and the current run into one dataframe

# %%
# get data file names - replace with your path for what i send
import glob
import pandas as pd

path = r'/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
allnmab_df = pd.concat(dfs, ignore_index=True)

# %%
allnmab_df
# Out:
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 1     Caracterización de los canales de potasio depe...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 4     Distal dendritic enrichment of HCN1 channels i...
# ...                                                 ...
# 3783  Distinct but overlapping roles of LRRTM1 and L...
# 3784   Synaptic protein interaction networks encode ...
# 3785   Pannexin 2 protein expression is not restrict...
# 3786  The role of Pannexin 2 in mitochondrial functi...
# 3787  Pannexin 2 localizes at ER-mitochondria contac...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 1                https://idus.us.es/handle/11441/138533
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 4     https://www.eneuro.org/content/5/5/eneuro.0258...
# ...                                                 ...
# 3783           https://elifesciences.org/articles/64742
# 3784  https://www.cell.com/cell-reports/pdf/S2211-12...
# 3785  https://www.frontiersin.org/articles/10.3389/f...
# 3786  https://open.library.ubc.ca/soa/cIRcle/collect...
# 3787            https://www.mdpi.com/2072-6694/11/3/343
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 1                M Ortego Domínguez - 2022 - idus.us.es
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 4     M Meseke, F Neumüller, B Brunne, X Li, M Anstö...
# ...                                                 ...
# 3783  SH Dhume, SA Connor, F Mills, PK Tari… - Elife...
# 3784  JD Lautz, KB Tsegay, Z Zhu, EP Gniffke, JP Wel...
# 3785  M Le Vasseur, J Lelowski, JF Bechberger… - Fro...
# 3786          M Le Vasseur - 2016 - open.library.ubc.ca
# 3787  M Le Vasseur, VC Chen, K Huang, WA Vogl, CC Na...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 1     Los adipocitos blancos son células que partici...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 4     HCN1 compartmentalization in CA1 pyramidal cel...
# ...                                                 ...
# 3783  LRRTMs are postsynaptic cell adhesion proteins...
# 3784  A core network of widely expressed proteins wi...
# 3785  … by UC Davis/NIH NeuroMab Facility (Davis, CA...
# 3786  … Figure 2.1 Specificity of two novel anti–Pan...
# 3787  Endomembrane specialization allows functional ...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 1                                                   NaN             NaN
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            12.0
# 4     https://scholar.google.com/scholar?cites=50206...             8.0
# ...                                                 ...             ...
# 3783  https://scholar.google.com/scholar?cites=97818...             5.0
# 3784  https://scholar.google.com/scholar?cites=12974...             6.0
# 3785  https://scholar.google.com/scholar?cites=77804...            81.0
# 3786                                                NaN             NaN
# 3787  https://scholar.google.com/scholar?cites=79444...            18.0
#
#                                                pdf_file Antibody  \
# 0                                                   NaN  N37A/10
# 1     https://idus.us.es/bitstream/handle/11441/1385...  N375/67
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  N212/17
# 3     https://www.jbc.org/article/S0021-9258(20)3303...  N212/17
# 4     https://www.eneuro.org/content/eneuro/5/5/ENEU...  N212/17
# ...                                                 ...      ...
# 3783       https://elifesciences.org/articles/64742.pdf  N127/31
# 3784  https://www.cell.com/cell-reports/pdf/S2211-12...  N127/31
# 3785  https://www.frontiersin.org/articles/10.3389/f...  N121A/1
# 3786  https://open.library.ubc.ca/media/download/pdf...  N121A/1
# 3787        https://www.mdpi.com/2072-6694/11/3/343/htm  N121A/1
#
#                       Target
# 0     Kv7.1/KCNQ1 K+ channel
# 1           Kv3.3 K+ channel
# 2          TRIP8b (constant)
# 3          TRIP8b (constant)
# 4          TRIP8b (constant)
# ...                      ...
# 3783               Pan-SAPAP
# 3784               Pan-SAPAP
# 3785              Pannexin-2
# 3786              Pannexin-2
# 3787              Pannexin-2
#
# [3788 rows x 9 columns]

# %%
# get data file names - replace with your path for what i send
import glob
import pandas as pd

path = r'/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
allnmab_df2 = pd.concat(dfs, ignore_index=True)

# %%
allnmab_df2
# Out:
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 1     Caracterización de los canales de potasio depe...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 4     Distal dendritic enrichment of HCN1 channels i...
# ...                                                 ...
# 3483  Protein components of the backbone structure o...
# 3484  Protein components of the backbone structure o...
# 3485   Pannexin 2 protein expression is not restrict...
# 3486  The role of Pannexin 2 in mitochondrial functi...
# 3487  Pannexin 2 localizes at ER-mitochondria contac...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 1                https://idus.us.es/handle/11441/138533
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 4     https://www.eneuro.org/content/5/5/eneuro.0258...
# ...                                                 ...
# 3483  https://soar-ir.repo.nii.ac.jp/?action=reposit...
# 3484  https://soar-ir.repo.nii.ac.jp/?action=reposit...
# 3485  https://www.frontiersin.org/articles/10.3389/f...
# 3486  https://open.library.ubc.ca/soa/cIRcle/collect...
# 3487            https://www.mdpi.com/2072-6694/11/3/343
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 1                M Ortego Domínguez - 2022 - idus.us.es
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 4     M Meseke, F Neumüller, B Brunne, X Li, M Anstö...
# ...                                                 ...
# 3483                樋口京一， 竹下敏一 - soar-ir.repo.nii.ac.jp
# 3484                郭維恒 - 2017 - soar-ir.repo.nii.ac.jp
# 3485  M Le Vasseur, J Lelowski, JF Bechberger… - Fro...
# 3486          M Le Vasseur - 2016 - open.library.ubc.ca
# 3487  M Le Vasseur, VC Chen, K Huang, WA Vogl, CC Na...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 1     Los adipocitos blancos son células que partici...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 4     HCN1 compartmentalization in CA1 pyramidal cel...
# ...                                                 ...
# 3483  (論文の内容の要旨)[背景と目的] シナプス後肥厚部 (postsynaptic densi...
# 3484  (論文の内容の要旨)[背景と目的] シナプス後肥厚部 (postsynaptic densi...
# 3485  … by UC Davis/NIH NeuroMab Facility (Davis, CA...
# 3486  … Figure 2.1 Specificity of two novel anti–Pan...
# 3487  Endomembrane specialization allows functional ...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 1                                                   NaN             NaN
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            13.0
# 4     https://scholar.google.com/scholar?cites=50206...             9.0
# ...                                                 ...             ...
# 3483                                                NaN             NaN
# 3484                                                NaN             NaN
# 3485  https://scholar.google.com/scholar?cites=77804...            84.0
# 3486                                                NaN             NaN
# 3487  https://scholar.google.com/scholar?cites=79444...            21.0
#
#                                                pdf_file Antibody  \
# 0                                                   NaN  N37A/10
# 1     https://idus.us.es/bitstream/handle/11441/1385...  N375/67
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  N212/17
# 3     https://www.jbc.org/article/S0021-9258(20)3303...  N212/17
# 4     https://www.eneuro.org/content/eneuro/5/5/ENEU...  N212/17
# ...                                                 ...      ...
# 3483  https://soar-ir.repo.nii.ac.jp/?action=reposit...  N127/31
# 3484  https://soar-ir.repo.nii.ac.jp/record/19942/fi...  N127/31
# 3485  https://www.frontiersin.org/articles/10.3389/f...  N121A/1
# 3486  https://open.library.ubc.ca/media/download/pdf...  N121A/1
# 3487        https://www.mdpi.com/2072-6694/11/3/343/htm  N121A/1
#
#                       Target
# 0     Kv7.1/KCNQ1 K+ channel
# 1           Kv3.3 K+ channel
# 2          TRIP8b (constant)
# 3          TRIP8b (constant)
# 4          TRIP8b (constant)
# ...                      ...
# 3483               Pan-SAPAP
# 3484               Pan-SAPAP
# 3485              Pannexin-2
# 3486              Pannexin-2
# 3487              Pannexin-2
#
# [3488 rows x 9 columns]

# %%
# merge the dataframes and drop duplicates
df_all = pd.concat([allnmab_df, allnmab_df2])
df_all
# Out:
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 1     Caracterización de los canales de potasio depe...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 4     Distal dendritic enrichment of HCN1 channels i...
# ...                                                 ...
# 3483  Protein components of the backbone structure o...
# 3484  Protein components of the backbone structure o...
# 3485   Pannexin 2 protein expression is not restrict...
# 3486  The role of Pannexin 2 in mitochondrial functi...
# 3487  Pannexin 2 localizes at ER-mitochondria contac...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 1                https://idus.us.es/handle/11441/138533
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 4     https://www.eneuro.org/content/5/5/eneuro.0258...
# ...                                                 ...
# 3483  https://soar-ir.repo.nii.ac.jp/?action=reposit...
# 3484  https://soar-ir.repo.nii.ac.jp/?action=reposit...
# 3485  https://www.frontiersin.org/articles/10.3389/f...
# 3486  https://open.library.ubc.ca/soa/cIRcle/collect...
# 3487            https://www.mdpi.com/2072-6694/11/3/343
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 1                M Ortego Domínguez - 2022 - idus.us.es
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 4     M Meseke, F Neumüller, B Brunne, X Li, M Anstö...
# ...                                                 ...
# 3483                樋口京一， 竹下敏一 - soar-ir.repo.nii.ac.jp
# 3484                郭維恒 - 2017 - soar-ir.repo.nii.ac.jp
# 3485  M Le Vasseur, J Lelowski, JF Bechberger… - Fro...
# 3486          M Le Vasseur - 2016 - open.library.ubc.ca
# 3487  M Le Vasseur, VC Chen, K Huang, WA Vogl, CC Na...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 1     Los adipocitos blancos son células que partici...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 4     HCN1 compartmentalization in CA1 pyramidal cel...
# ...                                                 ...
# 3483  (論文の内容の要旨)[背景と目的] シナプス後肥厚部 (postsynaptic densi...
# 3484  (論文の内容の要旨)[背景と目的] シナプス後肥厚部 (postsynaptic densi...
# 3485  … by UC Davis/NIH NeuroMab Facility (Davis, CA...
# 3486  … Figure 2.1 Specificity of two novel anti–Pan...
# 3487  Endomembrane specialization allows functional ...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 1                                                   NaN             NaN
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            12.0
# 4     https://scholar.google.com/scholar?cites=50206...             8.0
# ...                                                 ...             ...
# 3483                                                NaN             NaN
# 3484                                                NaN             NaN
# 3485  https://scholar.google.com/scholar?cites=77804...            84.0
# 3486                                                NaN             NaN
# 3487  https://scholar.google.com/scholar?cites=79444...            21.0
#
#                                                pdf_file Antibody  \
# 0                                                   NaN  N37A/10
# 1     https://idus.us.es/bitstream/handle/11441/1385...  N375/67
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  N212/17
# 3     https://www.jbc.org/article/S0021-9258(20)3303...  N212/17
# 4     https://www.eneuro.org/content/eneuro/5/5/ENEU...  N212/17
# ...                                                 ...      ...
# 3483  https://soar-ir.repo.nii.ac.jp/?action=reposit...  N127/31
# 3484  https://soar-ir.repo.nii.ac.jp/record/19942/fi...  N127/31
# 3485  https://www.frontiersin.org/articles/10.3389/f...  N121A/1
# 3486  https://open.library.ubc.ca/media/download/pdf...  N121A/1
# 3487        https://www.mdpi.com/2072-6694/11/3/343/htm  N121A/1
#
#                       Target
# 0     Kv7.1/KCNQ1 K+ channel
# 1           Kv3.3 K+ channel
# 2          TRIP8b (constant)
# 3          TRIP8b (constant)
# 4          TRIP8b (constant)
# ...                      ...
# 3483               Pan-SAPAP
# 3484               Pan-SAPAP
# 3485              Pannexin-2
# 3486              Pannexin-2
# 3487              Pannexin-2
#
# [7276 rows x 9 columns]

# %%
# compare the unique aantiboies in the two dataframes
set1 = set(allnmab_df['Antibody'].unique()) - set(allnmab_df2['Antibody'].unique())

# %%
set2 = set(allnmab_df2['Antibody'].unique()) - set(allnmab_df['Antibody'].unique())

# %%
print(set1)
print(set2)
# Out:
# {'L124/59', 'N65/37', 'N336B/83', 'N332B/15'}
# {'L108/92', 'N390/43'}

# %%
# create a list of these two, subset the df and rerun the run_code after subsetting the df
run_code(0, df[df['Clone'].isin(list(set1) + list(set2))])
# Out:
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN65_37.csv
# 33 N65/37
# 1
# <ipython-input-64-bdc4d3e1a36a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN336B_83.csv
# 35 N336B/83
# 2
# <ipython-input-64-bdc4d3e1a36a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN332B_15.csv
# 36 N332B/15
# 4
# <ipython-input-64-bdc4d3e1a36a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL124_59.csv
# 37 L124/59
# 1
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN390_43.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabN390_43.csv already exists. Skipping query for N390/43.
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL108_92.csv
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/new_test2/neuromabL108_92.csv already exists. Skipping query for L108/92.
# <ipython-input-64-bdc4d3e1a36a>:191: FutureWarning: The default value of regex will change from True to False in a future version.
#   final_df['title'] = final_df['title'].str.replace('\[HTML\]\[HTML\]|\[PDF\]\[PDF\]|\[CITATION\]|\[C\]|\[BOOK\]\[BOOK\]|\[B\]|\[BOOK\]\[B\]', '')

# %%
# groupby the title of the paper and create a new column that merges the antibody names but keep all the other columns
df_filter = df_all.groupby('title').agg({'Antibody': lambda x: ', '.join(set(x)), 
                                         'Target': lambda x: ', '.join(set(x))}).reset_index()
# enforce thaat all strings in the Antibody column are unique as well and then merge back to the original df
df_final = df_all.merge(df_filter, on='title', how='left').drop_duplicates(subset=['title'])
# drop the Antibody_y column and rename Antibody_x to Antibody
df_final = df_final.drop(['Antibody_x'], axis=1)
# same for the target column
df_final = df_final.drop(['Target_x'], axis=1)
df_final = df_final.rename(columns={'Target_y': 'Target'})
df_final = df_final.rename(columns={'Antibody_y': 'Antibody'})
df_final
# Out:
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 1     Caracterización de los canales de potasio depe...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 4     Distal dendritic enrichment of HCN1 channels i...
# ...                                                 ...
# 6925  RUFY3 and RUFY4 are ARL8 effectors that promot...
# 6928  Reversible association with motor proteins (RA...
# 6991  Giant pyramidal neurons of the primary motor c...
# 7145   Differential Alteration in Expression of Stri...
# 7167   Complete loss of KCNA1 activity causes neonat...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 1                https://idus.us.es/handle/11441/138533
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 4     https://www.eneuro.org/content/5/5/eneuro.0258...
# ...                                                 ...
# 6925  https://www.nature.com/articles/s41467-022-289...
# 6928  https://journals.plos.org/plosbiology/article?...
# 6991  https://www.biorxiv.org/content/10.1101/2024.0...
# 7145  https://www.academia.edu/download/90605829/d09...
# 7167  https://jmg.bmj.com/content/jmedgenet/early/20...
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 1                M Ortego Domínguez - 2022 - idus.us.es
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 4     M Meseke, F Neumüller, B Brunne, X Li, M Anstö...
# ...                                                 ...
# 6925  T Keren-Kaplan, A Sarić, S Ghosh… - Nature …, ...
# 6928  CM Guardia, R De Pace, A Sen, A Saric, M Jarni...
# 6991  S Teymornejad, KH Worthy, MGP Rosa, N Atapour ...
# 7145  Z Du, M Tertrais, G Courtand, T Leste-Lasserre...
# 7167  E Verdura, C Fons, A Schlüter, M Ruiz… - Journ...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 1     Los adipocitos blancos son células que partici...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 4     HCN1 compartmentalization in CA1 pyramidal cel...
# ...                                                 ...
# 6925  The small GTPase ARL8 associates with endolyso...
# 6928  We report the development and characterization...
# 6991  Vasoactive intestinal polypeptide (VIP) is kno...
# 7145  Huntington’s disease (HD) is a neurodegenerati...
# 7167  … Cells transfected with p513- KCNA1 vectors w...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 1                                                   NaN             NaN
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            12.0
# 4     https://scholar.google.com/scholar?cites=50206...             8.0
# ...                                                 ...             ...
# 6925  https://scholar.google.com/scholar?cites=13157...            26.0
# 6928  https://scholar.google.com/scholar?cites=72248...            24.0
# 6991                                                NaN             NaN
# 7145                                                NaN             NaN
# 7167  https://scholar.google.com/scholar?cites=40106...            26.0
#
#                                                pdf_file  \
# 0                                                   NaN
# 1     https://idus.us.es/bitstream/handle/11441/1385...
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 4     https://www.eneuro.org/content/eneuro/5/5/ENEU...
# ...                                                 ...
# 6925  https://www.nature.com/articles/s41467-022-289...
# 6928  https://journals.plos.org/plosbiology/article/...
# 6991  https://www.biorxiv.org/content/10.1101/2024.0...
# 7145  https://www.academia.edu/download/90605829/d09...
# 7167  https://jmg.bmj.com/content/jmedgenet/early/20...
#
#                            Antibody  \
# 0                           N37A/10
# 1     L23/27, L71/5, N375/67, K57/1
# 2                           N212/17
# 3                           N212/17
# 4                           N212/17
# ...                             ...
# 6925                         A12/18
# 6928                         A12/18
# 6991                        L108/92
# 7145                         N87/25
# 7167                         K20/78
#
#                                                  Target
# 0                                Kv7.1/KCNQ1 K+ channel
# 1     Kv1.3 K+ channel, Kv4.2 K+ channel (external),...
# 2                                     TRIP8b (constant)
# 3                                     TRIP8b (constant)
# 4                                     TRIP8b (constant)
# ...                                                 ...
# 6925                    Pan-Neurofascin (extracellular)
# 6928                    Pan-Neurofascin (extracellular)
# 6991                                                VIP
# 7145                                    GABA(A)R, Beta3
# 7167                                   Kv1.1 K+ channel
#
# [2613 rows x 9 columns]

# %%
# output the final df to the picklequeries folder as googescholar_mabidsearch.csv
df_final.to_csv('/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/googescholar_mabidsearch.csv', index=False)

# %% [markdown]
# # Pubmed scraping get PMID for each of the papers

# %%
def add_Pubmed_info_to_dataframe(df, developer_mode, pos):
    # TODO wendon this function is a bit of a mess and could use some cleaning I 
        # i would just make sure it is working and make sure the "significance" checking is good.
        # then i would take a look at the "try" and "except" blocks and see if there is a better way to do it
        # might be a better way then just intermediary files but also a good way to cache and abstract - just dependent on the previous dataframe
        # solution could be reading in old outputs titles or something idk - just a thought surely something simple here
    '''
    Description : 
    
    This function uses the PubMed tool to generate the pubmed ID from the value in the Title 
    column of each row of the desired dataframe
    
    Input : 
    
    leftoff = from what row you would like to start adding information to 
    
    autosave = the number of iterations before being saved as csv
    
    df = the desired dataframe to add the information to 
    
    Returns : 
    
    a dataframe with the PMID, Author, Publication Date, and Journal columns appended
    
    '''

    # initialize the tool being used 
    pubmed = PubMed(tool="PubMedSearcher", email="gmail.com")

    # read in desired dataframe 
    #df = pd.read_csv(generate_path_to_merged_df())
    
    # Initialize columns values to be added to NaN
    if 'PMID' not in df:
        df['PMID'] = np.nan
    if 'Author' not in df:
        df['Author'] = np.nan
    if 'Publication Date' not in df:
        df['Publication Date'] = np.nan
    if 'Journal' not in df:
        df['Journal'] = np.nan

    # iterate over the df from the desginated row 
    for index, row in df[pos:].iterrows():
        try:
            if pd.isna(row['title']):    # if the value in Title is empty skip over it 
                continue

            if not pd.isna(row['PMID']): # if there is a value in the PMID column skip over it 
                continue

            search_term = row['title']
            max_results = 500
            results = pubmed.query(search_term, max_results=max_results)
            last_pubmedId = None  # Initialize to None

            # iterate through each of the paper titles in results, if the title is 80% similar to one of the 
            # articles - then that is the paper that we will grab information from 
            for article in results:
                title = article.title
                pubmedId = article.pubmed_id.partition('\n')[0]

                # Compare the similarity of the title and the search term
                similarity = fuzz.token_set_ratio(title.lower(), search_term.lower())
                if similarity >= 80:
                    last_pubmedId = pubmedId
                    break

            if last_pubmedId is not None:  # Only assign pubmed_id if a significant title is found
                print(row['title'],last_pubmedId)
                df.at[index, 'PMID'] = last_pubmedId   # assign the PMID to the row 
                df.at[index, 'Date'] = article.publication_date # assign the publication date to the row 

                # Create the Publication information from the first authors name and 
                # journal the paper is from 
                authors = article.authors
                # Extracting the first author's lastname
                first_author_lastname = authors[0]['lastname']

                # Creating the "et al" part
                et_al = "et al"

                # Creating the formatted string for publication info
                publication_info = f"{first_author_lastname} {et_al}. {article.journal}"
                df.at[index, 'Publication'] = publication_info
        
        except Exception as e:
            import traceback
            traceback.print_exc()
            print(e)
            df[pos:index].to_csv(f"/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/merged_df_{pos}-{index}.csv", index=False)
            return df, index

        # save the dataframe whenever there are 100 iterations - there is a possibility of being dropped
    
    # remove the 'unnamed' column from the df 
    # for col in runresultsdf.columns:
    #     if col.startswith("Unnamed"):
    #         runresultsdf = runresultsdf.drop(col, axis=1)
            
    # Delete duplicates in the PMID column 
    #df = df.drop_duplicates(subset='PMID', keep='first')
    
    df.to_csv(f"/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/merged_df_{pos}_{index}_done.csv", index=False)
    return df

# %%
pos = 3253
df_final = pd.read_csv('/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/googescholar_mabidsearch.csv')
while pos < len(df_final):
    print(pos)
    result = add_Pubmed_info_to_dataframe(df_final, False, pos)
    pos = result[1]

# %%
# read all the merged_df file sin the directory and concat them together
import glob
import pandas as pd

path = r'/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries'
filenames = glob.glob(path + "/merged_df_*.csv")
 
dfs = []
for file in filenames:
    dfs.append(pd.read_csv(file))

df_finaln = pd.concat(dfs, ignore_index=True)
# drop duplicaates based on the pubmed id, antibody and title
df_finaln = df_finaln.drop_duplicates(subset=['PMID', 'Antibody', 'title'])
df_finaln
# Out:
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 1     Caracterización de los canales de potasio depe...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 4     Distal dendritic enrichment of HCN1 channels i...
# ...                                                 ...
# 9769  RUFY3 and RUFY4 are ARL8 effectors that promot...
# 9770  Reversible association with motor proteins (RA...
# 9771  Giant pyramidal neurons of the primary motor c...
# 9772   Differential Alteration in Expression of Stri...
# 9773   Complete loss of KCNA1 activity causes neonat...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 1                https://idus.us.es/handle/11441/138533
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 4     https://www.eneuro.org/content/5/5/eneuro.0258...
# ...                                                 ...
# 9769  https://www.nature.com/articles/s41467-022-289...
# 9770  https://journals.plos.org/plosbiology/article?...
# 9771  https://www.biorxiv.org/content/10.1101/2024.0...
# 9772  https://www.academia.edu/download/90605829/d09...
# 9773  https://jmg.bmj.com/content/jmedgenet/early/20...
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 1                M Ortego Domínguez - 2022 - idus.us.es
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 4     M Meseke, F Neumüller, B Brunne, X Li, M Anstö...
# ...                                                 ...
# 9769  T Keren-Kaplan, A Sarić, S Ghosh… - Nature …, ...
# 9770  CM Guardia, R De Pace, A Sen, A Saric, M Jarni...
# 9771  S Teymornejad, KH Worthy, MGP Rosa, N Atapour ...
# 9772  Z Du, M Tertrais, G Courtand, T Leste-Lasserre...
# 9773  E Verdura, C Fons, A Schlüter, M Ruiz… - Journ...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 1     Los adipocitos blancos son células que partici...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 4     HCN1 compartmentalization in CA1 pyramidal cel...
# ...                                                 ...
# 9769  The small GTPase ARL8 associates with endolyso...
# 9770  We report the development and characterization...
# 9771  Vasoactive intestinal polypeptide (VIP) is kno...
# 9772  Huntington’s disease (HD) is a neurodegenerati...
# 9773  … Cells transfected with p513- KCNA1 vectors w...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 1                                                   NaN             NaN
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            12.0
# 4     https://scholar.google.com/scholar?cites=50206...             8.0
# ...                                                 ...             ...
# 9769  https://scholar.google.com/scholar?cites=13157...            26.0
# 9770  https://scholar.google.com/scholar?cites=72248...            24.0
# 9771                                                NaN             NaN
# 9772                                                NaN             NaN
# 9773  https://scholar.google.com/scholar?cites=40106...            26.0
#
#                                                pdf_file Antibody  \
# 0                                                   NaN  N37A/10
# 1     https://idus.us.es/bitstream/handle/11441/1385...  N375/67
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  N212/17
# 3     https://www.jbc.org/article/S0021-9258(20)3303...  N212/17
# 4     https://www.eneuro.org/content/eneuro/5/5/ENEU...  N212/17
# ...                                                 ...      ...
# 9769  https://www.nature.com/articles/s41467-022-289...   A12/18
# 9770  https://journals.plos.org/plosbiology/article/...   A12/18
# 9771  https://www.biorxiv.org/content/10.1101/2024.0...  L108/92
# 9772  https://www.academia.edu/download/90605829/d09...   N87/25
# 9773  https://jmg.bmj.com/content/jmedgenet/early/20...   K20/78
#
#                                Target        PMID  Author  Publication Date  \
# 0              Kv7.1/KCNQ1 K+ channel  22024150.0     NaN               NaN
# 1                    Kv3.3 K+ channel         NaN     NaN               NaN
# 2                   TRIP8b (constant)  29427087.0     NaN               NaN
# 3                   TRIP8b (constant)  28887304.0     NaN               NaN
# 4                   TRIP8b (constant)         NaN     NaN               NaN
# ...                               ...         ...     ...               ...
# 9769  Pan-Neurofascin (extracellular)         NaN     NaN               NaN
# 9770  Pan-Neurofascin (extracellular)         NaN     NaN               NaN
# 9771                              VIP         NaN     NaN               NaN
# 9772                  GABA(A)R, Beta3         NaN     NaN               NaN
# 9773                 Kv1.1 K+ channel         NaN     NaN               NaN
#
#       Journal        Date                                       Publication
# 0         NaN  2011-10-26                    Krzystanek et al. Heart rhythm
# 1         NaN         NaN                                               NaN
# 2         NaN  2018-02-11            Frigerio et al. Molecular neurobiology
# 3         NaN  2017-09-10  Lyman et al. The Journal of biological chemistry
# 4         NaN         NaN                                               NaN
# ...       ...         ...                                               ...
# 9769      NaN         NaN                                               NaN
# 9770      NaN         NaN                                               NaN
# 9771      NaN         NaN                                               NaN
# 9772      NaN         NaN                                               NaN
# 9773      NaN         NaN                                               NaN
#
# [4739 rows x 15 columns]

# %%
# filte to only things with a pubmed id
df_finaln = df_finaln[df_finaln['PMID'].notna()]
df_finaln
# Out:
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 5     The TRIP8b-HCN Interaction as a Therapeutic Ta...
# 6     A complex of Protocadherin-19 and N-cadherin m...
# ...                                                 ...
# 9402  Kv4 channels underlie A-currents with highly v...
# 9405  Expression, cellular and subcellular localisat...
# 9408   DPP6 localization in brain supports function ...
# 9415  Erbin interacts with TARP γ-2 for surface expr...
# 9432  Carbonic anhydrase-related protein CA10 is an ...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 5     https://search.proquest.com/openview/493f089f1...
# 6     https://rupress.org/jcb/article-abstract/195/7...
# ...                                                 ...
# 9402  https://link.springer.com/article/10.1007/s004...
# 9405            https://www.mdpi.com/1422-0067/20/2/246
# 9408  https://www.frontiersin.org/articles/10.3389/n...
# 9415            https://www.nature.com/articles/nn.3320
# 9432  https://www.pnas.org/doi/abs/10.1073/pnas.1621...
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 5                 KA Lyman - 2016 - search.proquest.com
# 6     MR Emond, S Biswas, CJ Blevins, JD Jontes - Jo...
# ...                                                 ...
# 9402  C Strube, L Saliba, E Moubarak, V Penalba… - …...
# 9405  R Alfaro-Ruíz, C Aguado, A Martín-Belmonte… - ...
# 9408  BD Clark, E Kwon, J Maffie, HY Jeong… - Fronti...
# 9415  Y Tao, YJ Chen, C Shen, Z Luo, CR Bates, D Lee...
# 9432  FH Sterky, JH Trotter, SJ Lee… - Proceedings o...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 5     Hyperpolarization-activated cyclic nucleotide-...
# 6     … N144/14; University of California Davis/Nati...
# ...                                                 ...
# 9402  … Immunodetections of K v 4.2 and K v 4.3 chan...
# 9405  … -S2 loop, Q9NZV8; NeuroMab, UC Davis/NIH, Da...
# 9408  … K75/41 Neuromab; www.neuromab.org were used ...
# 9415  Inhibitory neurons control the firing of gluta...
# 9432  Establishment, specification, and validation o...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            12.0
# 5                                                   NaN             NaN
# 6     https://scholar.google.com/scholar?cites=11570...           116.0
# ...                                                 ...             ...
# 9402  https://scholar.google.com/scholar?cites=66496...            15.0
# 9405  https://scholar.google.com/scholar?cites=84227...            23.0
# 9408  https://scholar.google.com/scholar?cites=15195...            81.0
# 9415  https://scholar.google.com/scholar?cites=11307...            51.0
# 9432  https://scholar.google.com/scholar?cites=17357...            91.0
#
#                                                pdf_file         Antibody  \
# 0                                                   NaN          N37A/10
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          N212/17
# 3     https://www.jbc.org/article/S0021-9258(20)3303...          N212/17
# 5                                                   NaN          N212/17
# 6      https://rupress.org/jcb/article/195/7/1115/50544          N144/14
# ...                                                 ...              ...
# 9402                                                NaN    K57/1, K75/41
# 9405        https://www.mdpi.com/1422-0067/20/2/246/htm    K57/1, K75/41
# 9408  https://www.frontiersin.org/articles/10.3389/n...    K57/1, K75/41
# 9415  https://www.researchgate.net/profile/Tian-Ming...  N245/36, N245/1
# 9432  https://www.pnas.org/doi/full/10.1073/pnas.162...   N95/35, N87/25
#
#                       Target        PMID  Author  Publication Date  Journal  \
# 0     Kv7.1/KCNQ1 K+ channel  22024150.0     NaN               NaN      NaN
# 2          TRIP8b (constant)  29427087.0     NaN               NaN      NaN
# 3          TRIP8b (constant)  28887304.0     NaN               NaN      NaN
# 5          TRIP8b (constant)  28127990.0     NaN               NaN      NaN
# 6                      6xHis  22184198.0     NaN               NaN      NaN
# ...                      ...         ...     ...               ...      ...
# 9402        Kv4.3 K+ channel  24872163.0     NaN               NaN      NaN
# 9405        Kv4.3 K+ channel  30634540.0     NaN               NaN      NaN
# 9408        Kv4.3 K+ channel  18978958.0     NaN               NaN      NaN
# 9415    TARPGamma2/Stargazin  23354328.0     NaN               NaN      NaN
# 9432        GABA(A)R, Alpha1  28320946.0     NaN               NaN      NaN
#
#             Date                                        Publication
# 0     2011-10-26                     Krzystanek et al. Heart rhythm
# 2     2018-02-11             Frigerio et al. Molecular neurobiology
# 3     2017-09-10   Lyman et al. The Journal of biological chemistry
# 5     2017-01-28  Lyman et al. Expert opinion on therapeutic tar...
# 6     2011-12-21           Emond et al. The Journal of cell biology
# ...          ...                                                ...
# 9402  2014-05-30  Strube et al. Pflugers Archiv : European journ...
# 9405  2019-01-13  Alfaro-Ruíz et al. International journal of mo...
# 9408  2008-11-04   Clark et al. Frontiers in molecular neuroscience
# 9415  2013-01-29                     Tao et al. Nature neuroscience
# 9432  2017-03-23                                                NaN
#
# [2983 rows x 15 columns]

# %%
# output that to a csv file
df_finaln.to_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/googlescholar_mabidsearch_pubmed.csv", index=False)

# %%
# run bag of words and plot a pca on the title
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# create a bag of words from the title column
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df_finaln['title'].values.astype('U'))
X = X.toarray()
X.shape

# pca and graph
pca = PCA(n_components=2)
pca.fit(X)
X_pca = pca.transform(X)
plt.figure(figsize=(10, 10))
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('PCA of Titles')
plt.show()
# what are the furthest outliers in the PCA coordinates and what are their titles
df_finaln['PCA1'] = X_pca[:, 0] 
df_finaln['PCA2'] = X_pca[:, 1]
df_finaln.sort_values(by=['PCA1'], ascending=False).head(10)
df_finaln
# Out:
# <ipython-input-4-eaab29a3b24f>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_finaln['PCA1'] = X_pca[:, 0]
# <ipython-input-4-eaab29a3b24f>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_finaln['PCA2'] = X_pca[:, 1]
#                                                   title  \
# 0     Deubiquitylating enzyme USP2 counteracts Nedd4...
# 2     Neuroinflammation alters integrative propertie...
# 3      Allostery between two binding sites in the io...
# 5     The TRIP8b-HCN Interaction as a Therapeutic Ta...
# 6     A complex of Protocadherin-19 and N-cadherin m...
# ...                                                 ...
# 9402  Kv4 channels underlie A-currents with highly v...
# 9405  Expression, cellular and subcellular localisat...
# 9408   DPP6 localization in brain supports function ...
# 9415  Erbin interacts with TARP γ-2 for surface expr...
# 9432  Carbonic anhydrase-related protein CA10 is an ...
#
#                                              title_link  \
# 0     https://www.sciencedirect.com/science/article/...
# 2     https://link.springer.com/article/10.1007/s120...
# 3     https://www.jbc.org/article/S0021-9258(20)3303...
# 5     https://search.proquest.com/openview/493f089f1...
# 6     https://rupress.org/jcb/article-abstract/195/7...
# ...                                                 ...
# 9402  https://link.springer.com/article/10.1007/s004...
# 9405            https://www.mdpi.com/1422-0067/20/2/246
# 9408  https://www.frontiersin.org/articles/10.3389/n...
# 9415            https://www.nature.com/articles/nn.3320
# 9432  https://www.pnas.org/doi/abs/10.1073/pnas.1621...
#
#                                        publication_info  \
# 0     K Krzystanek, HB Rasmussen, M Grunnet, O Staub...
# 2     F Frigerio, C Flynn, Y Han, K Lyman, JN Lugo… ...
# 3     KA Lyman, Y Han, RJ Heuermann, X Cheng… - Jour...
# 5                 KA Lyman - 2016 - search.proquest.com
# 6     MR Emond, S Biswas, CJ Blevins, JD Jontes - Jo...
# ...                                                 ...
# 9402  C Strube, L Saliba, E Moubarak, V Penalba… - …...
# 9405  R Alfaro-Ruíz, C Aguado, A Martín-Belmonte… - ...
# 9408  BD Clark, E Kwon, J Maffie, HY Jeong… - Fronti...
# 9415  Y Tao, YJ Chen, C Shen, Z Luo, CR Bates, D Lee...
# 9432  FH Sterky, JH Trotter, SJ Lee… - Proceedings o...
#
#                                                 snippet  \
# 0     BACKGROUND: KCNQ1 (Kv7.1), together with its K...
# 2     … , N212/17, Neuromab, CA, USA) antibodies usi...
# 3     Tetratricopeptide repeat (TPR) domains are ubi...
# 5     Hyperpolarization-activated cyclic nucleotide-...
# 6     … N144/14; University of California Davis/Nati...
# ...                                                 ...
# 9402  … Immunodetections of K v 4.2 and K v 4.3 chan...
# 9405  … -S2 loop, Q9NZV8; NeuroMab, UC Davis/NIH, Da...
# 9408  … K75/41 Neuromab; www.neuromab.org were used ...
# 9415  Inhibitory neurons control the firing of gluta...
# 9432  Establishment, specification, and validation o...
#
#                                           cited_by_link  cited_by_count  \
# 0     https://scholar.google.com/scholar?cites=98014...            35.0
# 2     https://scholar.google.com/scholar?cites=19097...            41.0
# 3     https://scholar.google.com/scholar?cites=14199...            12.0
# 5                                                   NaN             NaN
# 6     https://scholar.google.com/scholar?cites=11570...           116.0
# ...                                                 ...             ...
# 9402  https://scholar.google.com/scholar?cites=66496...            15.0
# 9405  https://scholar.google.com/scholar?cites=84227...            23.0
# 9408  https://scholar.google.com/scholar?cites=15195...            81.0
# 9415  https://scholar.google.com/scholar?cites=11307...            51.0
# 9432  https://scholar.google.com/scholar?cites=17357...            91.0
#
#                                                pdf_file         Antibody  \
# 0                                                   NaN          N37A/10
# 2     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          N212/17
# 3     https://www.jbc.org/article/S0021-9258(20)3303...          N212/17
# 5                                                   NaN          N212/17
# 6      https://rupress.org/jcb/article/195/7/1115/50544          N144/14
# ...                                                 ...              ...
# 9402                                                NaN    K57/1, K75/41
# 9405        https://www.mdpi.com/1422-0067/20/2/246/htm    K57/1, K75/41
# 9408  https://www.frontiersin.org/articles/10.3389/n...    K57/1, K75/41
# 9415  https://www.researchgate.net/profile/Tian-Ming...  N245/36, N245/1
# 9432  https://www.pnas.org/doi/full/10.1073/pnas.162...   N95/35, N87/25
#
#                       Target        PMID  Author  Publication Date  Journal  \
# 0     Kv7.1/KCNQ1 K+ channel  22024150.0     NaN               NaN      NaN
# 2          TRIP8b (constant)  29427087.0     NaN               NaN      NaN
# 3          TRIP8b (constant)  28887304.0     NaN               NaN      NaN
# 5          TRIP8b (constant)  28127990.0     NaN               NaN      NaN
# 6                      6xHis  22184198.0     NaN               NaN      NaN
# ...                      ...         ...     ...               ...      ...
# 9402        Kv4.3 K+ channel  24872163.0     NaN               NaN      NaN
# 9405        Kv4.3 K+ channel  30634540.0     NaN               NaN      NaN
# 9408        Kv4.3 K+ channel  18978958.0     NaN               NaN      NaN
# 9415    TARPGamma2/Stargazin  23354328.0     NaN               NaN      NaN
# 9432        GABA(A)R, Alpha1  28320946.0     NaN               NaN      NaN
#
#             Date                                        Publication      PCA1  \
# 0     2011-10-26                     Krzystanek et al. Heart rhythm -0.105540
# 2     2018-02-11             Frigerio et al. Molecular neurobiology -0.141250
# 3     2017-09-10   Lyman et al. The Journal of biological chemistry -0.073129
# 5     2017-01-28  Lyman et al. Expert opinion on therapeutic tar... -0.385829
# 6     2011-12-21           Emond et al. The Journal of cell biology  0.536929
# ...          ...                                                ...       ...
# 9402  2014-05-30  Strube et al. Pflugers Archiv : European journ... -0.051911
# 9405  2019-01-13  Alfaro-Ruíz et al. International journal of mo...  0.639838
# 9408  2008-11-04   Clark et al. Frontiers in molecular neuroscience -0.627647
# 9415  2013-01-29                     Tao et al. Nature neuroscience  0.097598
# 9432  2017-03-23                                                NaN -0.948991
#
#           PCA2
# 0    -0.766357
# 2    -0.731648
# 3     0.097325
# 5    -0.549128
# 6    -0.297365
# ...        ...
# 9402  0.173067
# 9405  1.487905
# 9408  0.036345
# 9415 -0.171020
# 9432 -0.689563
#
# [2983 rows x 17 columns]

# %% [markdown]
# # Scrape the antibodies Inc Pages for all the entities to check.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import re
import os

def scrape_matching_links(base_url, num_items, items_per_page, url_pattern, output_dir, conj):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    total_pages = (num_items // items_per_page) + (1 if num_items % items_per_page else 0)
    options = Options()
    options.headless = True
    browser = webdriver.Chrome(options=options)

    for page in range(1, total_pages + 1):
        output_file = f"{output_dir}/page_{page}_{conj}.csv"
        if os.path.exists(output_file):
            print(f"File {output_file} already exists. Skipping page {page}.")
            continue

        print(f"Processing page {page}...")
        url = f"{base_url}&page={page}"
        browser.get(url)
        html = browser.page_source

        if not html or "No results found" in html:
            print("Empty response or no results found. Terminating script.")
            browser.quit()
            return

        soup = BeautifulSoup(html, 'html.parser')
        links = [f"https://www.antibodiesinc.com{link['href']}" for link in soup.find_all('a', href=True) if url_pattern in link['href']]

        if not links:
            print("No links found on this page. Terminating script.")
            browser.quit()
            return

        df = pd.DataFrame(links, columns=['Link'])
        df.to_csv(output_file, index=False)
        print(f"Saved {output_file}")

    browser.quit()

# Modify these parameters according to your needs
#conj_list = ['490', 'Unconjugated', "550", "594", "650"]
conj_list = ['490', 'Unconjugated', "550", "594", "650"]

for conj in conj_list:
    base_url = f"https://www.antibodiesinc.com/search?refinementList%5Bvendor%5D%5B0%5D=NeuroMab&refinementList%5Bnamed_tags.conj%5D%5B0%5D={conj}"
    num_items = 1000
    items_per_page = 15
    url_pattern = "products"
    output_dir = "/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages/"

    scrape_matching_links(base_url, num_items, items_per_page, url_pattern, output_dir, conj)
# Out:
# <ipython-input-49-fa80db5e0aff>:21: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_1_490.csv already exists. Skipping page 1.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_2_490.csv already exists. Skipping page 2.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_3_490.csv already exists. Skipping page 3.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_4_490.csv already exists. Skipping page 4.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_5_490.csv already exists. Skipping page 5.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_6_490.csv already exists. Skipping page 6.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_7_490.csv already exists. Skipping page 7.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_8_490.csv already exists. Skipping page 8.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_9_490.csv already exists. Skipping page 9.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_10_490.csv already exists. Skipping page 10.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_11_490.csv already exists. Skipping page 11.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_12_490.csv already exists. Skipping page 12.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_13_490.csv already exists. Skipping page 13.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_14_490.csv already exists. Skipping page 14.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_15_490.csv already exists. Skipping page 15.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_16_490.csv already exists. Skipping page 16.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_17_490.csv already exists. Skipping page 17.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_18_490.csv already exists. Skipping page 18.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_19_490.csv already exists. Skipping page 19.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_20_490.csv already exists. Skipping page 20.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_21_490.csv already exists. Skipping page 21.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_22_490.csv already exists. Skipping page 22.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_23_490.csv already exists. Skipping page 23.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_24_490.csv already exists. Skipping page 24.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_25_490.csv already exists. Skipping page 25.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_26_490.csv already exists. Skipping page 26.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_27_490.csv already exists. Skipping page 27.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_28_490.csv already exists. Skipping page 28.
# Processing page 29...
# No links found on this page. Terminating script.
# <ipython-input-49-fa80db5e0aff>:21: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_1_Unconjugated.csv already exists. Skipping page 1.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_2_Unconjugated.csv already exists. Skipping page 2.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_3_Unconjugated.csv already exists. Skipping page 3.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_4_Unconjugated.csv already exists. Skipping page 4.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_5_Unconjugated.csv already exists. Skipping page 5.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_6_Unconjugated.csv already exists. Skipping page 6.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_7_Unconjugated.csv already exists. Skipping page 7.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_8_Unconjugated.csv already exists. Skipping page 8.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_9_Unconjugated.csv already exists. Skipping page 9.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_10_Unconjugated.csv already exists. Skipping page 10.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_11_Unconjugated.csv already exists. Skipping page 11.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_12_Unconjugated.csv already exists. Skipping page 12.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_13_Unconjugated.csv already exists. Skipping page 13.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_14_Unconjugated.csv already exists. Skipping page 14.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_15_Unconjugated.csv already exists. Skipping page 15.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_16_Unconjugated.csv already exists. Skipping page 16.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_17_Unconjugated.csv already exists. Skipping page 17.
# Processing page 18...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_18_Unconjugated.csv
# Processing page 19...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_19_Unconjugated.csv
# Processing page 20...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_20_Unconjugated.csv
# Processing page 21...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_21_Unconjugated.csv
# Processing page 22...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_22_Unconjugated.csv
# Processing page 23...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_23_Unconjugated.csv
# Processing page 24...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_24_Unconjugated.csv
# Processing page 25...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_25_Unconjugated.csv
# Processing page 26...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_26_Unconjugated.csv
# Processing page 27...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_27_Unconjugated.csv
# Processing page 28...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_28_Unconjugated.csv
# Processing page 29...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page

# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_9_650.csv already exists. Skipping page 9.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_10_650.csv already exists. Skipping page 10.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_11_650.csv already exists. Skipping page 11.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_12_650.csv already exists. Skipping page 12.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_13_650.csv already exists. Skipping page 13.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_14_650.csv already exists. Skipping page 14.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_15_650.csv already exists. Skipping page 15.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_16_650.csv already exists. Skipping page 16.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_17_650.csv already exists. Skipping page 17.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_18_650.csv already exists. Skipping page 18.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_19_650.csv already exists. Skipping page 19.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_20_650.csv already exists. Skipping page 20.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_21_650.csv already exists. Skipping page 21.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_22_650.csv already exists. Skipping page 22.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_23_650.csv already exists. Skipping page 23.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_24_650.csv already exists. Skipping page 24.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_25_650.csv already exists. Skipping page 25.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_26_650.csv already exists. Skipping page 26.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_27_650.csv already exists. Skipping page 27.
# File /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages//page_28_650.csv already exists. Skipping page 28.
# Processing page 29...
# No links found on this page. Terminating script.

# %%
# create a master dataframe of all the pmids so we can track the index
df = pd.DataFrame()
for file in glob.glob("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pages/*.csv"):
    dfi = pd.read_csv(file)
    df = df.append(dfi)
    df = df.reset_index(drop=True)
# output this file
df.to_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/antibodiesinc_master.csv", index=False)

# %% [markdown]
# # Now we need to get the citations from antibodies inc for each of these.

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import re
import os
import time
import random

def extract_pmids(urls, base_output_dir, start_index, overwrite):
    output_dir = os.path.join(base_output_dir, 'pmid_output')
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    options = Options()
    options.headless = True
    options.add_argument("window-size=1920x1080")

    user_agents = [
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
        # Add more user agents here
    ]

    browser = webdriver.Chrome(options=options)
    number_of_0s = 170
    number_of_0s_count = 0
    # start at the index provided 
    for index, url in enumerate(urls[start_index:]):
        print(f"Processing URL {url}...")
        # check if file already exists
        output_file = os.path.join(output_dir, f"{url.split('/')[-1]}.csv")
        if os.path.exists(output_file) and not overwrite:
            print(f"File {output_file} already exists. Skipping URL {url}.")
            continue

        # Rotate user agent
        user_agent = random.choice(user_agents)
        browser.execute_cdp_cmd('Network.setUserAgentOverride', {"userAgent": user_agent})
        browser.get(url)
        html = browser.page_source

        pmid_pattern = re.compile(r'https://pubmed.ncbi.nlm.nih.gov/\d+')
        pmid_patter2 = re.compile(r'https://www.ncbi.nlm.nih.gov/pubmed/\d+')
        pmids = pmid_pattern.findall(html)
        pmids += pmid_patter2.findall(html)
        # also grab the Citations count  and the number in the () following it from the html
        citations_pattern = re.compile(r'Citations \(\d+\)')
        citations = citations_pattern.findall(html)
        
        if len(citations) >= 1:
            print(citations, len(pmids))
            print(pmids)
            assert len(citations) == 1
            #assert len(pmids) == int(citations[0].split('(')[1].split(')')[0])
        # if not pmids:
        #     print(f"No PMIDs found for {url}. Skipping.")
        #     continue
        if len(pmids) == 0:
            number_of_0s_count += 1
            if number_of_0s_count >= number_of_0s:
                print(f"Too many 0s in a row, resetting vpn")
                return (index - number_of_0s) + start_index
        else:
            number_of_0s_count = 0
        pmid_data = {'URL': [], 'PMID': []}
        for pmid in pmids:
            pmid_data['URL'].append(url)
            pmid_data['PMID'].append(pmid)
        # make this long when updating the daatafraame
        df = pd.DataFrame(pmid_data)
        df.to_csv(output_file, index=False)

        print(f"Saved {output_file}")

        # Delay to prevent triggering anti-bot mechanisms
        time.sleep(random.uniform(5, 10))

    browser.quit()

# %%
# Read URLs from CSV
file = "/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-gaba-a-r-alpha5-antibody-n415-24-75-401.csv
# Processing URL https://www.antibodiesinc.com/products/anti-nckx4-antibody-n414-25-75-404...
# ['Citations (9)'] 9
# ['https://pubmed.ncbi.nlm.nih.gov/36814474', 'https://pubmed.ncbi.nlm.nih.gov/33199372', 'https://pubmed.ncbi.nlm.nih.gov/29209227', 'https://pubmed.ncbi.nlm.nih.gov/27752731', 'https://pubmed.ncbi.nlm.nih.gov/28650316', 'https://pubmed.ncbi.nlm.nih.gov/33199372', 'https://pubmed.ncbi.nlm.nih.gov/29209227', 'https://pubmed.ncbi.nlm.nih.gov/27752731', 'https://pubmed.ncbi.nlm.nih.gov/28650316']
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-nckx4-antibody-n414-25-75-404.csv
# Processing URL https://www.antibodiesinc.com/products/anti-gaba-a-r-epsilon-antibody-n413-67-75-398...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-gaba-a-r-epsilon-antibody-n413-67-75-398.csv
# Processing URL https://www.antibodiesinc.com/products/anti-kv3-2-potassium-channel-antibody-n410-17-75-397...
# ['Citations (1)'] 1
# ['https://pubmed.ncbi.nlm.nih.gov/34180393']
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-kv3-2-potassium-channel-antibody-n410-17-75-397.csv
# Processing URL https://www.antibodiesinc.com/products/anti-bkbeta3a-k-channel-antibody-n40b-18-75-098...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-bkbeta3a-k-channel-antibody-n40b-18-75-098.csv
# Processing URL https://www.antibodiesinc.com/products/anti-arx-antibody-n411-51-75-402...
# ['Citations (1)'] 1
# ['https://pubmed.ncbi.nlm.nih.gov/32033960']
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-arx-antibody-n411-51-75-402.csv
# Processing URL https://www.antibodiesinc.com/products/anti-clcn5-antibody-n406-47-75-400...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-clcn5-antibody-n406-47-75-400.csv
# Processing URL https://www.antibodiesinc.com/products/anti-thyroid-hormone-receptor-beta1-antibody-n402-46-75-387...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-thyroid-hormone-receptor-beta1-antibody-n402-46-75-387.csv
# Processing URL https://www.antibodiesinc.com/products/anti-navbeta1-na-channel-antibody-n405-74-75-425...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-navbeta1-na-channel-antibody-n405-74-75-425.csv
# Processing URL https://www.antibodiesinc.com/products/anti-pink1-pten-induced-putative-kinase-1-antibody-n4-49-75-061...
# Saved /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/anti-pink1-pten-induced-putative-kinase-1-antibody-n4-49-75-061.csv
# None

# %% [markdown]
# # Create the master Antibodies inc dataframe

# %%
# create a master dataframe of the outputs from the code aboe
dfantiinc = pd.DataFrame()
for file in glob.glob("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinclinks/pmid_output/*.csv"):
    dfi = pd.read_csv(file)
    dfantiinc = dfantiinc.append(dfi)
    dfantiinc = dfantiinc.reset_index(drop=True)
    
for index, row in dfantiinc.iterrows():
    # look for -f with a number after it with regex
    dfantiinc.at[index, 'MABID1'] = row["URL"].split('-')[-4]
    dfantiinc.at[index, 'MABID2'] = row["URL"].split('-')[-3]
    dfantiinc.at[index, 'ANTIBODYINC1'] = row["URL"].split('-')[-2]
    dfantiinc.at[index, 'ANTIBODYINC2'] = row["URL"].split('-')[-1]
    dfantiinc.at[index, 'CONJUGATE'] = None
    # creaate a list column splitting on the last 5 objects of the url
dfantiinc['URLsplit'] = dfantiinc['URL'].str.split('-').str[-5:]
dfantiinc
# Out:
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# ...
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)
# <ipython-input-208-bc9d235d654d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfantiinc = dfantiinc.append(dfi)

# %%
# filter to where antibody is the MABID1 value or the MABID2 value
# print where antibody is not contained in the list
# fitler for ANTIBODYINC2 is null/na
print(len(dfantiinc[dfantiinc['ANTIBODYINC1'].isna()]))
print(len(dfantiinc[dfantiinc['ANTIBODYINC2'].isna()]))
print(len(dfantiinc[dfantiinc['MABID1'].isna()]))
print(len(dfantiinc[dfantiinc['MABID2'].isna()]))
# Out:
# 0
# 0
# 0
# 0

# %%
# create column antibody inc id that joins the antibodyinc1 and antibodyinc2 columns by -
dfantiinc['ANTIBODYINC_ID'] = dfantiinc['ANTIBODYINC1'] + '-' + dfantiinc['ANTIBODYINC2']
# same for MABID but make all caps and split on /
dfantiinc['MABID'] = dfantiinc['MABID1'].str.upper() + '/' + dfantiinc['MABID2'].str.upper()
# extract the column pmid_id from the url column
dfantiinc['PMID_ID'] = dfantiinc['PMID'].str.split('/').str[-1]
# remove duplicates again
# do a groupby and add the antibody ids together in a list and the mabids 
# join the list with a comma
dfantiinc = dfantiinc.groupby('PMID_ID').agg({'ANTIBODYINC_ID': lambda x: ', '.join(set(x)), 
                                         'MABID': lambda x: ', '.join(set(x))}).reset_index()

dfantiinc
# Out:
#                                                     URL  \
# 0     https://www.antibodiesinc.com/products/anti-ne...
# 1     https://www.antibodiesinc.com/products/anti-ne...
# 2     https://www.antibodiesinc.com/products/anti-ne...
# 3     https://www.antibodiesinc.com/products/anti-kv...
# 4     https://www.antibodiesinc.com/products/anti-kv...
# ...                                                 ...
# 5293  https://www.antibodiesinc.com/products/anti-ca...
# 5294  https://www.antibodiesinc.com/products/anti-ca...
# 5295  https://www.antibodiesinc.com/products/anti-ca...
# 5296  https://www.antibodiesinc.com/products/anti-lr...
# 5297  https://www.antibodiesinc.com/products/anti-sy...
#
#                                               PMID MABID1 MABID2 ANTIBODYINC1  \
# 0     https://www.ncbi.nlm.nih.gov/pubmed/25429153  n126b     31           75
# 1     https://www.ncbi.nlm.nih.gov/pubmed/24229388  n126b     31           75
# 2     https://www.ncbi.nlm.nih.gov/pubmed/22249266  n126b     31           75
# 3         https://pubmed.ncbi.nlm.nih.gov/28115470    k19     36           75
# 4         https://pubmed.ncbi.nlm.nih.gov/27872049    k19     36           75
# ...                                            ...    ...    ...          ...
# 5293      https://pubmed.ncbi.nlm.nih.gov/24703904   n263     31           75
# 5294      https://pubmed.ncbi.nlm.nih.gov/23858011   n263     31           75
# 5295      https://pubmed.ncbi.nlm.nih.gov/23568894   n263     31           75
# 5296  https://www.ncbi.nlm.nih.gov/pubmed/25981034  n209c     35           75
# 5297  https://www.ncbi.nlm.nih.gov/pubmed/25155179   n277      7           75
#
#      ANTIBODYINC2  CONJUGATE                        URLsplit ANTIBODYINC_ID  \
# 0             226        NaN  [antibody, n126b, 31, 75, 226]         75-226
# 1             226        NaN  [antibody, n126b, 31, 75, 226]         75-226
# 2             226        NaN  [antibody, n126b, 31, 75, 226]         75-226
# 3             012        NaN    [antibody, k19, 36, 75, 012]         75-012
# 4             012        NaN    [antibody, k19, 36, 75, 012]         75-012
# ...           ...        ...                             ...            ...
# 5293          257        NaN   [antibody, n263, 31, 75, 257]         75-257
# 5294          257        NaN   [antibody, n263, 31, 75, 257]         75-257
# 5295          257        NaN   [antibody, n263, 31, 75, 257]         75-257
# 5296          364        NaN  [antibody, n209c, 35, 75, 364]         75-364
# 5297          304        NaN    [antibody, n277, 7, 75, 304]         75-304
#
#          MABID
# 0     N126B/31
# 1     N126B/31
# 2     N126B/31
# 3       K19/36
# 4       K19/36
# ...        ...
# 5293   N263/31
# 5294   N263/31
# 5295   N263/31
# 5296  N209C/35
# 5297    N277/7
#
# [5298 rows x 10 columns]

# %%
# output the antibodies INC final 
dfantiinc.to_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinc_final.csv", index=False)

# %% [markdown]
# # Add pubmed info to a dataframe

# %%
from Bio import Entrez
import json

def fetch_details(pubmed_id):
    file_path = f"/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/pmidjsons/{pubmed_id}.json"
    try:
        # check if we dont have the file already and if we do just return the citation
        if os.path.exists(file_path):
            with open(file_path, 'r') as f:
                record = json.load(f)
        else:    
            Entrez.email = "kgmitchell@ucdavis.edu"  # Always provide your email
            handle = Entrez.efetch(db="pubmed", id=pubmed_id, retmode="xml")
            records = Entrez.read(handle)
            record = records
            if not records or 'PubmedArticle' not in records:
                print(f"PubMed returned no data for {pubmed_id}.")
                return None
            record = records
            with open(file_path, 'w') as f:
                json.dump(record, f)

        article = record['PubmedArticle'][0]
        article_data = article['MedlineCitation']['Article']
        authors = article_data['AuthorList']
        # update this to only return first 3 authors and et al if more than 3 or just 3 authors if 3 or less
        if len(authors) > 3:
            author_names = ', '.join([f"{a['LastName']} {a['Initials']}" for a in authors[:3]]) + ' et al.'
        else:
            author_names = ', '.join([f"{a['LastName']} {a['Initials']}" for a in authors])
        title = article_data['ArticleTitle']
        journal = article_data['Journal']['Title']
        year = article_data['Journal']['JournalIssue']['PubDate']['Year']

        # check if the pagination exists otherwise dont include it
        if 'Pagination' in article_data:
            pages = article_data['Pagination']['MedlinePgn']
        else:
            print(f"PubMed returned no pagination data for {pubmed_id}.")
            pages = ''
        
        # do the same check for the volume
        if 'Volume' in article_data['Journal']['JournalIssue']:
            volume = article_data['Journal']['JournalIssue']['Volume']
        else:
            print(f"PubMed returned no volume data for {pubmed_id}.")
            volume = ''

        if pages and volume:
            citation = f"{author_names}. {year}. {journal}. {volume}:{pages}."
        elif pages:
            citation = f"{author_names}. {year}. {journal}. {pages}."
        elif volume:
            citation = f"{author_names}. {year}. {journal}. {volume}."
        else:
            citation = f"{author_names}. {year}. {journal}."

        # create a dictionary with the citation and title and yeaar
        result = {'citation': citation, 'title': title, 'year': year}

        # also output all of the data as a json here /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/pmidjsons
        with open(file_path, 'w') as f:
            json.dump(record, f)
        return result
    except Exception as e:
        print(f"Error fetching data from PubMed for {pubmed_id}.")
        print(e)
        return e

# %% [markdown]
# ## Run the antibodies inc dataa

# %%
dfantiinc = pd.read_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinc_final.csv")
# get all the pmids from the PMID column
pubmed_ids = dfantiinc['PMID_ID'].tolist()
for pid in pubmed_ids:
    record = fetch_details(pid)
    if record:
        continue
    else:
        print(f"For {pid}, no record was found.")
        break

# %% [markdown]
# ## Run the google scholar mab id search data

# %%
# run the df_final which is from the google scholar search with mabid
df_final = pd.read_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/googlescholar_mabidsearch_pubmed.csv")
# get all the pmids from the PMID column
# first convert the file to an int and then string
df_final['PMID'] = df_final['PMID'].astype(int).astype(str)
pubmed_ids = df_final['PMID'].tolist()
for pid in pubmed_ids:
    record = fetch_details(pid)
    if record:
        continue
    else:
        print(f"For {pid}, no record was found.")
        break
# Out:
# Error fetching data from PubMed for 37333277.
# 'Volume'
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 32052742.
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 35550246.
# Error fetching data from PubMed for 37333281.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 27525480.
# PubMed returned no pagination data for 31434643.
# PubMed returned no pagination data for 29168692.
# PubMed returned no pagination data for 25918844.
# PubMed returned no pagination data for 36982541.
# PubMed returned no pagination data for 35806143.
# PubMed returned no pagination data for 31934864.
# PubMed returned no pagination data for 34132778.
# PubMed returned no pagination data for 34658337.
# PubMed returned no pagination data for 32129762.
# Error fetching data from PubMed for 28448009.
# 'Volume'
# PubMed returned no pagination data for 32840212.
# PubMed returned no pagination data for 30131441.
# PubMed returned no pagination data for 33650969.
# Error fetching data from PubMed for 37577625.
# 'Volume'
# PubMed returned no pagination data for 31964774.
# PubMed returned no pagination data for 31934864.
# PubMed returned no pagination data for 30377171.
# PubMed returned no pagination data for 29592971.
# PubMed returned no pagination data for 32435793.
# PubMed returned no pagination data for 31391239.
# PubMed returned no pagination data for 36656118.
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 32052742.
# PubMed returned no pagination data for 34180393.
# PubMed returned no pagination data for 35022233.
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 37756587.
# PubMed returned no pagination data for 31164339.
# PubMed returned no pagination data for 30545844.
# PubMed returned no pagination data for 36830639.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 33333928.
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 28119464.
# Error fetching data from PubMed for 37502980.
# 'Volume'
# PubMed returned no pagination data for 34137443.
# PubMed returned no pagination data for 32937450.
# PubMed returned no pagination data for 28856240.
# Error fetching data from PubMed for 37502980.
# 'Volume'
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 34131060.
# PubMed returned no pagination data for 37108794.
# PubMed returned no pagination data for 32202499.
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 37190086.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 36672216.
# Error fetching data from PubMed for 32202516.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 26883496.
# PubMed returned no pagination data for 36833753.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 33837049.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 33689678.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 33593893.
# PubMed returned no pagination data for 34261657.
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 34156984.
# PubMed returned no pagination data for 34261648.
# PubMed returned no pagination data for 33689679.
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 28584877.
# PubMed returned no pagination data for 31036155.
# PubMed returned no pagination data for 31036155.
# PubMed returned no pagination data for 31910261.
# Error fetching data from PubMed for 37333277.
# 'Volume'
# Error fetching data from PubMed for 36945454.
# 'Volume'
# PubMed returned no pagination data for 31727776.
# PubMed returned no pagination data for 37288813.
# PubMed returned no pagination data for 32052742.
# PubMed returned no pagination data for 28134616.
# PubMed returned no pagination data for 29138759.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 31910261.
# Error fetching data from PubMed for 36482968.
# 'Volume'
# PubMed returned no pagination data for 36795458.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 30302388.
# PubMed returned no pagination data for 33229412.
# Error fetching data from PubMed for 37693426.
# 'Volume'
# PubMed returned no pagination data for 33229412.
# Error fetching data from PubMed for 31816021.
# 'AuthorList'
# PubMed returned no pagination data for 32024240.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 29726811.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 34137443.
# PubMed returned no pagination data for 30974833.
# PubMed returned no pagination data for 33443209.
# Error fetching data from PubMed for 37425946.
# 'Volume'
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 28856240.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 34180393.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 33229412.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 30946007.
# PubMed returned no pagination data for 29173281.
# PubMed returned no pagination data for 33006315.
# Error fetching data from PubMed for 37693426.
# 'Volume'
# PubMed returned no pagination data for 37516919.
# PubMed returned no pagination data for 31658977.
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 26186538.
# 'LastName'
# PubMed returned no pagination data for 32202499.
# PubMed returned no pagination data for 32425157.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 31045576.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 35625761.
# PubMed returned no pagination data for 34429357.
# PubMed returned no pagination data for 35972069.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 29028184.
# PubMed returned no pagination data for 27935475.
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 35972069.
# PubMed returned no pagination data for 32311044.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 29138759.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 27091544.
# PubMed returned no pagination data for 26559620.
# PubMed returned no pagination data for 36173683.
# Error fetching data from PubMed for 36824888.
# 'Volume'
# PubMed returned no pagination data for 37516919.
# PubMed returned no pagination data for 36292621.
# PubMed returned no pagination data for 36951953.
# PubMed returned no pagination data for 32659913.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 36077460.
# PubMed returned no pagination data for 35441593.
# PubMed returned no pagination data for 36552754.
# PubMed returned no pagination data for 32425157.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 33188005.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 30946007.
# PubMed returned no pagination data for 26665164.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 37048156.
# PubMed returned no pagination data for 36697254.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 33689679.
# PubMed returned no pagination data for 33801205.
# PubMed returned no pagination data for 31727776.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 29671737.
# PubMed returned no pagination data for 33361086.
# PubMed returned no pagination data for 33361086.
# PubMed returned no pagination data for 34665127.
# PubMed returned no pagination data for 31609202.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 33801205.
# PubMed returned no pagination data for 31331967.
# PubMed returned no pagination data for 27091544.
# PubMed returned no pagination data for 26559620.
# PubMed returned no pagination data for 28660246.
# PubMed returned no pagination data for 28130923.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 33472865.
# PubMed returned no pagination data for 32570968.
# PubMed returned no pagination data for 29138759.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 28470148.
# PubMed returned no pagination data for 36302632.
# PubMed returned no pagination data for 31936259.
# PubMed returned no pagination data for 34180393.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 23894271.
# PubMed returned no pagination data for 32410728.
# Error fetching data from PubMed for 26381166.
# 'Volume'
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 29361569.
# PubMed returned no pagination data for 30398148.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 27083044.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 36612049.
# PubMed returned no pagination data for 36612049.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 32311044.
# PubMed returned no pagination data for 33837049.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 28660246.
# Error fetching data from PubMed for 31107446.
# 'Volume'
# Error fetching data from PubMed for 30451222.
# 'Volume'
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 36149401.
# PubMed returned no pagination data for 35326469.
# PubMed returned no pagination data for 34114604.
# PubMed returned no pagination data for 35269482.
# PubMed returned no pagination data for 30647193.
# PubMed returned no pagination data for 35326469.
# PubMed returned no pagination data for 35266954.
# PubMed returned no pagination data for 33568460.
# PubMed returned no pagination data for 33229412.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 33113832.
# Error fetching data from PubMed for 33191931.
# 'Volume'
# PubMed returned no pagination data for 33373328.
# PubMed returned no pagination data for 33689678.
# PubMed returned no pagination data for 34417170.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 34135003.
# PubMed returned no pagination data for 34452921.
# PubMed returned no pagination data for 29726811.
# PubMed returned no pagination data for 34658338.
# Error fetching data from PubMed for 37425856.
# 'Volume'
# PubMed returned no pagination data for 32024240.
# Error fetching data from PubMed for 37693426.
# 'Volume'
# PubMed returned no pagination data for 31663850.
# Error fetching data from PubMed for 35759110.
# 'Volume'
# PubMed returned no pagination data for 28955722.
# PubMed returned no pagination data for 34431981.
# PubMed returned no pagination data for 36077460.
# PubMed returned no pagination data for 32899153.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 30634540.
# PubMed returned no pagination data for 32899153.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 35098924.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 32202499.
# PubMed returned no pagination data for 37108794.
# Error fetching data from PubMed for 28320946.
# 'AuthorList'
# PubMed returned no pagination data for 35420982.
# PubMed returned no pagination data for 34180393.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 28650316.
# PubMed returned no pagination data for 34135003.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 37108794.
# PubMed returned no pagination data for 34759048.
# PubMed returned no pagination data for 34315807.
# PubMed returned no pagination data for 34431981.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 36729040.
# PubMed returned no pagination data for 31727776.
# PubMed returned no pagination data for 34766907.
# PubMed returned no pagination data for 30538170.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 26665164.
# PubMed returned no pagination data for 34137443.
# PubMed returned no pagination data for 32202499.
# PubMed returned no pagination data for 37759527.
# PubMed returned no pagination data for 31403402.
# PubMed returned no pagination data for 28119464.
# PubMed returned no pagination data for 34431981.
# PubMed returned no pagination data for 31663850.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 36612049.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 31403402.
# PubMed returned no pagination data for 32205379.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 31816021.
# 'AuthorList'
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 29464191.
# PubMed returned no pagination data for 30396997.
# PubMed returned no pagination data for 26665164.
# PubMed returned no pagination data for 34063992.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 33188005.
# PubMed returned no pagination data for 31663850.
# PubMed returned no pagination data for 32675279.
# PubMed returned no pagination data for 32675279.
# PubMed returned no pagination data for 31910261.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 28134616.
# PubMed returned no pagination data for 37408217.
# PubMed returned no pagination data for 31142543.
# PubMed returned no pagination data for 33689679.
# Error fetching data from PubMed for 37333277.
# 'Volume'
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 33229412.
# Error fetching data from PubMed for 28320946.
# 'AuthorList'
# PubMed returned no pagination data for 31658977.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 29726811.
# PubMed returned no pagination data for 33689679.
# PubMed returned no pagination data for 37759527.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 32899153.
# PubMed returned no pagination data for 30634540.
# PubMed returned no pagination data for 26665164.
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 30862038.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# PubMed returned no pagination data for 28119464.
# PubMed returned no pagination data for 34137443.
# PubMed returned no pagination data for 28856240.
# Error fetching data from PubMed for 38187582.
# 'Volume'
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 37108794.
# PubMed returned no pagination data for 32202499.
# PubMed returned no pagination data for 37891825.
# PubMed returned no pagination data for 33837049.
# PubMed returned no pagination data for 33689678.
# Error fetching data from PubMed for 38193537.
# 'Volume'
# PubMed returned no pagination data for 33689679.
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 31910261.
# Error fetching data from PubMed for 38014238.
# 'Volume'
# PubMed returned no pagination data for 31727776.
# PubMed returned no pagination data for 28134616.
# Error fetching data from PubMed for 38260608.
# 'Volume'
# PubMed returned no pagination data for 37843188.
# PubMed returned no pagination data for 29138759.
# Error fetching data from PubMed for 37693426.
# 'Volume'
# Error fetching data from PubMed for 31816021.
# 'AuthorList'
# Error fetching data from PubMed for 37333277.
# 'Volume'
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 32052742.
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 30667360.
# Error fetching data from PubMed for 37577625.
# 'Volume'
# PubMed returned no pagination data for 32024240.
# PubMed returned no pagination data for 29726811.
# PubMed returned no pagination data for 37945352.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# PubMed returned no pagination data for 30946007.
# PubMed returned no pagination data for 37516919.
# PubMed returned no pagination data for 31658977.
# PubMed returned no pagination data for 35972069.
# PubMed returned no pagination data for 32311044.
# Error fetching data from PubMed for 37916792.
# 'Volume'
# PubMed returned no pagination data for 27091544.
# PubMed returned no pagination data for 26559620.
# Error fetching data from PubMed for 38038892.
# 'Volume'
# PubMed returned no pagination data for 33801205.
# PubMed returned no pagination data for 28660246.
# PubMed returned no pagination data for 36612049.
# Error fetching data from PubMed for 38231269.
# 'Volume'
# PubMed returned no pagination data for 37874635.
# PubMed returned no pagination data for 34135003.
# PubMed returned no pagination data for 34431981.
# PubMed returned no pagination data for 32899153.
# PubMed returned no pagination data for 30634540.
# Error fetching data from PubMed for 28320946.
# 'AuthorList'

# %% [markdown]
# ## Run the google scholar neuromab search data
# - TODO

# %%
# run the df_final_review

# %%
# run the legacy data from the pubmed column
df = pd.read_excel("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/publications 041922.xlsx")
# get all the pmids from the PMID column
pubmed_ids = df['Pubmed'].tolist()
for pid in pubmed_ids:
    record = fetch_details(pid)
    if record:
        continue
    else:
        print(f"For {pid}, no record was found.")
        break
# Out:
# PubMed returned no pagination data for 20927324.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 22225533.
# PubMed returned no pagination data for 25517933.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for 24077800.
# list index out of range
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 26559620.
# PubMed returned no pagination data for 26665164.
# PubMed returned no pagination data for 26883496.
# PubMed returned no pagination data for 27800545.
# PubMed returned no pagination data for 27699209.
# PubMed returned no pagination data for 27863209.
# PubMed returned no pagination data for 27884958.
# PubMed returned no pagination data for 27677849.
# PubMed returned no pagination data for 27787195.
# PubMed returned no pagination data for 27046536.
# PubMed returned no pagination data for 27525480.
# PubMed returned no pagination data for 27537197.
# PubMed returned no pagination data for 27091544.
# PubMed returned no pagination data for 27257627.
# PubMed returned no pagination data for 29391966.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 28029095.
# PubMed returned no pagination data for 29046483.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 29138759.
# PubMed returned no pagination data for 29125462.
# PubMed returned no pagination data for 29168692.
# PubMed returned no pagination data for 29218323.
# PubMed returned no pagination data for 29250591.
# PubMed returned no pagination data for 29237760.
# PubMed returned no pagination data for 28512649.
# PubMed returned no pagination data for 28875935.
# PubMed returned no pagination data for 28856239.
# PubMed returned no pagination data for 29028184.
# PubMed returned no pagination data for 29263233.
# PubMed returned no pagination data for 28660246.
# PubMed returned no pagination data for 28347403.
# PubMed returned no pagination data for 28381466.
# PubMed returned no pagination data for 28598327.
# Error fetching data from PubMed for 28654047.
# 'Volume'
# PubMed returned no pagination data for 28785724.
# PubMed returned no pagination data for 28650316.
# PubMed returned no pagination data for 28584877.
# PubMed returned no pagination data for 28470148.
# PubMed returned no pagination data for 28560311.
# Error fetching data from PubMed for 28448009.
# 'Volume'
# PubMed returned no pagination data for 28816653.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 28955722.
# PubMed returned no pagination data for 28054918.
# PubMed returned no pagination data for 28060701.
# PubMed returned no pagination data for 28130923.
# PubMed returned no pagination data for 28134616.
# PubMed returned no pagination data for 28139198.
# PubMed returned no pagination data for 28164368.
# PubMed returned no pagination data for 28263709.
# PubMed returned no pagination data for 28321439.
# PubMed returned no pagination data for 28355134.
# PubMed returned no pagination data for 30225343.
# PubMed returned no pagination data for 30126943.
# PubMed returned no pagination data for 30190379.
# PubMed returned no pagination data for 30263951.
# PubMed returned no pagination data for 29553369.
# PubMed returned no pagination data for 29671737.
# PubMed returned no pagination data for 29712715.
# PubMed returned no pagination data for 29963618.
# Error fetching data from PubMed for 30451222.
# 'Volume'
# PubMed returned no pagination data for 30406178.
# PubMed returned no pagination data for 30398148.
# PubMed returned no pagination data for 30384417.
# PubMed returned no pagination data for 30511640.
# PubMed returned no pagination data for 30538174.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 29996472.
# PubMed returned no pagination data for 29361569.
# PubMed returned no pagination data for 29504938.
# PubMed returned no pagination data for 29361558.
# PubMed returned no pagination data for 29306897.
# PubMed returned no pagination data for 29311134.
# PubMed returned no pagination data for 29197141.
# PubMed returned no pagination data for 31878108.
# PubMed returned no pagination data for 30634540.
# PubMed returned no pagination data for 30680309.
# PubMed returned no pagination data for 31433295.
# PubMed returned no pagination data for 30789343.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 30396995.
# PubMed returned no pagination data for 30396997.
# PubMed returned no pagination data for 30545844.
# PubMed returned no pagination data for 30862038.
# PubMed returned no pagination data for 30957013.
# PubMed returned no pagination data for 30974833.
# PubMed returned no pagination data for 31017573.
# PubMed returned no pagination data for 31023719.
# PubMed returned no pagination data for 31658977.
# PubMed returned no pagination data for 31609202.
# PubMed returned no pagination data for 31615899.
# PubMed returned no pagination data for 31615901.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 31313987.
# PubMed returned no pagination data for 31036155.
# PubMed returned no pagination data for 31045576.
# PubMed returned no pagination data for 31042147.
# PubMed returned no pagination data for 31434643.
# PubMed returned no pagination data for 31566565.
# PubMed returned no pagination data for 31934859.
# PubMed returned no pagination data for 31947619.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 31985401.
# PubMed returned no pagination data for 32024240.
# PubMed returned no pagination data for 32033274.
# PubMed returned no pagination data for 32033960.
# PubMed returned no pagination data for 32052742.
# PubMed returned no pagination data for 32069266.
# PubMed returned no pagination data for 33046507.
# PubMed returned no pagination data for 32130108.
# PubMed returned no pagination data for 32202499.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 32217627.
# PubMed returned no pagination data for 32260356.
# PubMed returned no pagination data for 32289157.
# PubMed returned no pagination data for 32311044.
# PubMed returned no pagination data for 32341026.
# PubMed returned no pagination data for 32290408.
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 32937450.
# PubMed returned no pagination data for 32708917.
# PubMed returned no pagination data for 32706374.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 32848094.
# PubMed returned no pagination data for 32553116.
# PubMed returned no pagination data for 32858836.
# PubMed returned no pagination data for 33083793.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 32917708.
# PubMed returned no pagination data for 32915137.
# PubMed returned no pagination data for 31840160.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 31936259.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 31727776.
# PubMed returned no pagination data for 31820781.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 32604880.
# PubMed returned no pagination data for 33105624.
# PubMed returned no pagination data for 33188005.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 33208499.
# PubMed returned no pagination data for 33298440.
# PubMed returned no pagination data for 33443209.
# Error fetching data from PubMed for 33350496.
# 'Volume'
# PubMed returned no pagination data for 33335032.
# PubMed returned no pagination data for 33373327.
# PubMed returned no pagination data for 33401689.
# PubMed returned no pagination data for 33408125.
# PubMed returned no pagination data for 33502442.
# PubMed returned no pagination data for 33472865.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 33529173.
# PubMed returned no pagination data for 33536249.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# PubMed returned no pagination data for 33593893.
# Error fetching data from PubMed for 33732797.
# 'Initials'
# PubMed returned no pagination data for 33653948.
# PubMed returned no pagination data for 33803465.
# PubMed returned no pagination data for 33689679.
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'
# Error fetching data from PubMed for nan.
# 'float' object has no attribute 'split'

# %%
len(os.listdir("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/pmidjsons/"))
# Out:
# 3824

# %% [markdown]
# ### These seem to mostly be caused by the neuromab showing up in proximity to a target - we could search for Neuromab and the target but does not guarantee that the neuromab was the one used (though extremely likely).
# - Unfortunately scraping all papers to check proximity is not feasible as UC davis does not have access to all the papers.
# - The snipped could also be used as well to see if proximal to the target. I think 99% of the time it will be relevant.
# - The one hard part is that targets and the way they are shown have weird characters and stuff so search for those with google scholar wont be super easy.
# - Will certainly merge all this previous manual work into the pipeline so the current count will add 676
# - Overall my code retrieves 1185 more though (without adding just the general Neuromab search) and ensuring it is a review paper.
# - Need to remove the <sub> and </sub> from the titles and abstracts.
# - Need to remove the <sup> and </sup> from the titles and abstracts.
# - Need to remove the <i> and </i> from the titles and abstracts.
# - Need to remove the <b> and </b> from the titles and abstracts.
# - Need to remove the <u> and </u> from the titles and abstracts.
# - Be more clear where the source is from for the information
# - Need to fix a small subset that failed in the annotations of Pubmed info should be an easy fix
# - Possible new queries:
#   - Antibodies inc and target
#   - Antibodies inc and target and neuromab
#   - Antibodies inc and davis and target
#   - Davis and target and neuromab
#   - neuromab and (antibody or antibodies or mab or monoclonal) == review (if no target)
#   - antibodies inc and neuromab id
#      - how is antibodies inc doing this
#      - search for antibodies inc and "antibody or monoclonal or mab" and "target" and each part of the catalog number.
# - Double check the merging process to include all targets and mabs for the merge with old data
# - Mark which ones were exclusive to the aantibodies inc scraping
# -

# %%
# compare all the pmids to this file and see which we dont have
#/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/publications 041922.xlsx
df = pd.read_excel("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/publications 041922.xlsx")
# filter out anything that saays review in the clone
# remove all Pubmed that are empty
df = df[df['Pubmed'].notna()]
# set the Clone to a string column and remove any that are na
df['Clone'] = df['Clone'].astype(str)
df = df[df['Clone'] != 'nan']
df = df[~df['Clone'].str.contains('review', case=False)]
print(len(set([str(i) for i in df["Pubmed"].tolist()])- set([str(i.split('.')[0]) for i in os.listdir("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/pmidjsons/")])))
set([str(i) for i in df["Pubmed"].tolist()])- set([str(i.split('.')[0]) for i in os.listdir("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/pmidjsons/")])
# Out:
# 676
# {'16511870',
#  '16982420',
#  '17379638',
#  '17537961',
#  '17656725',
#  '17855588',
#  '18083105',
#  '18344983',
#  '18458091',
#  '18480286',
#  '18511484',
#  '18680201',
#  '18716211',
#  '18753128',
#  '18753382',
#  '18832009',
#  '18995817',
#  '19038221',
#  '19118598',
#  '19162133',
#  '19167097',
#  '19185209',
#  '19224364',
#  '19370153',
#  '19558451',
#  '19627441',
#  '19657031',
#  '31607869',
#  '37532012',
#  '22249457',
#  '37168495',
#  '31354436',
#  '30598502',
#  '36336067',
#  '36369219',
#  '29592971',
#  '30825330',
#  '19923600',
#  '32531277',
#  '37756587',
#  '30592011',
#  '26834556',
#  '34844642',
#  '37773316',
#  '34289359',
#  '28432329',
#  '26808347',
#  '35289477',
#  '27593178',
#  '38014238',
#  '31806492',
#  '35346832',
#  '33364977',
#  '34231259',
#  '36949148',
#  '37607607',
#  '36967142',
#  '32364262',
#  '28235805',
#  '31964774',
#  '26764482',
#  '38194969',
#  '36697254',
#  '36216607',
#  '36014775',
#  '37533653',
#  '27943591',
#  '31685650',
#  '36878501',
#  '24276495',
#  '37587147',
#  '37310860',
#  '34803580',
#  '36417873',
#  '31597963',
#  '30022868',
#  '35501931',
#  '35577065',
#  '37105442',
#  '35940118',
#  '36181963',
#  '28677679',
#  '28973664',
#  '28430183',
#  '31350430',
#  '29487522',
#  '26845140',
#  '35599495',
#  '26218245',
#  '28103480',
#  '37858465',
#  '35246535',
#  '36709330',
#  '32634531',
#  '37075948',
#  '34450161',
#  '37847372',
#  '32248813',
#  '35263136',
#  '34974536',
#  '38075021',
#  '31554851',
#  '37141099',
#  '34461722',
#  '24872163',
#  '31107446',
#  '35359569',
#  '26186538',
#  '31604597',
#  '28447247',
#  '27621318',
#  '29091766',
#  '38038892',
#  '26291161',
#  '25193658',
#  '28040728',
#  '36451656',
#  '26590557',
#  '36395691',
#  '31212013',
#  '37003353',
#  '37702787',
#  '29706865',
#  '33132203',
#  '36693856',
#  '21745462',
#  '28522792',
#  '25939886',
#  '27418514',
#  '33836114',
#  '29976627',
#  '34766907',
#  '29472595',
#  '37837904',
#  '37963972',
#  '35841648',
#  '24744440',
#  '29222469',
#  '35803734',
#  '37923712',
#  '36262316',
#  '35726573',
#  '34496232',
#  '35952494',
#  '34144124',
#  '36684387',
#  '36142639',
#  '36351843',
#  '31249512',
#  '31591156',
#  '36793543',
#  '33989527',
#  '35678782',
#  '37289222',
#  '37759527',
#  '34522029',
#  '31591393',
#  '31403402',
#  '29934346',
#  '35012605',
#  '35857479',
#  '36656118',
#  '34335184',
#  ...}

# %%
# print the snippets out line by line for the google scholar search
for index, row in df_final.iterrows():
    print(row['snippet'])
    print('')
# Out:
# BACKGROUND: KCNQ1 (Kv7.1), together with its KCNE β subunits, plays a pivotal role
# both in the repolarization of cardiac tissue and in water and salt transport across epithelial …
#
# … , N212/17, Neuromab, CA, USA) antibodies using a previously described protocol [36, 37].
# Imaging analysis was performed using a Nikon A1 confocal microscope at the Northwestern …
#
# Tetratricopeptide repeat (TPR) domains are ubiquitous structural motifs that mediate protein–protein
# interactions. For example, the TPR domains in the peroxisomal import receptor …
#
# Hyperpolarization-activated cyclic nucleotide-gated (HCN) channels are expressed in the
# heart and central nervous system where they regulate membrane excitability. Recently, …
#
# … N144/14; University of California Davis/National Institutes of Health … (N144/14) was
# obtained form the University of California Davis/National Institutes of Health NeuroMab Facility. …
#
# … Lysates were incubated with CRMP-2-6xHis, following phosphorylation, and immunoprecipitated
# (IP) with a 6xHis antibody (UC Davis/NIH NeuroMab Facility, clone N144/14) overnight …
#
# … Mouse antibody against His (N144/14) for western blotting was from NeuroMab (Davis,
# CA). Mouse antibody against His (27E8) and rabbit antibody against His (no. 2365) were …
#
# α-Synuclein plays a key role in the pathogenesis of Parkinson’s disease and related disorders,
# but critical interacting partners and molecular mechanisms mediating neurotoxicity are …
#
# Eukaryotic pathogens display multiple mechanisms for breaching the blood-brain barrier (BBB)
# and invading the central nervous system (CNS). Of the fungal spp., that cause disease in …
#
# The conventional kinesin motor transports many different cargos to specific locations in neurons.
# How cargos regulate motor function remains unclear. Here we focus on KIF5, the heavy …
#
# Botulinum neurotoxin A (BoNT/A) belongs to the most dangerous class of bioweapons 1 .
# Despite this, BoNT/A is used to treat a wide range of common medical conditions such as …
#
# … the UC Davis/NIH NeuroMab facility: AnkG (106/36; RRID:AB_10673030), AnkG (106/65;
# RRID:AB_10675130), PanNav (N419/78; RRID:AB_2493099), b1 spectrin (N385/21; RRID:…
#
# Skeletal muscle contraction depends on activation of clustered acetylcholine receptors (AchRs)
# and muscle-specific Na + channels (Nav1.4). Some Nav1.4 channels are highly …
#
# Clustered ion channels at nodes of Ranvier are critical for fast action potential propagation
# in myelinated axons. Axon-glia interactions converge on ankyrin and spectrin cytoskeletal …
#
# … Mouse monoclonal antibody against GKAP (clone N1427/31, used at 1:100), pan Shank (clone
# N23B/49, which recognizes all three members of the Shank family: Shank 1, 2 and 3, …
#
# … 1:1000 for Western), and pan Shank (clone N23B/49, used at 1:200 for microscopy and 1:1000
# for Western) were from NeuroMab, Davis, CA, USA. Rabbit polyclonal antibody against …
#
# … The monoclonal mouse antibodies against Shank (N23B/49) and PSD-95 (K28/43) were
# from NeuroMAB. ECL and ECL plus reagents were from Amersham. Other reagents were from …
#
# IRSp53 (BAIAP2) is an abundant protein at the postsynaptic density (PSD) that binds to major
# PSD scaffolds, PSD-95 and Shanks, as well as to F-actin. The distribution of IRSp53 at the …
#
# Early in development spontaneous activity modulates survival and connectivity of neurons
# and thus plays a crucial role in the formation of neural networks. The emergence of …
#
# Regulated exocytosis is essential for many biological processes and many components of
# the protein trafficking machinery are ubiquitous. However, there are also exceptions, such as …
#
# The family of Shank scaffolding molecules (comprising Shank1, 2 and 3) are core components
# of the postsynaptic density ( PSD ) in neuronal synapses. Shanks link surface receptors to …
#
# Most neurological disorders display impaired synaptic connectivity. Hence, modulation of
# synapse formation may have therapeutic relevance. However, the high density and small size …
#
# In vitro studies suggest that the intracellular C terminus of Neuroligin1 (NL1) could play a
# central role in the maturation of excitatory synapses. However, it is unknown how this activity …
#
# … ), mouse monoclonal anti-Pan-Shank (clone N23B/49; 1:400, Neuromab, N23B/49), mouse
# monoclonal anti-NR2A (clone N327/95; 1:400, Neuromab, Q00959), mouse monoclonal anti-…
#
# … for Western), and pan-Shank (clone N23B/49, which recognizes all three members of the
# Shank family: Shank1, 2 and 3, used at 1:250 for EM) were from NeuroMab (Davis, CA). Mouse …
#
# … (clone N23B/49, which recognizes all three members of the Shank family: Shank 1, 2 and 3,
# used at 1:250), and Shank 2 (clone N23B/6, used at 1:200) were from NeuroMab (Davis, CA)…
#
# Excitatory glutamatergic synapses facilitate important aspects of communication between
# the neurons that govern complex forms of behavior. Accordingly, small differences in the …
#
# Synapses are specialized adhesion sites between neurons that are connected by protein
# complexes spanning the synaptic cleft. These trans‐synaptic interactions can organize …
#
# Despite the central role PSD-95 plays in anchoring postsynaptic AMPARs, how PSD-95
# itself is tethered to postsynaptic sites is not well understood. Here we show that the F-actin …
#
# Mutations or altered protein levels of SHANK3 are implicated in neurodevelopmental disorders
# such as Phelan–McDermid syndrome, autism spectrum disorders, and schizophrenia ( …
#
# Variants in the ANK3 gene encoding ankyrin-G are associated with neurodevelopmental
# disorders, including intellectual disability, autism, schizophrenia, and bipolar disorder. However…
#
# A core network of widely expressed proteins within the glutamatergic post-synapse mediates
# activity-dependent synaptic plasticity throughout the brain, but the specific proteomic …
#
# Scribble (Scrib) is a key regulator of apicobasal polarity, presynaptic architecture, and short-term
# synaptic plasticity in Drosophila. In mammals, its homolog Scrib1 has been implicated …
#
# LRRTMs are postsynaptic cell adhesion proteins that have region-restricted expression in the
# brain. To determine their role in the molecular organization of synapses in vivo, we studied …
#
# … Knockouts were confirmed by Sanger sequencing and Western blotting using anti- ATAD1
# antibody (N125/10, NeuroMab) and anti- Histone H3 (ab1791, Abcam) as a loading control. …
#
# The spatial and temporal balance of spinal α‐motoneuron (αMN) intrinsic membrane
# conductances underlies the neural output of the final common pathway for motor commands. …
#
# Shank3 is a postsynaptic density (PSD) scaffold protein of the Shank family. Here we use
# pre-embedding immunogold electron microscopy to investigate factors influencing the …
#
# … subjected to immunoblotting with antibody N69/46 to Shank3. The … N69/46 anti-Shank3
# antibody directed against an epitope downstream of the PDZ domain (UC Davis/NIH NeuroMab …
#
# Haploinsufficiency of the Shank3 gene, which encodes a scaffolding protein at glutamatergic
# synapses, is a highly prevalent and penetrant risk factor for autism. Using combined …
#
# Rho GTPases activated by GDP/GTP exchange factors (GEFs) play key roles in the
# developing and adult nervous system. Kalirin-7 (Kal7), the predominant adult splice form of the …
#
# A core network of widely expressed proteins within the glutamatergic post-synapse mediates
# activity-dependent synaptic plasticity throughout the brain, but the specific proteomic …
#
# … of NeuroMabs as a method to archive all NeuroMabs, to unambiguously define NeuroMabs
# … for specific labeling (N355/1 in a1 and N399/19 in b1) and two other candidates from these …
#
# Neurons in the rostral ventrolateral medulla (RVLM) regulate blood pressure through direct
# projections to spinal sympathetic preganglionic neurons. Only some RVLM neurons are …
#
# As a basic functional unit in neural circuits, each neuron integrates input signals from hundreds
# to thousands of synapses. Knowledge of the synaptic input fields of individual neurons, …
#
# … Here, we describe a BaseScope/RNAscope-immunohistochemical protocol using a mouse
# monoclonal anti-GFP antibody from NeuroMab (clone N86/8; University of California, Davis). …
#
# … the auspices of the National Institute of Child Health and Human Development and
# maintained by the University of Iowa; and from the University of California Davis/NIH NeuroMab …
#
# … The primary antibodies used for western blotting were mouse monoclonal anti-GFP (1∶1000,
# NeuroMab, N86/8) and rabbit polyclonal anti-FGF14 (1∶1000). Secondary antibodies …
#
# Loss of Fragile X mental retardation protein (FMRP) leads to Fragile X syndrome (FXS), the
# most common form of inherited intellectual disability and autism. Although the functions of …
#
# Aggregation of the multifunctional RNA‐binding protein TDP‐43 defines large subgroups of
# amyotrophic lateral sclerosis and frontotemporal dementia and correlates with …
#
# … The GFP N86/8 antibody was from the University of California, Davis/NIH NeuroMab
# Facility. Drosophila stocks obtained from the Bloomington Drosophila Stock Center (NIH …
#
# Anastasis is a recently described process in which cells recover after late-stage apoptosis
# activation. The functional consequences of anastasis for cells and tissues are not clearly …
#
# The homeostatic control of presynaptic neurotransmitter release stabilizes information transfer
# at synaptic connections in the nervous system of organisms ranging from insect to human. …
#
# Chemotherapy-related cognitive impairment (CRCI) is a common adverse effect of treatment
# and is characterized by deficits involving multiple cognitive domains including memory. …
#
# Vesicular trafficking defects, particularly those in the autophagolysosomal system, have
# been strongly implicated in the pathogenesis of Parkinson’s disease and related α-…
#
# INTRODUCTION Mitochondria are endosymbiotic organelles that have their own genome and
# perform many essential functions in eukaryotic cells, including ATP synthesis via oxidative …
#
# Investigating the expression of RNAs that differ by short or single nucleotide sequences at a
# single-cell level in tissue has been limited by the sensitivity and specificity of in situ …
#
# Control of translation is a fundamental source of regulation in gene expression. The induction
# of protein synthesis by brain-derived neurotrophic factor (BDNF) critically contributes to …
#
# Mutations in LRRK2 are the most common cause of familial Parkinson’s disease and typically
# cause disease in the context of abnormal aggregation and deposition of α-synuclein within …
#
# The Ca 2+ /calcineurin-dependent transcription factor NFAT (nuclear factor of activated T-cells)
# is implicated in regulating dendritic and axonal development, synaptogenesis, and …
#
# … Citation 49 Membranes were probed with anti-GFP N86/8 mouse monoclonal antibody (1
# μg/mL; UC Davis/NeuroMab Facility, 73–131:RRID AB_10671444) and rabbit anti-Zwf1/…
#
# … We thank the current and former staff members of the UC Davis/NIH NeuroMab Facility and
# the Trimmer laboratory for their contributions and dedicated efforts, and Dr. Randall Stewart …
#
# … ) prior to immuno-detection with mouse anti-GFP (UC Davis/NIH Neuromab Facility, Cat.
# No.: N86/8) and rabbit anti Calnexin antibody (Enzo Life Sciences, Cat. No.: ADI-SPA-860). …
#
# Förster resonance energy transfer (FRET) microscopy is frequently used to study protein
# interactions and conformational changes in living cells. The utility of FRET is limited by false …
#
# Background Guanine nucleotide exchange factors (GEFs) and their target Rho GTPases
# regulate cytoskeletal changes and membrane trafficking. Dynamin, a large force-generating …
#
# … The blot was blocked with 5% milk for 1 hour, and then developed with 1 μg/mL anti-GFP
# mouse monoclonal clone N86/8 (catalogue no. 75-131; nonprofit University of California Davis/…
#
# Autophagy promotes protein degradation, and therefore has been proposed to maintain
# amino acid pools to sustain protein synthesis during metabolic stress. To date, how autophagy …
#
# Altered excitatory/inhibitory (E/I) balance is implicated in neuropsychiatric and neurodevelopmental
# disorders, but the underlying genetic etiology remains poorly understood. Copy …
#
# … (NeuroMab clone N86/8) were obtained commercially. Following incubation with the primary
# antibody, the membrane was exposed to the HRP-conjugated goat anti-rabbit secondary …
#
# 10.7554/eLife.16807.001 Altered insulin signaling has been linked to widespread nervous
# system dysfunction including cognitive dysfunction, neuropathy and susceptibility to …
#
# … Antibodies were purchased: mouse anti-GFP (clone N86/8, antibody registry #AB_10671444,
# UC Davis/NIH NeuroMab Facility), rabbit anti-GFP (Invitrogen), rat monoclonal anti-HA (…
#
# … Mouse anti-GFP antibody (N86/8) was from NeuroMab. Mouse anti-β tubulin (E7) and anti-GAPDH
# (MAB374) were from DSHB and MilliporeSigma (Burlington, Massachusetts, USA), …
#
# … Louis, MO), anti–glucose-6-phosphate dehydrogenase (G6PDH; Zwf1; 1:100,000; Sigma-Aldrich),
# or anti-GFP (1 μg/ml; N86/8; Neuromab, Davis, CA) primary antibodies and visualized …
#
# Phosphorylation regulates surface and synaptic expression of NMDA receptors (NMDARs).
# Both the tyrosine kinase Fyn and the tyrosine phosphatase striatal-enriched protein tyrosine …
#
# Presynaptic homeostatic plasticity (PHP) adaptively regulates synaptic transmission in health
# and disease. Despite identification of numerous genes that are essential for PHP, we lack …
#
# The submicroscopic spatial organization of cell surface receptors and plasma membrane
# signaling molecules is readily characterized by electron microscopy (EM) via immunogold …
#
# Proper brain development and function requires finely controlled mechanisms for protein
# turnover, and disruption of genes involved in proteostasis is a common cause of …
#
# The C9orf72 repeat expansion causes amyotrophic lateral sclerosis and frontotemporal
# dementia, but the poor correlation between C9orf72‐specific pathology and TDP ‐43 pathology …
#
# The pathogenesis of peripheral neuropathies in adults is linked to maintenance mechanisms
# that are not well understood. Here, we elucidate a novel critical maintenance mechanism …
#
# Structural plasticity of dendritic spines and synapses is a fundamental mechanism governing
# neuronal circuits and may form an enduring basis for information storage in the brain. We …
#
# … Membranes were probed with α-GFP N86/8 monoclonal antibody (1 µg/ml; NeuroMab), α-G6PDH
# (Zwf1; 1:1,000; Sigma-Aldrich), α-Atg13 (1:1,000; polyclonal, gift of D. Klionsky, …
#
# RNA-binding proteins (RBPs) function in higher-order assemblages such as RNA granules
# to regulate RNA localization and translation. The Fragile X homolog FXR2P is an RBP …
#
# Intronic hexanucleotide (G 4 C 2 ) repeat expansions in C9orf72 are genetically associated
# with frontotemporal lobar degeneration ( FTLD ) and amyotrophic lateral sclerosis ( ALS ). …
#
# … The following antibodies were used: Anti-GFP (mouse N86/8, Neuromab, Davis, CA, USA
# and rabbit, Clontech, Mountainview, CA, USA), anti-β-actin (Sigma Aldrich, St. Louis, MO, USA)…
#
# Long-term forms of brain plasticity share a requirement for changes in gene expression
# induced by neuronal activity. Mechanisms that determine how the distinct and overlapping …
#
# A repeat expansion in the non-coding region of C9orf72 gene is the most common mutation
# causing frontotemporal lobar degeneration (FTLD) and amyotrophic lateral sclerosis (ALS). …
#
# … Mouse monoclonal anti-gfp, clone N86/8, was obtained from Antibodies Inc. (University
# of California Davis, National Institutes of Health NeuroMab, Davis, CA). Mouse monoclonal …
#
# The DISC1 protein is implicated in major mental illnesses including schizophrenia, depression,
# bipolar disorder, and autism. Aberrant mitochondrial dynamics are also associated with …
#
# MicroRNAs (miRNAs) are important regulators of localized mRNA translation in neuronal
# dendrites. The presence of RNA-induced silencing complex proteins in these compartments …
#
# … Mouse monoclonal anti-gfp, clone N86/8 was obtained from Antibodies Incorporated (UC
# Davis, NIH NeuroMab, Davis, CA, USA).Mouse monoclonal antibody against beta-actin (cat # …
#
# nan
#
# Astroglia play active and diverse roles in modulating neuronal/synaptic functions in the CNS.
# How these astroglial functions are regulated, especially by neuronal signals, remains …
#
# Mitochondrial transport plays an important role in matching mitochondrial distribution to
# localized energy production and calcium buffering requirements. Here, we demonstrate that …
#
# Repeat expansion in C9orf72 causes amyotrophic lateral sclerosis and frontotemporal lobar
# degeneration. Expanded sense and antisense repeat RNA transcripts in C9orf72 are …
#
# Mutations in leucine-rich repeat kinase 2 (LRRK2) are the most common cause of familial
# Parkinson disease. Genetics and neuropathology link Parkinson disease with the microtubule-…
#
# Cell‐to‐cell transmission of protein aggregates is an emerging theme in neurodegenerative
# disease. Here, we analyze the dipeptide repeat ( DPR ) proteins that form neuronal …
#
# The microtubule binding protein tau is strongly implicated in multiple neurodegenerative
# disorders, including frontotemporal dementia and parkinsonism linked to chromosome 17 (FTDP…
#
# Rare variants in GRIN genes, which encode NMDAR subunits, are strongly associated with
# neurodevelopmental disorders. Among these, GRIN2A, which encodes the GluN2A subunit …
#
# Neuron‐secreted factors induce astrocytic expression of the glutamate transporter, GLT ‐1 (excitatory
# amino acid transporter 2). In addition to their elaborate anatomic relationships with …
#
# Synaptic plasticity requires remodeling of the actin cytoskeleton. Although two actin isoforms,
# β- and γ-actin, are expressed in dendritic spines, the specific contribution of γ-actin in the …
#
# The dystrophin complex is a multimolecular membrane-associated protein complex whose
# defects underlie many forms of muscular dystrophy. The dystrophin complex is postulated to …
#
# Mutations in the X-linked MECP2 cause Rett syndrome, a devastating neurological disorder
# typified by a period of apparently normal development followed by loss of cognitive and …
#
# GGGGCC (G 4 C 2 ) repeat expansion in the C9orf72 gene has been shown to cause
# frontotemporal lobar degeneration and amyotrophic lateral sclerosis. Dipeptide repeat proteins …
#
# The process by which future behavioral responses are shaped by past experiences is one of
# the central questions in neuroscience. To gain insight into this process at the molecular and …
#
# 10.7554/eLife.31181.001 Treatment for medulloblastoma, the most common malignant
# brain tumor in children, remains limited to surgical resection, radiation, and traditional …
#
# … Mouse IgG2a monoclonal antibody (NeuroMab, clone N86/8), raised against fusion
# protein amino acid 1-238 (full length) of jellyfish green fluorescent protein. …
#
# Protein phosphatase 2A (PP2A) is a large enzyme family responsible for most cellular Ser/Thr
# dephosphorylation events. PP2A substrate specificity, localization, and regulation by …
#
# Amyotrophic lateral sclerosis (ALS) and frontotemporal dementia (FTD) are severe
# neurodegenerative diseases with overlapping clinical and pathological features. Recently, a …
#
# Nestin, an intermediate filament protein widely used as a marker of neural progenitors, was
# recently found to be expressed transiently in developing cortical neurons in culture and in …
#
# 10.7554/eLife.07739.001 The conserved MICOS complex functions as a primary determinant
# of mitochondrial inner membrane structure. We address the organization and functional …
#
# Mitochondrial transport plays an important role in matching mitochondrial distribution to
# localised energy production and calcium buffering requirements. Miro is an outer mitochondrial …
#
# Protein translation is necessary for cell function, but it is an incredibly energy demanding
# process, and is therefore tightly regulated by the metabolic state of the cell. There are a …
#
# Schizophrenia is associated with cognitive and behavioral dysfunctions thought to reflect
# imbalances in neurotransmission systems. Recent screenings suggested that lack of (functional…
#
# … antibody to PSD-95 (clone K28/43, NeuroMab), rabbit antibody to GRIP1 (Millipore), mouse
# antibody to PICK1 (clone L20/8, NeuroMab) and rabbit antibody to phospho-Ser880 GluA2 (…
#
# Protein interacting with C-kinase 1 (PICK1) is a 415-aa multidomain scaffold protein
# encoded by the PICK1 gene. Accumulating evidence suggests that PICK1 is involved in the …
#
# … ), and NR2B (1:300, mouse IgG2a N59/20; NeuroMab). Sections were washed three times
# for 5 min in 1× PBS at room temperature with gentle agitation before applying Alexa Fluor dye-…
#
# MicroRNAs (miRNAs) are important regulators of localized mRNA translation in neuronal
# dendrites. The presence of RNA-induced silencing complex proteins in these compartments …
#
# … Mouse anti-PICK1 antibody (#L20-8) was from NeuroMab (Davis, CA) and rabbit
# polycolonal anti-PICK1 antibody was from Jun Xia (Hong Kong). Horseradish peroxidase-conjugated …
#
# Excitatory glutamatergic synapses facilitate important aspects of communication between
# the neurons that govern complex forms of behavior. Accordingly, small differences in the …
#
# The authors regret an error in section 2.3 of the Methods section of the manuscript. We
# inadvertently listed the Arl13b antibody lot number (455–8JD-29) in place of the antibody clone …
#
# Primary cilia are microtubule-based organelles that protrude from the cell surface. Primary
# cilia play a critical role in development and disease through regulation of signaling pathways …
#
# … NeuroMab Facility, clone N295B/66) to verify the marking of cilia with the antibody against
# acetylated tubulin. The slides were then washed with PBS for 10 minutes (3 x 10 min). The …
#
# Genetic diseases involving overactivation of the mechanistic target of rapamycin (mTOR)
# pathway, so‐called “mTORopathies,” often manifest with malformations of cortical development …
#
# The neural mechanisms that underlie responses to drugs of abuse are complex, and
# impacted by a number of neuromodulatory peptides. Within the past 10 years it has been …
#
# Background Ciliary defects cause heterogenous phenotypes related to mutation burden which
# lead to impaired development. A previously reported homozygous deletion in the Man1a2 …
#
# The primary cilium is a nexus for cell signaling and relies on specific protein trafficking for
# function. The tubby family protein TULP3 transports integral membrane proteins into cilia …
#
# … on knockout tissue by NeuroMab (documented on NeuroMab Clone N295B/66 datasheet). In
# WB … detects an ≈60 kDa band that is absent in the Arl13b knockout (datasheet NeuroMab). …
#
# … The following antibodies and dilutions were used in this study: mouse anti-ARL13B (NeuroMabs
# N295B/66, 1:500), rabbit anti-ARL13B (gift from Tamara Caspary, 1:500, and …
#
# Cilia are highly conserved organelles, which serve critical roles in development and physiology.
# Motile cilia are expressed in a limited range of tissues, where they principally regulate …
#
# … ), rabbit anti-Olig2 (AB9610, 1:500, Millipore Sigma), and mouse anti-Arl13b (N295B/66, 1:1500,
# NeuroMab). Multiple sections from three embryos of each genotype were examined. …
#
# Activating LRRK2 mutations cause Parkinson’s disease, and pathogenic LRRK2 kinase
# interferes with ciliogenesis. Previously, we showed that cholinergic interneurons of the dorsal …
#
# Retinitis pigmentosa (RP) is an inherited retinal degenerative disease with severe vision
# impairment leading to blindness. About 10–15% of RP cases are caused by mutations in the …
#
# … (C) Confocal images of cilia marker IFT88 (green) and ARL13B (magenta; NeuroMab)
# staining in neural tube of E10.5 somite-matched embryos. ARL13B-positive cilia are visible in …
#
# Cellular primary cilia crucially sense and transduce extracellular physicochemical stimuli.
# Cilium-mediated developmental signaling is tissue and cell type specific. Primary cilia are …
#
# The primary cilium is a paradigmatic organelle for studying compartmentalized signaling;
# however, unlike soluble protein trafficking, processes targeting integral membrane proteins to …
#
# The primary cilium is fundamentally important for the proliferation of neural stem/progenitor
# cells and for neuronal differentiation during embryonic, postnatal, and adult life. In addition, …
#
# Background: Cilia are important for Hedgehog signaling in vertebrates and many genes that
# encode proteins involved in ciliogenesis have been studied for their roles in embryonic …
#
# … NeuroMab Facility clone N295B/66), rabbit anti-centrosome and spindle pole associated
# protein 1 (CSPP1, 1:200, Proteintech, 11931-1-AP), rabbit anti-intraflagellar transport protein …
#
# During the development of the cerebral cortex, neurons are generated directly from radial
# glial cells or indirectly via basal progenitors. The balance between these division modes …
#
# We have previously described a forward genetic screen in mice for abnormalities of brain
# development. Characterization of two hydrocephalus mutants by whole-exome sequencing …
#
# We tested whether cannabinoids (CBs) potentiate alcohol-induced birth defects in mice and
# zebrafish, and explored the underlying pathogenic mechanisms on Sonic Hedgehog (Shh) …
#
# Histone H4 lysine 16 acetylation (H4K16ac), governed by the histone acetyltransferase MOF,
# orchestrates gene expression regulation and chromatin interaction. However, the roles of …
#
# Growing evidence shows that alterations occurring at early developmental stages contribute
# to symptoms manifested in adulthood in the setting of neurodegenerative diseases. Here, …
#
# The primary cilium is a microtubule-enriched cell-communication organelle that participates
# in mechanisms controlling tissue development and maintenance, including cerebellar …
#
# Four distinct subgroups of cerebellar medulloblastomas (MBs) differ in their histopathology,
# molecular profiles, and prognosis. c-Myc (Myc) or MycN overexpression in granule neuron …
#
# … They were incubated overnight in mouse anti-ADP-ribosylation factor-like protein 13B (Arl13b
# clone N295B/66, NeuroMab) diluted 1:100 in blocking buffer at 4 ​C overnight. The LROs …
#
# Cilia perform essential signalling functions during development and tissue homeostasis. A
# key event in ciliogenesis occurs when the distal appendages of the mother centriole form a …
#
# As essential components of the eukaryotic cytoskeleton, microtubules fulfill a variety of functions
# that can be temporally and spatially controlled by tubulin posttranslational modifications. …
#
# Primary cilia are complex organelles, usually singularly located on cell surfaces that are
# now known to be important for signaling and whose defect is implicated in a category of …
#
# … The following primary antibodies were used: mouse anti-ARL13B and rabbit-anti-ARL13B
# (NeuroMab, clone N295B/66; 1:300 dilution for immunofluorescence (IF) and ProteinTech, …
#
# Primary cilia are compartmentalized sensory organelles present on the majority of neurons
# in the mammalian brain throughout adulthood. Recent evidence suggests that cilia regulate …
#
# Polycystic kidney disease proteins, polycystin-1 and polycystin-2, localize to primary cilia.
# Polycystin knockouts have severe cystogenesis compared to ciliary disruption, whereas …
#
# Evidence is lacking as to how developing neurons integrate mitogenic signals with
# microenvironment cues to control proliferation and differentiation. We determine that the Siah2 E3 …
#
# The microtubule cytoskeleton is one of the principal components of eukaryotic cells. Microtubules
# are involved in the processes of cell division, transport, signaling and differentiation. …
#
# The regulation of proliferation is a primary function of Hedgehog (Hh) signaling in development.
# Hh signal transduction requires the primary cilium for several steps in the pathway [1–5]. …
#
# Primary cilia are sensory organelles present on most vertebrate cells and are critical for
# development and health. Ciliary dysfunction is associated with a large class of human …
#
# Aberrant Notch signalling has been linked to many cancers including choroid plexus (CP)
# tumours, a group of rare and predominantly paediatric brain neoplasms. We developed …
#
# Primary Cilia (PC) are a very likely place for signal integration where multiple signaling
# pathways converge. Two major signaling pathways clearly shown to signal through the PC, …
#
# Background The mechanisms by which primary cilia affect glioma pathogenesis are unclear.
# Depending on the glioma cell line, primary cilia can promote or inhibit tumor development. …
#
# The health and maintenance of rod photoreceptors depends on the high-fidelity vectorial
# transport of rhodopsin from its site of synthesis in the inner segment to its final resting place in …
#
# The intracellular ciliogenesis pathway requires membrane trafficking, fusion, and reorganization.
# Here, we demonstrate in human cells and zebrafish that the F-BAR domain containing …
#
# Cilia are near ubiquitous small, cellular appendages critical for cell-to-cell communication.
# As such, they are involved in diverse developmental and homeostatic processes, including …
#
# Sonic hedgehog (Shh) signal transduction specifies ventral cell fates in the neural tube and
# is mediated by the Gli transcription factors that play both activator (GliA) and repressor (GliR) …
#
# Mutations in the hepatocyte nuclear factor (HNF)1β gene (HNF1B) cause autosomal dominant
# tubulointerstitial kidney disease, a rare and heterogeneous disease characterized by …
#
# Centriolar satellites are dynamic, membraneless granules composed of over 200 proteins.
# They store, modify, and traffic centrosome and primary cilium proteins, and help to regulate …
#
# Primary cilia are a small microtubule based signaling organelle. Primary cilia can be found
# on almost every mammalian cell, including neurons and glia. Tau Tubulin Kinase 2 (TTBK2) …
#
# The small GTPase Arl13b is enriched in primary cilia and regulates Sonic hedgehog (Shh)
# signaling. During neural development, Shh controls patterning and proliferation through a …
#
# Multiciliated cells (MCCs) in the brain reside in the ependyma and the choroid plexus (CP)
# epithelia. The CP secretes cerebrospinal fluid that circulates within the ventricular system, …
#
# Primary cilia are chemosensors that play a dual role to either activate or repress Hedgehog
# signaling, depending on presence or absence of ligand, respectively. While inhibition of …
#
# Arl13b is a gene known to regulate ciliogenesis. Functional alterations in this gene's activity
# have been associated with Joubert syndrome. We found that in Arl13 null mouse embryos …
#
# … Rabbit polyclonal anti-WDR5 (Bethyl, A302-430A; 1:150), mouse monoclonal anti-Arl13b
# (NeuroMab, N295B/66; 1:100) and mouse monoclonal anti-γ tubulin (Sigma-Aldrich, T6557; 1:…
#
# Cilia-mediated signal transduction involves precise targeting and localization of selected
# molecules along the ciliary membrane. However, the molecular mechanism underlying these …
#
# Trisomy 21 (T21) is the most prevalent human chromosomal disorder, causing a range of
# cardiovascular, musculoskeletal, and neurological abnormalities. However, the cellular …
#
# The primary cilium in neural stem cells plays distinct roles in different stages during cortical
# development. Ciliary dysfunctions in human (ie, ciliopathy) cause developmental defects in …
#
# In the absence of Hedgehog ligand, patched-1 (Ptch1) localizes to cilia and prevents ciliary
# accumulation and activation of smoothened (Smo). Upon ligand binding, Ptch1 is removed …
#
# Sonic hedgehog (Shh) determines cerebellar granule cell (GC) progenitor proliferation and
# medulloblastoma pathogenesis. However, the pathways regulating GC progenitors during …
#
# The mechanisms underlying subcellular targeting of cAMP-generating adenylyl cyclases
# and processes regulated by their compartmentalization are poorly understood. Here, we …
#
# Primary cilia are ubiquitous sensory organelles that mediate diverse signaling pathways.
# Cilia position on the cell surface is determined by the location of the basal body (BB) that …
#
# Defects in primary cilia, cellular antennas that control multiple intracellular signaling pathways,
# underlie several neurodevelopmental disorders, but it remains unknown how cilia control …
#
# Primary cilia perceive the extracellular environment through receptors localized in the ciliary
# membrane, but mechanisms directing specific proteins to this domain are poorly understood…
#
# Cilia are organelles specialized for movement and signaling. To infer when during evolution
# signaling pathways became associated with cilia, we characterized the proteomes of cilia …
#
# Mutations in the Abelson-helper integration site 1 (AHI1) gene are associated with
# neurological/neuropsychiatric disorders, and cause the neurodevelopmental ciliopathy Joubert …
#
# Trisomy 21, the genetic cause of Down syndrome, disrupts primary cilia formation and function,
# in part through elevated Pericentrin, a centrosome protein encoded on chromosome 21. …
#
# … NeuroMab, a joint facility of the University of California-Davis and the NIH (http://www.neuromab.…
# Two mAbs were produced from the A3 VCD fusion: N144/17 (anti-A3), which is specific …
#
# Neuregulin 1 (NRG1) is a neuron-derived trophic molecule that supports axoglial and
# neuromuscular development through several alternatively spliced isoforms; its possible role in the …
#
# … Use of the type III (cysteine-rich domain) specific antibody (clone N126B/31, UC Davis/NIH
# NeuroMab facility) was as described previously (Citation6). …
#
# Classical accommodation is a form of spike frequency adaptation in neurons whereby
# excitatory drive results in action potential output of gradually decreasing frequency. Here we …
#
# C-type synaptic boutons (C-boutons) provide cholinergic afferent input to spinal cord motor
# neurons (MNs), which display an endoplasmic reticulum (ER)–related subsurface cistern (…
#
# … were purchased from the UC Davis/NIH NeuroMab facility: AnkG (106/36; RRID:AB_10673030),
# AnkG (106/65; RRID:AB_10675130), PanNav (N419/78; RRID:AB_2493099), b1 …
#
# Skeletal muscle contraction depends on activation of clustered acetylcholine receptors (AchRs)
# and muscle-specific Na + channels (Nav1.4). Some Nav1.4 channels are highly …
#
# … The following monoclonal primary antibodies were purchased from the UC Davis/NIH
# NeuroMab facility: AnkG (106/36; RRID: AB_10673030), Pan-Nav1 (N419/78; RRID: AB_2493099)…
#
# Neuronal ankyrins cluster and link membrane proteins to the actin and spectrin-based
# cytoskeleton. Among the three vertebrate ankyrins, little is known about neuronal Ankyrin-R (AnkR…
#
# The axon initial segment (AIS) is a highly specialized axonal compartment where the action
# potential is initiated. The heterogeneity of AISs has been suggested to occur between …
#
# Mutations of the cyclin-dependent kinase-like 5 (CDKL5) and netrin-G1 (NTNG1) genes
# cause a severe neurodevelopmental disorder with clinical features that are closely related to …
#
# … Mouse monoclonal anti-PSD-93 (N18/30) and anti-ADAM22 (cytoplasmic, N46/30; extracellular,
# N57/2) were obtained from the University of California Davis/NIH NeuroMab Facility and …
#
# Disruption of axon‐glia interactions in the peripheral nervous system has emerged as a major
# cause of arthrogryposis multiplex congenita (AMC), a condition characterized by multiple …
#
# … A mouse monoclonal anti-SNAT1 antibody (N104/37; NeuroMabs, UC Davis, like the rabbit
# … background staining (Figure S1) and therefore N104/37 was used. Free-floating sections …
#
# … The LRRTM4 monoclonal antibody N205B/22 was developed with the UC Davis/NIH
# NeuroMab Facility. Mono- and disaccharide analysis of GPC4-Fc was performed by the UCSD …
#
# Synaptic cell-adhesion molecules (CAMs) organize the architecture and properties of neural
# circuits. However, whether synaptic CAMs are involved in activity-dependent remodeling of …
#
# Presynaptic neurexins (Nrxs) and type IIa receptor-type protein tyrosine phosphatases (RPTPs)
# organize synapses through a network of postsynaptic ligands. We show that leucine-rich-…
#
# LRRTMs are postsynaptic cell adhesion proteins that have region-restricted expression in the
# brain. To determine their role in the molecular organization of synapses in vivo, we studied …
#
# LRRTM4 is a transsynaptic adhesion protein regulating glutamatergic synapse assembly on
# dendrites of central neurons. In the mouse retina, we find that LRRTM4 is enriched at …
#
# The four members of the LRRTM family (LRRTM1-4) are postsynaptic adhesion molecules
# essential for excitatory synapse development. They have also been implicated in …
#
# … The monoclonal antibody vGluT3 was obtained from the UC Davis/NIH NeuroMab Facility,
# supported by NIH grant U24NS050606 and maintained by the Department of Neurobiology, …
#
# … (N29/29), VGLUT3 (N34/34), as well as the mouse monoclonal antibody for VAChT (N6/38)
# were purchased from Antibodies Incorporated (UC Davis/NIH NeuroMab Facility, Davis, CA). …
#
# Glutamate and its receptor N-methyl-D-aspartate receptor (NMDAR) have been associated
# with cancer, although their functions are not fully understood. Herein, we implicate glutamate-…
#
# The Foxi3 transcription factor, expressed in the neural plate border at the end of gastrulation,
# is necessary for the formation of posterior placodes and is thus important for ectodermal …
#
# … The mouse monoclonal antibody K88-64 that we used was … Unexpectedly, we showed that
# the Mab K88-64 has a very … the UC Davis/NINDS/NIMH NeuroMab Facility, supported by NIH …
#
# Cortactin-binding protein 2 (CTTNBP2) interacts with cortactin to regulate cortactin mobility
# and control dendritic spine formation. CTTNBP2 has also been associated with autistic …
#
# … Syt3 NB is a monoclonal antibody from Neuromab, and Syt3 NT is a polyclonal antibody
# developed by Synaptic Systems. Tubulin is a loading control. (B) Syt3 immunoreactivity is …
#
# A hallmark of inflammatory diseases is the excessive recruitment and influx of monocytes to
# sites of tissue damage and their ensuing differentiation into macrophages. Numerous stimuli …
#
# … monoclonal antibodies that specifically target QKI-5 (N195A/16), QKI-6 (N182/17), or QKI-7
# (N183/15.1; UC Davis/NIH NeuroMab Facility). Mouse monoclonal antibodies were used to …
#
# Alternative splicing is critical for animal ontogeny; however, its role in the earliest developmental
# decision, the specification of the three embryonic germ layers, is poorly understood. By …
#
# … (APC-021; d) and a mouse monoclonal (L6/23; e) antibody against the BK channel. f, The …
# (APC-021 recognizes an epitope between amino acid residues 1089 and 1196, and L6/23 …
#
# … (APC-021; d) and a mouse monoclonal (L6/23; e) antibody against the BK channel. f, The …
# (APC-021 recognizes an epitope between amino acid residues 1089 and 1196, and L6/23 …
#
# α-Synucleinopathies are spreading neurodegenerative disorders characterized by the
# intracellular accumulation of insoluble aggregates populated by α-Synuclein (α-Syn) fibrils. In …
#
# A hallmark of inflammatory diseases is the excessive recruitment and influx of monocytes to
# sites of tissue damage and their ensuing differentiation into macrophages. Numerous stimuli …
#
# Alternative splicing is critical for animal ontogeny; however, its role in the earliest developmental
# decision, the specification of the three embryonic germ layers, is poorly understood. By …
#
# … N121A/1 and N121A/31) were generated by UC Davis/NIH NeuroMab Facility (Davis, CA, …
# Panx2 monoclonal antibodies (N121A/1 and N121A/31) by showing that both clones identified …
#
# Pannexins (PANX) are a family of three channel-forming membrane glycoproteins expressed
# in the skin. Previous studies have focused on the role of PANX1 and PANX3 in the …
#
# Traumatic brain injury (TBI) can result in the development of posttraumatic epilepsy (PTE).
# Recently, we reported differential alterations in tonic and phasic GABA A receptor (GABA A R) …
#
# … NeuroMab N423/75. In all cases duplicate immunoblots were probed the anti-Mortalin/GRP75
# NeuroMab N52A/42 … in which the anti-pan-KChIP NeuroMab K55/82 was used to show the …
#
# Developmental and epileptic encephalopathies (DEE) are a group of severe epilepsies that
# usually present with intractable seizures, developmental delay, and often have elevated risk …
#
# … (NeuroMab N52A/42; RRID:2120479; 1 μg/mL), which served as a normalization control.
# Anti-rabbit Alexa Fluor 790 and anti-mouse 680 antibodies (Jackson ImmunoResearch, 1:…
#
# … (1:500; KC; RRID: AB_2315767) and as loading controls mouse anti-mortalin (1:2, N52A/42
# tissue culture supernatant; RRID: AB_10674108, from the UC Davis/NIH NeuroMab Facility) …
#
# Transient receptor potential melastatin-like 4 (TRPM4) is a Ca 2+ -activated non-selective
# cation channel expressed in a wide range of human tissues. TRPM4 participates in a variety of …
#
# Neuroinflammation plays a fundamental role in the pathogenesis of Alzheimer's disease (AD),
# resulting in the extensive activation of microglial and astroglial cells. Here we describe the …
#
# Voltage-gated K + (Kv) channels play important roles in regulating neuronal excitability. Kv
# channels comprise four principal α subunits, and transmembrane and/or cytoplasmic …
#
# The plasma membrane (PM) comprises distinct subcellular domains with diverse functions
# that need to be dynamically coordinated with intracellular events, one of the most impactful …
#
# TRPM4 is a Ca2+-activated non-selective cation channel expressed in a wide range of
# human tissues. TRPM4 participates in a variety of physiological processes such as T cell …
#
# … (K7/45) and Mortalin/Grp75 (N52A/42) using monoclonal antibodies (clone number in
# parentheses) obtained from the UC Davis/NIH NeuroMab Facility. Alexa-conjugated fluorescent …
#
# … N52A/42; NeuroMab), and subsequently with goat anti-mouse or anti-rabbit IgG–HRP
# secondary antibodies (1:10,000; Antibodies Inc.). Immunoreactive proteins on membranes were …
#
# … , including at the UC Davis/NIH NeuroMab Facility, we have generated a large collection of
# … The plasmid backbone was generated by EcoRI/HindIII restriction digestion of the N52A/42 …
#
# … For immunoblots we used anti-Grp75/mortalin mAb N52A/42 (UC Davis/NIH NeuroMab
# Facility, Davis, CA, USA) or otubulin (T5168, Sigma, St Louis, MO, USA) as a loading control. …
#
# … subunits (1:1000-500, Clone N52A/42) were obtained from Sigma-Aldrich and the UC
# Davis/NIH NeuroMab facility, respectively. Control immunoprecipitations were performed using a …
#
# The neurodevelopmental factor dysbindin is required for synapse function and GABA
# interneuron development. Dysbindin protein levels are reduced in the hippocampus of …
#
# Errors in replication or segregation lead to DNA damage, mutations, and aneuploidies.
# Consequently, cells monitor these events and delay progression through the cell cycle so repair …
#
# Charcot-Marie-Tooth (CMT) disease 4A is an autosomal-recessive polyneuropathy caused
# by mutations of ganglioside-induced differentiation-associated protein 1 (GDAP1), a putative …
#
# … , including at the UC Davis/NIH NeuroMab Facility, we have generated a large collection of
# … The plasmid backbone was generated by EcoRI/HindIII restriction digestion of the N52A/42 …
#
# … 1b (N16B/8, NeuroMab, San Diego, CA), rabbit polyclonal anti-Kv3.1b (laboratory-generated),
# mouse monoclonal anti-mortalin (N52A/42, NeuroMab), mouse monoclonal anti-HA tag (…
#
# … For immunoblots we used anti-Grp75/mortalin mAb N52A/42 (UC Davis/NIH NeuroMab
# Facility, Davis, CA, USA) or otubulin (T5168, Sigma, St Louis, MO, USA) as a loading control. …
#
# Recent studies have underscored the importance of C5a and other complement components
# in inflammatory and neuropathic pain, although the underlying mechanisms are largely …
#
# The disc-large (DLG)–membrane-associated guanylate kinase (MAGUK) family of proteins
# forms a central signaling hub of the glutamate receptor complex. Among this family, some …
#
# Genetic variants in SCN2A, encoding the Na V 1.2 voltage-gated sodium channel, are
# associated with a range of neurodevelopmental disorders with overlapping phenotypes. Some …
#
# … GRP75 was used as a loading control and probed with a monoclonal anti-GRP75 antibody
# (1:2000; clone N52A/42; Neuromab). The membranes were then washed with TBS and …
#
# Dynamic modulation of ion channel expression, localization, and/or function drives plasticity
# in intrinsic neuronal excitability. Voltage-gated Kv2.1 potassium channels are constitutively …
#
# … The mouse mAbs N52A/42, K13/31, K89/34, L83/11, L86/33, and L86A/37 are available
# from the UC Davis/NIH NeuroMab Facility (http://neuromab.ucdavis.edu/), a not-for profit …
#
# … (N372B/60) and Grp75/Mortalin (N52A/42) using mAbs (clone number in parentheses)
# obtained from the UC-Davis/NIH NeuroMab Facility (http://neuromab.ucdavis.edu/), a not-for profit …
#
# Skeletal muscle contraction depends on activation of clustered acetylcholine receptors (AchRs)
# and muscle-specific Na + channels (Nav1.4). Some Nav1.4 channels are highly …
#
# … Mouse Mono K89/34 Amino acids 837–853 ratHMLPGGGAHGSTRDQSI NeuroMab 75-014 …
# Ankyrin-G Mouse Mono N106/65 full length human NeuroMab 75–147 Purified IgG 10 μg/…
#
# … encoding functional recombinant K89/34 mAb (IgG2a). Recombinant K89/34 was produced
# … Sections were labeled free floating and probed with K89/34 IgG1 antibody diluted in vehicle …
#
# … Briefly, Kv2.1 and Kv2.2 expression was characterized using the K89/34 (for Kv2.1) and
# N372B/1 or N372B/60 (for Kv2.2) antibodies (both from NeuroMab) in 4 Thy1 mice (P26–P42) (…
#
# Objective: To perform functional characterization of a potentially pathogenic KCNB1 variant
# identified by clinical exome sequencing of a proband with a neurodevelopmental disorder …
#
# … Immunocytochemistry We stained organotypic slices with the Neuromab Kv2.1 monoclonal
# antibody (K89/34). Slices contained non-transfected cells and cells with GFP fluorescence, …
#
# … (K89/34). Sections were then incubated with fluorescein isothiocyanate-conjugated or cyanine
# 3-conjugated secondary antibodies (Jackson ImmunoResearch, West Grove, PA). Images …
#
# … with an anti-K v 2.1 (K89/34) mAb in order to detect the … with an anti-K v 2.1 (K89/34)
# mAb. The DTDP-induced tyrosine … with anti-K v 2.1 (K89/34, NeuroMab, CA, USA) and in-house …
#
# … (K89/34) mAb. Tyrosine phosphorylation of the Kv2.1 channel was detected using an anti-…
# (K89/34) mAb. PV treatments induced tyrosine phosphorylation of Kv2.1-WT, Kv2.1-…
#
# … K89/34 (green) antibodies in cerebral cortex of CO 2 -treated (2 min) mouse… (K89/34 and
# K39/25), Kv1.2 (K14/16) and PSD-95 (K28/43) were obtained from the UC Davis/NIH NeuroMab …
#
# … Neurons were then incubated with the Kv2.1 primary antibody K89/34 (NeuroMab) and a
# GFP primary antibody (A10262, Invitrogen) overnight at 4 C. Cells were washed three times …
#
# … K89/34 can be obtained from NeuroMab (www.neuromab.org… S563P or S603P together
# with K89/34. The sections were then … with S563P or S603P together with K89/34, and Alexa-…
#
# … at the UC Davis/NIH NeuroMab Facility, we have generated a … These monoclonal K89/34
# cell lines have been expanded … of the various K89/34 subclones archived at different times. …
#
# The microtubule-associated axonal specification collapsin response mediator protein 2 (CRMP2)
# is a novel target for neuroprotection. A CRMP2 peptide (TAT-CBD3) conjugated to the …
#
# Objective Numerous studies have demonstrated increased load of de novo copy number
# variants or single nucleotide variants in individuals with neurodevelopmental disorders, …
#
# … (K7/45) and Mortalin/Grp75 (N52A/42) using monoclonal antibodies (clone number in
# parentheses) obtained from the UC Davis/NIH NeuroMab Facility. Alexa-conjugated fluorescent …
#
# Lysosomes communicate through cholesterol transfer at endoplasmic reticulum (ER) contact
# sites. At these sites, the Niemann Pick C1 cholesterol transporter (NPC1) facilitates the …
#
# ...
# 1 h. For double labeling, a cocktail of secondary antibodies (Alexa 555-conjugated goat anti…
#
# Intracellular Fibroblast Growth Factor 14 (iFGF14) and the other intracellular FGFs (iFGF11-13)
# regulate the properties and densities of voltage-gated neuronal and cardiac Na + (Nav) …
#
# … A monoclonal antibody anti-GABAB1 (Clone N93A/49; NeuroMab, Davis, CA, USA) and
# anti-GABAB2 (Clone N81/37; NeuroMab) were used. A guinea-pig polyclonal antibody anti-…
#
# Genes with multiple co-active promoters appear common in brain, yet little is known about
# functional requirements for these potentially redundant genomic regulatory elements. SCN1A, …
#
# … -reactivity validated by NeuroMab. Antibodies N257/25 and … The subclone N262/16 raised
# against the hapten 4 showed … Given these results, N257/25.1.1 and N262/16 represent …
#
# Key points This paper provides a comprehensive electrophysiological characterization of the
# external [K + ] dependence and inward rectifying properties of Kir channels in fast skeletal …
#
# Gamma aminobutyric acid (GABA) subtype A receptors (GABA A Rs) are integral membrane
# ion channels composed of five individual proteins or subunits. Up to 19 different GABA A R …
#
# Impaired inhibitory signaling underlies the pathophysiology of many neuropsychiatric and
# neurodevelopmental disorders including autism spectrum disorders and epilepsy. Neuronal …
#
# Retromer is an evolutionarily conserved endosomal trafficking complex that mediates the
# retrieval of cargo proteins from a degradative pathway for sorting back to the cell surface. To …
#
# Multiple trans-synaptic complexes organize synapse development, yet their roles in the
# mature brain and cooperation remain unclear. We analyzed the postsynaptic adhesion protein …
#
# … PSD-95 (K28/43) and SAP97 (N19/2) antibodies were obtained from Neuromab. ERK 1/2
# (extracellular signal-regulated kinase 1/2) antibody was purchased from Cell Signaling …
#
# … Anti-PSD95/SAP90 antibody (K28/43) and SAP102 (N19/2) was purchased from
# University of California Davis/National Institutes of Health (NIH) NeuroMab facility. Anti-α-tubulin …
#
# Neurodevelopmental disorders such as autism spectrum disorders and schizophrenia
# differentially impact males and females and are highly heritable. The ways in which sex and …
#
# Classical cadherins, a set of ~20 related recognition and signaling molecules, have been
# implicated in many aspects of neural development, including the formation and remodeling of …
#
# Sensitive and specific antibodies are essential for detecting molecules in cells and tissues.
# However, currently used polyclonal and monoclonal antibodies are often less sensitive than …
#
# In tauopathic conditions, such as Alzheimer's disease (AD), highly soluble and natively
# unfolded tau polymerizes into an insoluble filament; however, the mechanistic details of this …
#
# Glycoprotein M6B and the closely related proteolipid protein regulate oligodendrocyte
# myelination in the central nervous system, but their role in the peripheral nervous system is less …
#
# Myelin is a highly specialized structure, organized into short periodical segments, which are
# extensions of the Schwann cell membrane in the peripheral nervous system (PNS). Myelin …
#
# The ability of dendritic spines to change size and shape rapidly is critical in modulating synaptic
# strength; these morphological changes are dependent upon rearrangements of the actin …
#
# … Anti–PAN MAGUK antibody (clone K28/86) and anti-SAP97 antibody (clone K64/15) were
# purchased from the University of California Davis/NIH NeuroMab Facility. Anti–human SAP97 …
#
# … 407140), and 3) monoclonal mouse anti-IP3 receptor clone L24/18, obtained from the
# UC Davis/NIH NeuroMab Facility, University of California, Davis (catalog No. 75-035). …
#
# The GABA-B receptor is densely expressed throughout the brain and has been implicated in
# many CNS functions and disorders, including addiction, epilepsy, spasticity, schizophrenia, …
#
# … , N6/38) from NeuroMab; mouse anti-SATB2 (clone, 4B19) from Abcam; rabbit anti-fluorescein
# (Life Technologies); and rabbit anti-protein kinase C alpha (P4334) from Sigma. Rabbit …
#
# … , N6/38) from NeuroMab (Davis, CA); mouse anti-protein kinase C- α (PKCα) (clone MC5)
# and rabbit anti-PKCα (P4334) from Sigma; rabbit anti-Opn4 from Thermo Fisher (PA1-780), …
#
# … with 0.1% Triton X-100 in Tris-buffered saline (TBS), blocked in 5% horse serum in TBS (vehicle),
# and incubated overnight in vehicle containing K55/7 (anti-KChIP1) or K75/30 (anti-Kv4.…
#
# The ENU-induced neurological mutant ataxia3 was mapped to distal mouse chromosome
# 15. Sequencing of the positional candidate gene Scn8a encoding the sodium channel Na v …
#
# … (A) Representative images of the sensory epithelia showing cristae immunolabeled with the
# K65/35 anti-CASPR1 antibody (green) and the AB19013 anti-tenascin antibody (red). In the …
#
# … Trimmer, University of California, Davis, CA) and/or mouse monoclonal anti-Caspr (K65/35)
# antibody (1:500 dilution in vehicle; UC Davis/NIH NeuroMab Facility). Subsequently, …
#
# Action potential initiation and propagation in myelinated axons require ion channel clustering
# at axon initial segments (AIS) and nodes of Ranvier. Disruption of these domains after …
#
# … anti-CASPR1 (clone K65/35, RRID: AB_2083496, used at 1:400 dilution) and anti-PSD95
# (clone K28/43, RRID: AB_2292909, 1:100) from the UC Davis/NIH NeuroMab Facility; mouse …
#
# … -associated protein (Caspr1) (clone K65/35, IgG1, cat. # 75–001) and anti-PSD95 (clone
# K28/43, IgG2a, cat# 75–028) from Neuromab. We used the following secondary antibodies …
#
# Astrocytes, once considered passive support cells, are increasingly appreciated as dynamic
# regulators of neuronal development and function, in part via secreted factors. The extent to …
#
# … QKI was immunoprecipitated with a QKI-5 specific (Bethyl, A300-183A) or panQKI (Neuromab,
# N147/6) antibodies and sequencing libraries prepared including a size matched input …
#
# … Mouse anti-GFP (University of California at Davis/NIH NeuroMab Facility, Davis, CA;
# abbreviated NeuroMab; Cat. no. 75-132, clone N86/38, RRID:AB_10672529) was generated …
#
# The strength of synaptic inhibition can be controlled by the stability and endocytosis of
# surface and synaptic GABA A receptors (GABA A Rs), but the surface receptor dynamics that …
#
# … The monoclonal anti-PSD95 (clone K28/43), GABA B R1 (clone NR3A/49) and GABA B R2
# (clone N81/2) antibodies were obtained from the UC Davis/NIH NeuroMab Facility, supported …
#
# … Mouse monoclonal antibodies were developed by UC Davis/NIH NeuroMab Facility in mouse
# generating hybridomas. The anti-GABAAR α1 mouse monoclonal antibody (clone N95/35 …
#
# The axon initial segment (AIS) contains the site of action potential initiation and plays a
# major role in neuronal excitability. AIS function relies on high concentrations of different ion …
#
# Purpose Intracellular free calcium ions (Ca 2+) are an important element in retinal ganglion
# cell response. Two major EF-hand (E-helix-loop-F-helix-hand) calcium binding proteins in …
#
# Proteins that interact with voltage-gated sodium (Na v ) channels are important in channel
# sorting and modulation. In this study, we identified the transcriptional regulator, Sin3B, as a …
#
# Purpose: Recent studies indicate the presence of functional voltage-gated sodium channels
# (Na v channels) in the distal retina in several species. This study examined the distribution …
#
# Purpose: Recent studies indicate the presence of functional voltage-gated sodium channels
# (Nav channels) in the distal retina in several species. This study examined the distribution of …
#
# In neurons, voltage-gated sodium channel β subunits regulate the expression levels, subcellular
# localization, and electrophysiological properties of sodium channel α subunits. However…
#
# … ) and mouse monoclonal (clone K74/71, NeuroMab) antibodies raised respectively against
# … monoclonal (clone K87A/10, NeuroMab) antibodies raised respectively against amino acids …
#
# Alzheimer's disease (AD) is the most frequent neurodegenerative disease and a common
# dementia in elderly individuals. Previous studies found a strong correlation between axon …
#
# The axon initial segment (AIS) plays an important role in maintaining neuronal polarity and
# initiating action potentials (APs). The AIS adapts to its environment by changing its length and …
#
# Cerebellar granule (CG) cells generate high‐frequency action potentials that have been
# proposed to depend on the unique properties of their voltage‐gated ion channels. To address …
#
# Precise axon pathfinding is crucial for establishment of the initial neuronal network during
# development. Pioneer axons navigate without the help of preexisting axons and pave the way …
#
# … The anti-neurofascin antibody (extNF; A12/18, 75-172) and anti-Nav1.2 antibody (K69/3)
# were obtained from NeuroMab (USA). The anti-ankyrin G antibody (33-8800) was purchased …
#
# The role played by the transient receptor potential vanilloid 1 (TRPV1) channel on the thin
# fibre afferents evoking the exercise pressor reflex is controversial. To shed light on this …
#
# Dopamine‐ and tyrosine hydroxylase–immunopositive cells (TH cells) modulate visually
# driven signals as they flow through retinal photoreceptor, bipolar, and ganglion cells. Previous …
#
# Growth of a properly complex dendrite arbor is a key step in neuronal differentiation and a
# prerequisite for neural circuit formation. Diverse cell surface molecules, such as the clustered …
#
# … :500–1:1000) were generated by NeuroMab in collaboration with the Weiner laboratory [55] …
# ); N148/30 (specific for γB2); N174B/27 (specific for γC3). A rabbit polyclonal antibody raised …
#
# SLITRK1 is an obsessive-compulsive disorder spectrum-disorders-associated gene that
# encodes a neuronal transmembrane protein. Here we show that SLITRK1 suppresses …
#
# … Anti-vesicular glutamate transporter 1 (VGLUT1; NeuroMAB, University of California,
# Davis, Davis, CA; clone N28/9), a mouse monoclonal antibody, raised against fusion protein …
#
# The proper formation and maintenance of functional synapses in the central nervous system
# (CNS) requires communication between neurons and astrocytes and the ability of …
#
# Brain-derived neurotrophic factor (BDNF) signals through its high affinity receptor Tropomyosin
# receptor kinase-B (TrkB) to regulate neuronal development, synapse formation and …
#
# The accumulation of insoluble amyloid-beta (Aβ) peptides is associated with neurodegenerative
# disorders, such as Alzheimer's disease (AD). As essential tremor (ET) could involve …
#
# PPM1H phosphatase reverses Parkinson's disease-associated, LRRK2-mediated Rab
# GTPase phosphorylation. We show here that PPM1H relies on an N-terminal amphipathic helix …
#
# Mutations in the leucine-rich repeat kinase-2 (LRRK2) gene cause late-onset Parkinson’s
# disease, but its physiological function has remained largely unknown. Here we report that …
#
# Mutations and variations in the leucine-rich repeat kinase 2 (LRRK2) gene are strongly
# associated with an increased risk to develop Parkinson’s disease (PD). Most pathogenic LRRK2 …
#
# … The panel shows a TEM image of uEVs and dual immunogold labeling with anti-LRRK2
# antibodies (RabMab UDD3 and Neuromab N241, revealed by large and small gold particles, …
#
# Parkinson disease (PD) is the most common neurodegenerative movement disorder for which
# no treatments exist capable of slowing progression of the disease. One obstacle slowing …
#
# … For blots, primary antibodies used were: Mouse anti-total LRRK2 (Neuromab N241A/34),
# Rabbit antiLRRK2 pS935 (UDD2 10(12), MRC PPU Reagents and Services, or ab133450, …
#
# The Parkinson’s VPS35[D620N] mutation causes lysosome dysfunction enhancing LRRK2
# kinase activity. We find the VPS35[D620N] mutation alters expression of ∼350 lysosomal …
#
# … The whole brain crude membrane fractions from WT (2 μg total protein) and KI (20 μg total
# protein) mice were analyzed with an anti-PSD-95 K28/43 antibody. F, Immunohistochemical …
#
# Compact myelin, the paranode, and the juxtaparanode are discrete domains that are formed
# on myelinated axons. In humans, neurological disorders associated with loss of myelin, …
#
# Ionotropic neurotransmitter receptors mediate fast synaptic transmission by functioning as
# ligand-gated ion channels. Fast inhibitory transmission in the brain is mediated mostly by …
#
# Autism spectrum disorder (ASD) is a neurological condition characterized by difficulties in
# social 22 interaction, communication, and behavior. The classical type II cadherins cadherin-8 (…
#
# AMPA receptors and interacting proteins are importantly involved in mediating stress-dependent
# plasticity. Previously we reported that GluA1-containing AMPA receptors and their …
#
# Calsyntenin-3 (Clstn3) is a postsynaptic adhesion molecule that induces presynaptic
# differentiation via presynaptic neurexins (Nrxns), but whether Nrxns directly bind to Clstn3 has …
#
# Gephyrin is a central scaffold protein that mediates development, function, and plasticity of
# mammalian inhibitory synapses by interacting with various inhibitory synaptic proteins. Here, …
#
# Depolarization drives neuronal plasticity. However, whether depolarization drives
# sensitization of peripheral nociceptive neurons remains elusive. By high-content screening (HCS) …
#
# … The NeuroMab KChIP1 antibody stained a double band with … The NeuroMab KChIP2 antibody
# stained a single band with a … The NeuroMab KChIP3 antibody stained a single band with …
#
# … The specificity of each of the primary antibodies has been verified using Western blots
# from brain tissue by the UC, Davis/NeuroMab Facility and also in our laboratory in BLA tissue …
#
# … Mouse anti-KChIP1 (University of California at Davis / NIH NeuroMab Facility, Davis, CA;
# abbreviated NeuroMab; Cat. no. 75-003, clone K55/7, RRID:AB_10673162) was generated …
#
# Potassium channels comprise the most diverse family of ion channels. In nerve cells, their
# critical roles in synaptic integration and output generation have been demonstrated. Here, we …
#
# … We used the following primary antibodies from NeuroMab (UC Davis/NIH, Davis, CA,
# USA): (1) monoclonal anti-Kv4.2 (K57/1; amino acid. 209–225 of human Kv4.2, Q9NZV8), (2) …
#
# … The Ms mAb to pan-Pcdh-γ (clone N159/5, to amino acids 808–931 of the constant
# cytoplasmic domain of mouse Pcdh-γA1 that is shared by all 22 Pcdh-γs) and the Ms mAb to pan-…
#
# It has been proposed that the combinatorial expression of γ‐protocadherins (Pcdh‐γs) and
# other clustered protocadherins (Pcdhs) provides a code of molecular identity and individuality …
#
# … The mouse anti-γ-Pcdh constant domain (N159/5) and mouse anti-γ-Pcdh-B2 (N148/30)
# were generated by the UC Davis/NIH NeuroMab Facility using antigens produced in our …
#
# Hyperpolarisation-activated (I h ) currents are considered important for dendritic integration,
# synaptic transmission, setting membrane potential and rhythmic action potential (AP) …
#
# Kv4 channels mediate most of the somatodendritic subthreshold operating A‐type current (I
# SA ) in neurons. This current plays essential roles in the regulation of spike timing, repetitive …
#
# … Immunodetections of K v 4.2 and K v 4.3 channels were performed using monoclonal
# antibodies from Neuro Mab (clones K57/1 and K75/41, respectively). These antibodies have been …
#
# … -S2 loop, Q9NZV8; NeuroMab, UC Davis/NIH, Davis, CA, USA); monoclonal anti-Kv4.3 (K75/41;
# aa. 415–636 of rat Kv4.3, cytoplasmic C-terminus, Q62897; NeuroMab, UC Davis/NIH, …
#
# … K75/41 Neuromab; www.neuromab.org were used for immunolocalization experiments in
# brain. Immunoperoxidase [DPP6 antibodies diluted (1:1000); Kv4.2 (1:2000)] and …
#
# Inhibitory neurons control the firing of glutamatergic neurons and synchronize brain activity.
# However, little is known about mechanisms of excitatory synapse formation in inhibitory …
#
# Establishment, specification, and validation of synaptic connections are thought to be mediated
# by interactions between pre- and postsynaptic cell-adhesion molecules. Arguably, the …

# %% [markdown]
# # Final Output

# %% [markdown]
# ## TODO merge in the old outputs we are missing as well ~600 and talk to Jim about best strategy for those

# %%
import pandas as pd
# import BytesIO to read the data from the url
from io import BytesIO

# merge df_final and dfantiinc on the pmid columns do an outer join
df_final = pd.read_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/googlescholar_mabidsearch_pubmed.csv")
dfantiinc = pd.read_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/antibodiesinc_final.csv")
df_final = df_final.merge(dfantiinc, left_on='PMID', right_on='PMID_ID', how='outer')
# create a final mab_id column that takes all the unique values from the MABID column and the Antibody column
df_final['MAB_ID'] = df_final['MABID'].fillna(df_final['Antibody'])
df_final['PMID'] = df_final['PMID'].fillna(df_final['PMID_ID'])
df_final['PMID'] = df_final['PMID'].astype(int).astype(str)

# read the cfm file like before to get the target information
data = requests.get("https://neuromab.ucdavis.edu/catalog-download.cfm").content
df = pd.read_csv(BytesIO(data))

# for the MAB_ID column create a new column called target that is the target from the df where aall the clones match
for index, row in df_final.iterrows():
    # look for -f with a number after it with regex
    # get the list of clones in the df_final["MAB_ID"]
    clones = row["MAB_ID"].split(',')
    df_final.at[index, 'Target'] = df[df['Clone'].isin(clones)]['Target'].tolist()

# now add the pubmed dictionary columns to the df_final
df_cure = df_final[['MAB_ID', 'Target', 'PMID']]
# do another groupby on the PMID and join the Target column with a comma and the PMID column with a comma
# then ensure that the Target values are unique and the MAID_ID values are unique
# turn the list columns into strings with a comma by joining

for index, row in df_cure.iterrows():
    if type(row['Target']) == list:
        df_cure.at[index, 'Target'] = ', '.join(set(row['Target']))
    if type(row['MAB_ID']) == list:
        df_cure.at[index, 'MAB_ID'] = ', '.join(set(row['MAB_ID']))

# groupby the pmid and join the target and mab_id columns with a comma
df_cure = df_cure.groupby('PMID').agg({'MAB_ID': lambda x: ', '.join(x)
                                        , 'Target': lambda x: ', '.join(x)}).reset_index()

# now turn these back into a list and make sure they are unique
for index, row in df_cure.iterrows():
    if type(row['Target']) == str:
        df_cure.at[index, 'Target'] = set(row['Target'].split(', '))
    if type(row['MAB_ID']) == str:
        df_cure.at[index, 'MAB_ID'] = set(row['MAB_ID'].split(', '))

# add the citation column to the df_cure using the column output as a dictionary (citation title and year)
df_cure["citation"] = ""
df_cure["title"] = ""
df_cure["year"] = ""
for index, row in df_cure.iterrows():
    # look for -f with a number after it with regex
    # get the list of clones in the df_final["MAB_ID"]
    pmid = row["PMID"]
    record = fetch_details(pmid)
    # check if the record is a dictionary with the relevant keys
    if type(record) == dict and 'citation' in record and 'title' in record and 'year' in record:
        df_cure.at[index, 'citation'] = record['citation']
        df_cure.at[index, 'title'] = record['title']
        df_cure.at[index, 'year'] = record['year']
    else:
        print(f"For {pmid}, no record was found.")
        
df_cure
# Out:
# PubMed returned no pagination data for 20927324.
# PubMed returned no pagination data for 23894271.
# PubMed returned no pagination data for 25918844.
# Error fetching data from PubMed for 26186538.
# 'LastName'
# For 26186538, no record was found.
# Error fetching data from PubMed for 26381166.
# 'Volume'
# For 26381166, no record was found.
# PubMed returned no pagination data for 26559620.
# PubMed returned no pagination data for 26665164.
# PubMed returned no pagination data for 26883496.
# PubMed returned no pagination data for 27083044.
# PubMed returned no pagination data for 27091544.
# PubMed returned no pagination data for 27458797.
# PubMed returned no pagination data for 27525480.
# PubMed returned no pagination data for 27537197.
# PubMed returned no pagination data for 27677849.
# PubMed returned no pagination data for 27699209.
# PubMed returned no pagination data for 27787195.
# PubMed returned no pagination data for 27800545.
# PubMed returned no pagination data for 27935475.
# PubMed returned no pagination data for 28054918.
# PubMed returned no pagination data for 28060701.
# PubMed returned no pagination data for 28119464.
# PubMed returned no pagination data for 28130923.
# PubMed returned no pagination data for 28134616.
# PubMed returned no pagination data for 28139198.
# PubMed returned no pagination data for 28164368.
# PubMed returned no pagination data for 28263709.
# Error fetching data from PubMed for 28320946.
# 'AuthorList'
# For 28320946, no record was found.
# PubMed returned no pagination data for 28321439.
# PubMed returned no pagination data for 28381466.
# Error fetching data from PubMed for 28448009.
# 'Volume'
# For 28448009, no record was found.
# PubMed returned no pagination data for 28470148.
# PubMed returned no pagination data for 28512649.
# PubMed returned no pagination data for 28560311.
# PubMed returned no pagination data for 28584877.
# PubMed returned no pagination data for 28650316.
# PubMed returned no pagination data for 28660246.
# PubMed returned no pagination data for 28785724.
# PubMed returned no pagination data for 28816653.
# PubMed returned no pagination data for 28856240.
# PubMed returned no pagination data for 28875935.
# PubMed returned no pagination data for 28955722.
# PubMed returned no pagination data for 29028184.
# PubMed returned no pagination data for 29125462.
# PubMed returned no pagination data for 29138759.
# PubMed returned no pagination data for 29168692.
# PubMed returned no pagination data for 29173281.
# PubMed returned no pagination data for 29197141.
# PubMed returned no pagination data for 29199957.
# PubMed returned no pagination data for 29218323.
# PubMed returned no pagination data for 29306897.
# PubMed returned no pagination data for 29311134.
# PubMed returned no pagination data for 29361558.
# PubMed returned no pagination data for 29361569.
# PubMed returned no pagination data for 29391966.
# PubMed returned no pagination data for 29464191.
# PubMed returned no pagination data for 29504938.
# PubMed returned no pagination data for 29553369.
# PubMed returned no pagination data for 29592971.
# PubMed returned no pagination data for 29671737.
# PubMed returned no pagination data for 29676260.
# PubMed returned no pagination data for 29712715.
# PubMed returned no pagination data for 29726811.
# PubMed returned no pagination data for 29963618.
# PubMed returned no pagination data for 29996472.
# PubMed returned no pagination data for 30131441.
# PubMed returned no pagination data for 30225343.
# PubMed returned no pagination data for 30302388.
# PubMed returned no pagination data for 30377171.
# PubMed returned no pagination data for 30384417.
# PubMed returned no pagination data for 30396997.
# PubMed returned no pagination data for 30398148.
# Error fetching data from PubMed for 30451222.
# 'Volume'
# For 30451222, no record was found.
# PubMed returned no pagination data for 30463852.
# PubMed returned no pagination data for 30511640.
# PubMed returned no pagination data for 30538170.
# PubMed returned no pagination data for 30538174.
# PubMed returned no pagination data for 30545844.
# PubMed returned no pagination data for 30598502.
# PubMed returned no pagination data for 30634540.
# PubMed returned no pagination data for 30647193.
# PubMed returned no pagination data for 30667360.
# PubMed returned no pagination data for 30680309.
# PubMed returned no pagination data for 30862038.
# PubMed returned no pagination data for 30946007.
# PubMed returned no pagination data for 30974833.
# PubMed returned no pagination data for 31017573.
# PubMed returned no pagination data for 31023719.
# PubMed returned no pagination data for 31036155.
# PubMed returned no pagination data for 31042147.
# PubMed returned no pagination data for 31045576.
# Error fetching data from PubMed for 31107446.
# 'Volume'
# For 31107446, no record was found.
# PubMed returned no pagination data for 31142543.
# PubMed returned no pagination data for 31164339.
# PubMed returned no pagination data for 31268420.
# PubMed returned no pagination data for 31282864.
# PubMed returned no pagination data for 31331967.
# PubMed returned no pagination data for 31391239.
# PubMed returned no pagination data for 31403402.
# PubMed returned no pagination data for 31434643.
# PubMed returned no pagination data for 31609202.
# PubMed returned no pagination data for 31615899.
# PubMed returned no pagination data for 31615901.
# PubMed returned no pagination data for 31636080.
# PubMed returned no pagination data for 31658977.
# PubMed returned no pagination data for 31663850.
# PubMed returned no pagination data for 31663853.
# PubMed returned no pagination data for 31727776.
# Error fetching data from PubMed for 31816021.
# 'AuthorList'
# For 31816021, no record was found.
# PubMed returned no pagination data for 31820781.
# PubMed returned no pagination data for 31840160.
# PubMed returned no pagination data for 31910261.
# PubMed returned no pagination data for 31934859.
# PubMed returned no pagination data for 31934864.
# PubMed returned no pagination data for 31936259.
# PubMed returned no pagination data for 31947619.
# PubMed returned no pagination data for 31964774.
# PubMed returned no pagination data for 31985401.
# PubMed returned no pagination data for 32024240.
# PubMed returned no pagination data for 32033960.
# PubMed returned no pagination data for 32052742.
# PubMed returned no pagination data for 32129762.
# PubMed returned no pagination data for 32130108.
# PubMed returned no pagination data for 32202499.
# Error fetching data from PubMed for 32202516.
# 'Volume'
# For 32202516, no record was found.
# PubMed returned no pagination data for 32205379.
# Error fetching data from PubMed for 32250352.
# 'Volume'
# For 32250352, no record was found.
# PubMed returned no pagination data for 32260356.
# PubMed returned no pagination data for 32289157.
# PubMed returned no pagination data for 32290408.
# PubMed returned no pagination data for 32311044.
# PubMed returned no pagination data for 32410728.
# PubMed returned no pagination data for 32425157.
# PubMed returned no pagination data for 32435793.
# PubMed returned no pagination data for 32490811.
# PubMed returned no pagination data for 32553116.
# PubMed returned no pagination data for 32570968.
# PubMed returned no pagination data for 32604880.
# PubMed returned no pagination data for 32659913.
# PubMed returned no pagination data for 32675279.
# PubMed returned no pagination data for 32824677.
# PubMed returned no pagination data for 32840212.
# PubMed returned no pagination data for 32848094.
# PubMed returned no pagination data for 32899153.
# PubMed returned no pagination data for 32915137.
# PubMed returned no pagination data for 32917588.
# PubMed returned no pagination data for 32917708.
# PubMed returned no pagination data for 32937450.
# PubMed returned no pagination data for 32938678.
# PubMed returned no pagination data for 33006315.
# PubMed returned no pagination data for 33046507.
# PubMed returned no pagination data for 33083793.
# PubMed returned no pagination data for 33105624.
# PubMed returned no pagination data for 33113832.
# PubMed returned no pagination data for 33185190.
# PubMed returned no pagination data for 33188005.
# Error fetching data from PubMed for 33191931.
# 'Volume'
# For 33191931, no record was found.
# PubMed returned no pagination data for 33208499.
# PubMed returned no pagination data for 33229412.
# PubMed returned no pagination data for 33298440.
# PubMed returned no pagination data for 33333928.
# PubMed returned no pagination data for 33335032.
# Error fetching data from PubMed for 33350496.
# 'Volume'
# For 33350496, no record was found.
# PubMed returned no pagination data for 33361086.
# PubMed returned no pagination data for 33372037.
# PubMed returned no pagination data for 33373327.
# PubMed returned no pagination data for 33373328.
# PubMed returned no pagination data for 33401689.
# PubMed returned no pagination data for 33408125.
# PubMed returned no pagination data for 33441399.
# PubMed returned no pagination data for 33443209.
# PubMed returned no pagination data for 33472865.
# PubMed returned no pagination data for 33502442.
# PubMed returned no pagination data for 33568460.
# PubMed returned no pagination data for 33593893.
# PubMed returned no pagination data for 33650969.
# PubMed returned no pagination data for 33653948.
# PubMed returned no pagination data for 33656439.
# PubMed returned no pagination data for 33689678.
# PubMed returned no pagination data for 33689679.
# PubMed returned no pagination data for 33727250.
# Error fetching data from PubMed for 33732797.
# 'Initials'
# For 33732797, no record was found.
# PubMed returned no pagination data for 33801205.
# PubMed returned no pagination data for 33803465.
# PubMed returned no pagination data for 33837049.
# PubMed returned no pagination data for 34003113.
# Error fetching data from PubMed for 34057457.
# 'Volume'
# For 34057457, no record was found.
# PubMed returned no pagination data for 34061161.
# PubMed returned no pagination data for 34063992.
# PubMed returned no pagination data for 34065662.
# PubMed returned no pagination data for 34114604.
# PubMed returned no pagination data for 34131060.
# PubMed returned no pagination data for 34132778.
# PubMed returned no pagination data for 34135003.
# PubMed returned no pagination data for 34137443.
# PubMed returned no pagination data for 34156984.
# PubMed returned no pagination data for 34180393.
# PubMed returned no pagination data for 34261648.
# PubMed returned no pagination data for 34261657.
# PubMed returned no pagination data for 34269178.
# PubMed returned no pagination data for 34315807.
# PubMed returned no pagination data for 34346313.
# PubMed returned no pagination data for 34417170.
# PubMed returned no pagination data for 34429357.
# PubMed returned no pagination data for 34431981.
# PubMed returned no pagination data for 34452921.
# PubMed returned no pagination data for 34459572.
# PubMed returned no pagination data for 34463328.
# PubMed returned no pagination data for 34531281.
# PubMed returned no pagination data for 34546336.
# PubMed returned no pagination data for 34576197.
# PubMed returned no pagination data for 34610637.
# PubMed returned no pagination data for 34658337.
# PubMed returned no pagination data for 34658338.
# PubMed returned no pagination data for 34665127.
# PubMed returned no pagination data for 34759048.
# PubMed returned no pagination data for 34766907.
# PubMed returned no pagination data for 34799447.
# PubMed returned no pagination data for 34911751.
# PubMed returned no pagination data for 34914639.
# PubMed returned no pagination data for 34968236.
# PubMed returned no pagination data for 35022233.
# PubMed returned no pagination data for 35098924.
# PubMed returned no pagination data for 35131865.
# PubMed returned no pagination data for 35163623.
# PubMed returned no pagination data for 35201268.
# PubMed returned no pagination data for 35266954.
# PubMed returned no pagination data for 35269482.
# PubMed returned no pagination data for 35269919.
# PubMed returned no pagination data for 35326469.
# PubMed returned no pagination data for 35328381.
# PubMed returned no pagination data for 35346959.
# PubMed returned no pagination data for 35420982.
# PubMed returned no pagination data for 35441593.
# PubMed returned no pagination data for 35456979.
# PubMed returned no pagination data for 35550246.
# PubMed returned no pagination data for 35625761.
# PubMed returned no pagination data for 35626730.
# PubMed returned no pagination data for 35662394.
# PubMed returned no pagination data for 35671105.
# Error fetching data from PubMed for 35759110.
# 'Volume'
# For 35759110, no record was found.
# PubMed returned no pagination data for 35776681.
# PubMed returned no pagination data for 35803737.
# PubMed returned no pagination data for 35805070.
# PubMed returned no pagination data for 35806143.
# PubMed returned no pagination data for 35899529.
# PubMed returned no pagination data for 35972069.
# PubMed returned no pagination data for 36014775.
# PubMed returned no pagination data for 36040482.
# PubMed returned no pagination data for 36077460.
# PubMed returned no pagination data for 36139754.
# PubMed returned no pagination data for 36142639.
# PubMed returned no pagination data for 36149401.
# PubMed returned no pagination data for 36173683.
# PubMed returned no pagination data for 36274588.
# PubMed returned no pagination data for 36292621.
# PubMed returned no pagination data for 36302632.
# PubMed returned no pagination data for 36358921.
# PubMed returned no pagination data for 36421705.
# PubMed returned no pagination data for 36429074.
# PubMed returned no pagination data for 36458527.
# PubMed returned no pagination data for 36472910.
# Error fetching data from PubMed for 36482968.
# 'Volume'
# For 36482968, no record was found.
# PubMed returned no pagination data for 36519542.
# PubMed returned no pagination data for 36552754.
# PubMed returned no pagination data for 36606424.
# PubMed returned no pagination data for 36612049.
# PubMed returned no pagination data for 36631269.
# PubMed returned no pagination data for 36656118.
# PubMed returned no pagination data for 36661138.
# PubMed returned no pagination data for 36661357.
# PubMed returned no pagination data for 36672216.
# PubMed returned no pagination data for 36672247.
# PubMed returned no pagination data for 36697254.
# PubMed returned no pagination data for 36729040.
# PubMed returned no pagination data for 36795458.
# Error fetching data from PubMed for 36824888.
# 'Volume'
# For 36824888, no record was found.
# PubMed returned no pagination data for 36830639.
# PubMed returned no pagination data for 36833753.
# PubMed returned no pagination data for 36848492.
# Error fetching data from PubMed for 36945454.
# 'Volume'
# For 36945454, no record was found.
# PubMed returned no pagination data for 36951953.
# PubMed returned no pagination data for 36982541.
# Error fetching data from PubMed for 36997609.
# 'Volume'
# For 36997609, no record was found.
# PubMed returned no pagination data for 37048156.
# PubMed returned no pagination data for 37059474.
# PubMed returned no pagination data for 37108794.
# PubMed returned no pagination data for 37190086.
# PubMed returned no pagination data for 37288813.
# PubMed returned no pagination data for 37303235.
# Error fetching data from PubMed for 37333277.
# 'Volume'
# For 37333277, no record was found.
# Error fetching data from PubMed for 37333281.
# 'Volume'
# For 37333281, no record was found.
# PubMed returned no pagination data for 37408217.
# Error fetching data from PubMed for 37425759.
# 'Volume'
# For 37425759, no record was found.
# Error fetching data from PubMed for 37425856.
# 'Volume'
# For 37425856, no record was found.
# Error fetching data from PubMed for 37425915.
# 'Volume'
# For 37425915, no record was found.
# Error fetching data from PubMed for 37425946.
# 'Volume'
# For 37425946, no record was found.
# Error fetching data from PubMed for 37461609.
# 'Volume'
# For 37461609, no record was found.
# Error fetching data from PubMed for 37502980.
# 'Volume'
# For 37502980, no record was found.
# PubMed returned no pagination data for 37516919.
# Error fetching data from PubMed for 37577625.
# 'Volume'
# For 37577625, no record was found.
# PubMed returned no pagination data for 37642648.
# Error fetching data from PubMed for 37693426.
# 'Volume'
# For 37693426, no record was found.
# PubMed returned no pagination data for 37702787.
# PubMed returned no pagination data for 37756587.
# PubMed returned no pagination data for 37759527.
# PubMed returned no pagination data for 37800623.
# PubMed returned no pagination data for 37833914.
# PubMed returned no pagination data for 37843188.
# PubMed returned no pagination data for 37874635.
# PubMed returned no pagination data for 37891825.
# Error fetching data from PubMed for 37916792.
# 'Volume'
# For 37916792, no record was found.
# PubMed returned no pagination data for 37945352.
# Error fetching data from PubMed for 38014238.
# 'Volume'
# For 38014238, no record was found.
# Error fetching data from PubMed for 38038892.
# 'Volume'
# For 38038892, no record was found.
# PubMed returned no pagination data for 38137092.
# Error fetching data from PubMed for 38187582.
# 'Volume'
# For 38187582, no record was found.
# Error fetching data from PubMed for 38193537.
# 'Volume'
# For 38193537, no record was found.
# Error fetching data from PubMed for 38231269.
# 'Volume'
# For 38231269, no record was found.
# Error fetching data from PubMed for 38260608.
# 'Volume'
# For 38260608, no record was found.
#           PMID             MAB_ID                           Target  \
# 0     16525047    {K75/41, K55/7}               {Kv4.3 K+ channel}
# 1     16566008            {L6/60}   {Slo1/BKAlpha maxi-K+ channel}
# 2     16687515           {K73/20}                   {Contactin/F3}
# 3     16817858  {K87A/10, K65/35}             {Nav1.6 Na+ channel}
# 4     16870743          {K87A/10}             {Nav1.6 Na+ channel}
# ...        ...                ...                              ...
# 3818  38231269         {N241A/34}     {LRRK2/Dardarin, C-terminus}
# 3819  38239897          {N106/36}           {Ankyrin-G (staining)}
# 3820  38260608          {N106/36}           {Ankyrin-G (staining)}
# 3821   8853953           {L24/18}           {IP3 receptor, type 1}
# 3822   9383641           {L57/46}  {Cav1.2 + Cav1.3 Ca2+ channels}
#
#                                                citation  \
# 0     Kollo M, Holderith NB, Nusser Z. 2006. The Jou...
# 1     Misonou H, Menegola M, Buchwalder L et al.. 20...
# 2     Ogawa Y, Schafer DP, Horresh I et al.. 2006. T...
# 3     Rush AM, Wittmack EK, Tyrrell L et al.. 2006. ...
# 4     Lopez-Santiago LF, Pertin M, Morisod X et al.....
# ...                                                 ...
# 3818
# 3819  Tee J, Vitetta GM. 2023. Frontiers in computat...
# 3820
# 3821  Michikawa T, Miyawaki A, Furuichi T et al.. 19...
# 3822  Duridanova DB, Gagov HS, Dimitrov SD et al.. 1...
#
#                                                   title  year
# 0     Novel subcellular distribution pattern of A-ty...  2006
# 1     Immunolocalization of the Ca2+-activated K+ ch...  2006
# 2     Spectrins and ankyrinB constitute a specialize...  2006
# 3     Differential modulation of sodium channel Na(v...  2006
# 4     Sodium channel beta2 subunits regulate tetrodo...  2006
# ...                                                 ...   ...
# 3818
# 3819  Editorial: Advances in Shannon-based communica...  2023
# 3820
# 3821  Inositol 1,4,5-trisphosphate receptors and cal...  1996
# 3822  Main components of voltage-sensitive K+ curren...  1997
#
# [3823 rows x 6 columns]

# %%
# lets add the legacy info so iterate through the df and see if the pubmed is not in the df_cure, if not append it
df = pd.read_excel("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/publications 041922.xlsx")
# filter out anything that saays review in the clone
# remove all Pubmed that are empty
df = df[df['Pubmed'].notna()]
# set the Clone to a string column and remove any that are na
df['Clone'] = df['Clone'].astype(str)
df = df[df['Clone'] != 'nan']
df_cure["source"] = ""

for index, row in df.iterrows():
    # look for -f with a number after it with regex
    # get the list of clones in the df_final["MAB_ID"]
    pmid = str(row["Pubmed"]).split('.')[0]
    if pmid not in df_cure['PMID'].tolist():
        record = fetch_details(pmid)
        # check if the record is a dictionary with the relevant keys
        if type(record) == dict and 'citation' in record and 'title' in record and 'year' in record:
            
            # use the clone column for MAB_ID and the target column for Target just make them a set after splitting on the comma
            # check if both are not na first
            if type(row['Clone']) == str and type(row['Target']) == str:
                df_cure = df_cure.append({'PMID': pmid, 'citation': record['citation'], 'title': record['title'], 'year': record['year'], 'source':'legacy', 'MAB_ID': set(row['Clone'].split(', ')), 'Target': set(row['Target'].split(', '))}, ignore_index=True)
            else:
                df_cure = df_cure.append({'PMID': pmid, 'citation': record['citation'], 'title': record['title'], 'year': record['year'], 'source':'legacy', 'MAB_ID': row['Clone'], 'Target': row['Target']}, ignore_index=True)

        else:
            print(f"For {pmid}, no record was found.")


# now also iterate through the df_cure is not in the df, if so update the source column to google scholar unique
for index, row in df_cure.iterrows():
    # look for -f with a number after it with regex
    # get the list of clones in the df_final["MAB_ID"]
    pmid = str(row["PMID"])
    if pmid not in df['Pubmed'].astype(str).tolist():
        df_cure.at[index, 'source'] = 'google scholar unique'
# Out:
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:25: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# PubMed returned no pagination data for 22225533.
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# PubMed returned no pagination data for 25517933.
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Error fetching data from PubMed for 24077800.
# list index out of range
# For 24077800, no record was found.
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# ...
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# PubMed returned no pagination data for 31878108.
# PubMed returned no pagination data for 31433295.
# PubMed returned no pagination data for 30789343.
# PubMed returned no pagination data for 30396995.
# PubMed returned no pagination data for 30957013.
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# PubMed returned no pagination data for 31313987.
# PubMed returned no pagination data for 32033274.
# PubMed returned no pagination data for 32069266.
# PubMed returned no pagination data for 32217627.
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# PubMed returned no pagination data for 32341026.
# PubMed returned no pagination data for 32708917.
# PubMed returned no pagination data for 32706374.
# PubMed returned no pagination data for 32858836.
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-341-b8b1931b25da>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# PubMed returned no pagination data for 33529173.
# PubMed returned no pagination data for 33536249.

# %%
df_cure
# Out:
#           PMID             MAB_ID                          Target  \
# 0     16525047    {K75/41, K55/7}              {Kv4.3 K+ channel}
# 1     16566008            {L6/60}  {Slo1/BKAlpha maxi-K+ channel}
# 2     16687515           {K73/20}                  {Contactin/F3}
# 3     16817858  {K87A/10, K65/35}            {Nav1.6 Na+ channel}
# 4     16870743          {K87A/10}            {Nav1.6 Na+ channel}
# ...        ...                ...                             ...
# 4514  33536249          {N106/65}                     {Ankyrin-G}
# 4515  33556372            {L6/60}                  {Slo1/BKAlpha}
# 4516  33547341            {N212B}                        {TRIP8b}
# 4517  33663561           {K28/43}                        {PSD-95}
# 4518  33615226           {K28/43}                        {PSD-95}
#
#                                                citation  \
# 0     Kollo M, Holderith NB, Nusser Z. 2006. The Jou...
# 1     Misonou H, Menegola M, Buchwalder L et al.. 20...
# 2     Ogawa Y, Schafer DP, Horresh I et al.. 2006. T...
# 3     Rush AM, Wittmack EK, Tyrrell L et al.. 2006. ...
# 4     Lopez-Santiago LF, Pertin M, Morisod X et al.....
# ...                                                 ...
# 4514  Ogawa Y, Rasband MN. 2021. Journal of cell sci...
# 4515  Bukiya AN, Leo MD, Jaggar JH et al.. 2021. The...
# 4516  Rátkai A, Tárnok K, Aouad HE et al.. 2021. Sci...
# 4517  Perkins EM, Burr K, Banerjee P et al.. 2021. M...
# 4518  Gavrilovici C, Jiang Y, Kiroski I et al.. 2021...
#
#                                                   title  year  source
# 0     Novel subcellular distribution pattern of A-ty...  2006
# 1     Immunolocalization of the Ca2+-activated K+ ch...  2006
# 2     Spectrins and ankyrinB constitute a specialize...  2006
# 3     Differential modulation of sodium channel Na(v...  2006
# 4     Sodium channel beta2 subunits regulate tetrodo...  2006
# ...                                                 ...   ...     ...
# 4514  Endogenously expressed Ranbp2 is not at the ax...  2021  legacy
# 4515  Cholesterol activates BK channels by increasin...  2021  legacy
# 4516  Homeostatic plasticity and burst activity are ...  2021  legacy
# 4517  Altered network properties in C9ORF72 repeat e...  2021  legacy
# 4518  Behavioral Deficits in Mice with Postnatal Dis...  2021  legacy
#
# [4519 rows x 7 columns]

# %%
# summarize the source column with a figure 
import plotly.express as px
fig = px.histogram(df_cure, x="source")
fig.show()
# Out:
# <div>                            <div id="ba4dadb4-41c5-423d-a7f9-1eeace0f98c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba4dadb4-41c5-423d-a7f9-1eeace0f98c2")) {                    Plotly.newPlot(                        "ba4dadb4-41c5-423d-a7f9-1eeace0f98c2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"source=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","google scholar unique","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","google scholar unique","","","","","","","google scholar unique","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","google scholar unique","","","","","","","google scholar unique","google scholar unique","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","google scholar unique","","","","","","","","","google scholar unique","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","
# 3647  36945454                                          {N106/36}
# 3655  36997609                                           {N87/25}
# 3703  37333277                        {N106/36, N144/14, N105/17}
# 3704  37333281                                            {N86/8}
# 3721  37425759  {L113/130, K28/74, L113/13, K28/86, L106/93, L...
# 3722  37425856                                           {K28/43}
# 3723  37425915  {K14/16, N398A/34, K28/43, N106/20, L109/39, N...
# 3724  37425946                                         {N276A/15}
# 3727  37461609  {K14/16, L109/57, L115/13, K28/43, L114/81, N2...
# 3733  37502980                                           {K89/34}
# 3741  37577625                                         {N295B/66}
# 3759  37693426                          {K28/43, N355/1, N367/62}
# 3798  37916792                                           {K14/16}
# 3807  38014238                                          {N106/36}
# 3809  38038892                                           {N67/15}
# 3815  38187582  {K14/16, N68/6, K65/35, N134/12, N372B/60, K89...
# 3816  38193537                                          {N106/36}
# 3818  38231269                                         {N241A/34}
# 3820  38260608                                          {N106/36}
#
#                                                  Target citation title year  \
# 1563                                    {Co-Rest/RCOR1}
# 1621                                              {GFP}
# 2033                          {Beta3, Alpha1, GABA(A)R}
# 2069                                           {Arl13b}
# 2507                                           {VGlut1}
# 2640                                           {VGlut1}
# 2790  {GluN2B/NR2B glutamate receptor, GluA2/GluR2 g...
# 2868                                             {GFAP}
# 2882                       {LRRK2/Dardarin, C-terminus}
# 3041                                           {PSD-95}
# 3069                                           {Arl13b}
# 3139                               {Nav1.1 Na+ channel}
# 3186                                           {Arl13b}
# 3447                                           {PSD-95}
# 3575                               {Nav1.7 Na+ channel}
# 3632                    {KCNT1/Slo2.2/Slack K+ channel}
# 3647                             {Ankyrin-G (staining)}
# 3655                                  {Beta3, GABA(A)R}
# 3703           {Ankyrin-B, Ankyrin-G (staining), 6xHis}
# 3704                                              {GFP}
# 3721  {PSD-95, Pan-MAGUK, AMIGO-1, Homer1L + Homer1S...
# 3722                                           {PSD-95}
# 3723  {PSD-95, Calbindin, GABA(B)R1, Kv1.2 K+ channe...
# 3724                                  {Synaptotagmin-9}
# 3727  {PSD-95, Calbindin, Kv1.2 K+ channel, VGlut1, ...
# 3733                                 {Kv2.1 K+ channel}
# 3741                                           {Arl13b}
# 3759   {PSD-95, Shank3, GluA1/GluR1 glutamate receptor}
# 3798                                 {Kv1.2 K+ channel}
# 3807                             {Ankyrin-G (staining)}
# 3809                                            {TrpC5}
# 3815                               {Nav1.7 Na+ channel}
# 3816                             {Ankyrin-G (staining)}
# 3818                       {LRRK2/Dardarin, C-terminus}
# 3820                             {Ankyrin-G (staining)}
#
#                      source
# 1563  google scholar unique
# 1621  google scholar unique
# 2033  google scholar unique
# 2069
# 2507
# 2640  google scholar unique
# 2790  google scholar unique
# 2868  google scholar unique
# 2882  google scholar unique
# 3041  google scholar unique
# 3069
# 3139
# 3186  google scholar unique
# 3447  google scholar unique
# 3575  google scholar unique
# 3632  google scholar unique
# 3647  google scholar unique
# 3655  google scholar unique
# 3703  google scholar unique
# 3704  google scholar unique
# 3721  google scholar unique
# 3722  google scholar unique
# 3723  google scholar unique
# 3724  google scholar unique
# 3727  google scholar unique
# 3733  google scholar unique
# 3741  google scholar unique
# 3759  google scholar unique
# 3798  google scholar unique
# 3807  google scholar unique
# 3809  google scholar unique
# 3815  google scholar unique
# 3816  google scholar unique
# 3818  google scholar unique
# 3820  google scholar unique

# %%
# output df_cure
df_cure = df_cure[df_cure['year'] >= 2000]

df_cure.to_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/df_cure.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/jupyter/Scraper_Main(2_28_23)-checkpoint.ipynb Cell 72 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/jupyter/Scraper_Main%282_28_23%29-checkpoint.ipynb#Y256sZmlsZQ%3D%3D?line=0'>1</a> # output df_cure
# ----> <a href='vscode-notebook-cell:/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/jupyter/Scraper_Main%282_28_23%29-checkpoint.ipynb#Y256sZmlsZQ%3D%3D?line=1'>2</a> df_cure = df_cure[df_cure['year'] >= 2000]
#       <a href='vscode-notebook-cell:/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/jupyter/Scraper_Main%282_28_23%29-checkpoint.ipynb#Y256sZmlsZQ%3D%3D?line=3'>4</a> df_cure.to_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/df_cure.csv", index=False)
#
# File /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/pandas/core/arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# File /opt/anaconda3/envs/trimmer_lab/lib/python3.8/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
# expand out the list columns into multiple rows (do MAB_ID)
df_cure = pd.read_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/df_cure.csv")
# turn the string columns into lists after getting rid of the {} for MAB_ID 
# some are split on or as well fix that by replacing or with a comma space
df_cure['MAB_ID'] = df_cure['MAB_ID'].str.replace('{', '').str.replace('}', '').str.replace("'", '').str.replace(' or ', ', ').str.split(', ')
# replace the html stuff in the title that <>
df_cure['title'] = df_cure['title'].str.replace('<i>', '').str.replace('</i>', '').str.replace('<b>', '').str.replace('</b>', '')
df_cure['title'] = df_cure['title'].str.replace('<sub>', '').str.replace('</sub>', '').str.replace('<sup>', '').str.replace('</sup>', '')
df_cure['title'] = df_cure['title'].str.replace('<u>', '').str.replace('</u>', '')
# output a df_cure_cleaaned
# turn year into an int
#df_cure['year'] = df_cure['year'].astype(int)
df_cure.to_csv("/Users/keithmitchell/Desktop/Repositories/NeuroMabSeq/trimmer/picklequeries/df_cure_cleaned.csv", index=False)
df_cure = df_cure.explode('MAB_ID')
df_cure
# Out:
# <ipython-input-351-27d238ce64ce>:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#           PMID   MAB_ID                            Target  \
# 0     16525047   K75/41              {'Kv4.3 K+ channel'}
# 0     16525047    K55/7              {'Kv4.3 K+ channel'}
# 1     16566008    L6/60  {'Slo1/BKAlpha maxi-K+ channel'}
# 2     16687515   K73/20                  {'Contactin/F3'}
# 3     16817858  K87A/10            {'Nav1.6 Na+ channel'}
# ...        ...      ...                               ...
# 4514  33536249  N106/65                     {'Ankyrin-G'}
# 4515  33556372    L6/60                  {'Slo1/BKAlpha'}
# 4516  33547341    N212B                        {'TRIP8b'}
# 4517  33663561   K28/43                        {'PSD-95'}
# 4518  33615226   K28/43                        {'PSD-95'}
#
#                                                citation  \
# 0     Kollo M, Holderith NB, Nusser Z. 2006. The Jou...
# 0     Kollo M, Holderith NB, Nusser Z. 2006. The Jou...
# 1     Misonou H, Menegola M, Buchwalder L et al.. 20...
# 2     Ogawa Y, Schafer DP, Horresh I et al.. 2006. T...
# 3     Rush AM, Wittmack EK, Tyrrell L et al.. 2006. ...
# ...                                                 ...
# 4514  Ogawa Y, Rasband MN. 2021. Journal of cell sci...
# 4515  Bukiya AN, Leo MD, Jaggar JH et al.. 2021. The...
# 4516  Rátkai A, Tárnok K, Aouad HE et al.. 2021. Sci...
# 4517  Perkins EM, Burr K, Banerjee P et al.. 2021. M...
# 4518  Gavrilovici C, Jiang Y, Kiroski I et al.. 2021...
#
#                                                   title    year  source
# 0     Novel subcellular distribution pattern of A-ty...  2006.0     NaN
# 0     Novel subcellular distribution pattern of A-ty...  2006.0     NaN
# 1     Immunolocalization of the Ca2+-activated K+ ch...  2006.0     NaN
# 2     Spectrins and ankyrinB constitute a specialize...  2006.0     NaN
# 3     Differential modulation of sodium channel Na(v...  2006.0     NaN
# ...                                                 ...     ...     ...
# 4514  Endogenously expressed Ranbp2 is not at the ax...  2021.0  legacy
# 4515  Cholesterol activates BK channels by increasin...  2021.0  legacy
# 4516  Homeostatic plasticity and burst activity are ...  2021.0  legacy
# 4517  Altered network properties in C9ORF72 repeat e...  2021.0  legacy
# 4518  Behavioral Deficits in Mice with Postnatal Dis...  2021.0  legacy
#
# [6213 rows x 7 columns]

# %%
# testing

# %%
# remove anything before the year 2000
df_cure = df_cure[df_cure['year'] >= 2000]
# make the same plot
fig = px.histogram(df_cure, x="year", color="MAB_ID")
fig.show()
# Out:
# <div>                            <div id="851e5c28-8f2d-4a34-a9d8-fcddc5a1395a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById